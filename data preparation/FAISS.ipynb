# %% [markdown]
# **Setup and Imports**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Install necessary packages
# !pip install langchain langchain-community tiktoken faiss-cpu huggingface_hub sentence-transformers spacy

# Download spaCy model
# !python -m spacy download en_core_web_lg

# Create required directories
import os
os.makedirs("data/cleaned_texts", exist_ok=True)
os.makedirs("chunks", exist_ok=True)
os.makedirs("faiss_index", exist_ok=True)
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.11/dist-packages (0.3.23)
# Collecting langchain-community
#   Downloading langchain_community-0.3.21-py3-none-any.whl.metadata (2.4 kB)
# Collecting tiktoken
#   Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.10.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (0.30.2)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (3.4.1)
# Requirement already satisfied: spacy in /usr/local/lib/python3.11/dist-packages (3.8.5)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.51 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.51)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.28)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.11.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (3.11.15)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (9.1.2)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.8.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: numpy<3,>=1.26.2 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (24.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (2025.3.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (4.13.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.51.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (2.6.0+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.14.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.1.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.15.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy) (75.2.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.4.2)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.19.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.51->langchain) (1.33)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.0)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (2025.1.31)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.51->langchain) (3.0.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.1)
# Downloading langchain_community-0.3.21-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 48.7 MB/s eta 0:00:00
# Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 70.0 MB/s eta 0:00:00
# Downloading faiss_cpu-1.10.0-cp311-cp311-manylinux_2_28_x86_64.whl (30.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.7/30.7 MB 64.9 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading pydantic_settings-2.8.1-py3-none-any.whl (30 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 109.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 83.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.0 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.2 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 66.7 MB/s eta 0:00:00
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.9 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: python-dotenv, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, mypy-extensions, marshmallow, httpx-sse, faiss-cpu, typing-inspect, tiktoken, nvidia-cusparse-cu12, nvidia-cudnn-cu12, pydantic-settings, nvidia-cusolver-cu12, dataclasses-json, langchain-community
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed dataclasses-json-0.6.7 faiss-cpu-1.10.0 httpx-sse-0.4.0 langchain-community-0.3.21 marshmallow-3.26.1 mypy-extensions-1.0.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pydantic-settings-2.8.1 python-dotenv-1.1.0 tiktoken-0.9.0 typing-inspect-0.9.0
# Collecting en-core-web-lg==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.8.0/en_core_web_lg-3.8.0-py3-none-any.whl (400.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.7/400.7 MB 3.7 MB/s eta 0:00:00
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import os
os.makedirs("data/cleaned_texts", exist_ok=True)
os.makedirs("chunks", exist_ok=True)
os.makedirs("faiss_index", exist_ok=True)

# %%
import os
import shutil
from pathlib import Path

# Create the target directory if it doesn't exist
os.makedirs("data/cleaned_texts", exist_ok=True)

# Source directory in Google Drive
source_dir = "/content/drive/MyDrive/cleaned_texts"

# Check if source directory exists
if not os.path.exists(source_dir):
    print(f"Source directory {source_dir} does not exist. Please check the path.")
else:
    # Get list of files in source directory
    files = os.listdir(source_dir)
    print(f"Found {len(files)} files in {source_dir}")

    # Copy each file to the target directory
    copied_count = 0
    for filename in files:
        source_path = os.path.join(source_dir, filename)
        target_path = os.path.join("data/cleaned_texts", filename)

        # Only copy files, not directories
        if os.path.isfile(source_path):
            shutil.copy2(source_path, target_path)
            copied_count += 1
            print(f"Copied: {filename}")

    print(f"\nSuccessfully copied {copied_count} files to data/cleaned_texts")

    # Verify files in target directory
    target_files = os.listdir("data/cleaned_texts")
    print(f"Target directory now has {len(target_files)} files")
# Out:
# Found 1428 files in /content/drive/MyDrive/cleaned_texts
# Copied: Smartshare.txt
# Copied: Spendcoin.txt
# Copied: SONM.txt
# Copied: SHIELD.txt
# Copied: STEX.txt
# Copied: Robotina.txt
# Copied: Sharder.txt
# Copied: SalPay.txt
# Copied: SakuraCoin.txt
# Copied: SpiderVPS.txt
# Copied: Switcheo.txt
# Copied: Synthetix Network.txt
# Copied: SyncFab.txt
# Copied: Oasis City.txt
# Copied: Patron.txt
# Copied: Primalbase.txt
# Copied: Poseidon Network.txt
# Copied: Privatix.txt
# Copied: Power Ledger.txt
# Copied: Odyssey.txt
# Copied: osadc en.txt
# Copied: Polis.txt
# Copied: Probit.txt
# Copied: OWNDATA.txt
# Copied: Pillar.txt
# Copied: Pluton.txt
# Copied: Oyster.txt
# Copied: Pirate Chain.txt
# Copied: OTCBTC Token.txt
# Copied: PotCoin.txt
# Copied: Pesetacoin.txt
# Copied: PayPie.txt
# Copied: Project Coin.txt
# Copied: Pibble.txt
# Copied: ORS Group.txt
# Copied: Peerplays.txt
# Copied: Polymath.txt
# Copied: PKG Token.txt
# Copied: PlusCoin.txt
# Copied: Piction.txt
# Copied: OneGame.txt
# Copied: Opiria PDATA.txt
# Copied: Playgroundz.txt
# Copied: Provoco.txt
# Copied: ONO.txt
# Copied: Parachute.txt
# Copied: Prometeus.txt
# Copied: Ontology.txt
# Copied: On.Live.txt
# Copied: Pixie Coin.txt
# Copied: OptiToken.txt
# Copied: Paxos.txt
# Copied: Peerguess.txt
# Copied: Primas.txt
# Copied: Platin.txt
# Copied: Promotion Coin.txt
# Copied: Path.txt
# Copied: Playkey.txt
# Copied: ProximaX.txt
# Copied: Observer Technical Note.txt
# Copied: Phantasma.txt
# Copied: ODEM.txt
# Copied: Pledgecamp.txt
# Copied: Puregold.txt
# Copied: Obitan Chain.txt
# Copied: Project Pai.txt
# Copied: Opennity.txt
# Copied: PAYCENT.txt
# Copied: Planet.txt
# Copied: Opus.txt
# Copied: PoSToken.txt
# Copied: OneLedger.txt
# Copied: Phore.txt
# Copied: Pecunio.txt
# Copied: Populous.txt
# Copied: PLATINCOIN.txt
# Copied: Orbs.txt
# Copied: PIVX.txt
# Copied: Payfair.txt
# Copied: Phi.txt
# Copied: Polybius.txt
# Copied: Olympus Labs.txt
# Copied: PolySwarm.txt
# Copied: PressOne.txt
# Copied: Oceanlab.txt
# Copied: Omnitude.txt
# Copied: Perlin.txt
# Copied: Polkadot.txt
# Copied: OAX.txt
# Copied: Primecoin.txt
# Copied: Origami.txt
# Copied: Orchid.txt
# Copied: Pivot.txt
# Copied: OneRoot Network.txt
# Copied: PUBLYTO.txt
# Copied: OATH protocol.txt
# Copied: PumaPay.txt
# Copied: Presearch.txt
# Copied: Po.et.txt
# Copied: Power.txt
# Copied: PundiX.txt
# Copied: Publica.txt
# Copied: Powerchain.txt
# Copied: OIO.txt
# Copied: PlayChip.txt
# Copied: OmiseGO.txt
# Copied: PlayerOne.txt
# Copied: Pedity.txt
# Copied: Plair.txt
# Copied: PAX Gold.txt
# Copied: Paytomat.txt
# Copied: ProChain.txt
# Copied: Ocean Protocol.txt
# Copied: Pascal Coin.txt
# Copied: Peercoin.txt
# Copied: Ormeus Coin.txt
# Copied: patientory.txt
# Copied: PACcoin.txt
# Copied: Opal.txt
# Copied: Phonecoin.txt
# Copied: Obyte.txt
# Copied: OriginTrail.txt
# Copied: PWR Coin.txt
# Copied: Proton.txt
# Copied: OracleChain.txt
# Copied: PAXEX.txt
# Copied: Pura.txt
# Copied: OOOBTC Token.txt
# Copied: PlayFuel.txt
# Copied: Ondori.txt
# Copied: pEOS.txt
# Copied: Propy.txt
# Copied: Olyseum.txt
# Copied: Petro.txt
# Copied: PalletOne.txt
# Copied: Pathhive.txt
# Copied: ParkGene.txt
# Copied: Pylon Network.txt
# Copied: Origo.txt
# Copied: PiplCoin.txt
# Copied: OST.txt
# Copied: MenaPay.txt
# Copied: Monero.txt
# Copied: Measurable Data Token.txt
# Copied: Maincoin.txt
# Copied: MergeCoin.txt
# Copied: Maecenas.txt
# Copied: Monetha.txt
# Copied: messe.txt
# Copied: MovieBloc.txt
# Copied: Melon.txt
# Copied: Monero Gold.txt
# Copied: Metronome.txt
# Copied: MaidSafeCoin.txt
# Copied: Mozo Token.txt
# Copied: Monster Byte.txt
# Copied: MassGrid.txt
# Copied: Monaco.txt
# Copied: MinexCoin.txt
# Copied: MTC Mesh Network.txt
# Copied: Metaverse ETP.txt
# Copied: Mithril Ore.txt
# Copied: MobilinkToken.txt
# Copied: membrana.txt
# Copied: Maya Preferred.txt
# Copied: MINDOL.txt
# Copied: MediBloc.txt
# Copied: Modum.txt
# Copied: Matic Network.txt
# Copied: mcashchain.txt
# Copied: MineBee.txt
# Copied: MoneroV.txt
# Copied: Mirai.txt
# Copied: Magnet.txt
# Copied: MGC.txt
# Copied: Monero Original.txt
# Copied: MediShares.txt
# Copied: MIR COIN.txt
# Copied: MetaHash.txt
# Copied: Mero.txt
# Copied: MCPC.txt
# Copied: MESG.txt
# Copied: Merculet.txt
# Copied: Magic Cube.txt
# Copied: MFCoin.txt
# Copied: MicroBitcoin.txt
# Copied: MB8.txt
# Copied: MixMarvel.txt
# Copied: MEET.ONE.txt
# Copied: Medibit.txt
# Copied: Mothership.txt
# Copied: MobileGo.txt
# Copied: Mobius.txt
# Copied: Mindexcoin.txt
# Copied: Mossland.txt
# Copied: Micromines.txt
# Copied: Mixin.txt
# Copied: Modultrade.txt
# Copied: Mainframe.txt
# Copied: metal Pay.txt
# Copied: Monero Classic.txt
# Copied: Matchpool.txt
# Copied: Matrix AI Network.txt
# Copied: Motocoin.txt
# Copied: MOAC.txt
# Copied: Mercury Protocol.txt
# Copied: MARK.SPACE.txt
# Copied: Marginless.txt
# Copied: Mithril.txt
# Copied: Maggie.txt
# Copied: MEXC Token.txt
# Copied: Medicalchain.txt
# Copied: Molecular Future.txt
# Copied: MMOCoin.txt
# Copied: MedicCoin.txt
# Copied: NeoWorld Cash.txt
# Copied: Noah Coin.txt
# Copied: Nos.txt
# Copied: NeuroChain.txt
# Copied: NANJCOIN.txt
# Copied: Nuls.txt
# Copied: Nebulas.txt
# Copied: Neural Protocol.txt
# Copied: NEM.txt
# Copied: Nectar.txt
# Copied: Nano.txt
# Copied: Newton.txt
# Copied: NOW Token.txt
# Copied: Next.Exchange.txt
# Copied: Neblio.txt
# Copied: Nexo.txt
# Copied: NapoleonX.txt
# Copied: Natmin.txt
# Copied: MyBit Token.txt
# Copied: NewYork Exchange Coin.txt
# Copied: NewsToken.txt
# Copied: Mytoken.txt
# Copied: MX Token.txt
# Copied: Neox.txt
# Copied: Nexty.txt
# Copied: netbox coin.txt
# Copied: Noir.txt
# Copied: Nervos.txt
# Copied: Muzika.txt
# Copied: NoLimitCoin.txt
# Copied: NIX.txt
# Copied: Nebula AI.txt
# Copied: Noku.txt
# Copied: Nestree.txt
# Copied: NPCoin.txt
# Copied: Nash Exchange Token.txt
# Copied: MultiVAC Tech.txt
# Copied: No BS Crypto.txt
# Copied: Mysterium.txt
# Copied: Numeraire.txt
# Copied: Nasdacoin.txt
# Copied: NOIZ.txt
# Copied: netkoin.txt
# Copied: Neumark.txt
# Copied: Nexus.txt
# Copied: NEO.txt
# Copied: NOIA Network.txt
# Copied: namecoin.txt
# Copied: Niobium Coin.txt
# Copied: Netrum.txt
# Copied: NKN.txt
# Copied: Nitro.txt
# Copied: NAGA.txt
# Copied: NEVERDIE.txt
# Copied: Nxt.txt
# Copied: Liquidity Network.txt
# Copied: LeviarCoin.txt
# Copied: Lisk.txt
# Copied: LikeCoin.txt
# Copied: Ladder Network.txt
# Copied: Loopring.txt
# Copied: Lykke.txt
# Copied: Levolution.txt
# Copied: Lition.txt
# Copied: LiquidApps.txt
# Copied: Linkey.txt
# Copied: Litecoin Cash.txt
# Copied: LiteDoge.txt
# Copied: Lympo.txt
# Copied: LoyalCoin.txt
# Copied: Live Stars.txt
# Copied: LinkEye.txt
# Copied: Lisk Machine Learning.txt
# Copied: Kleros.txt
# Copied: Kin.txt
# Copied: legolas.txt
# Copied: Leo Token.txt
# Copied: komodo.txt
# Copied: Litex.txt
# Copied: LUXCoin.txt
# Copied: LEOcoin.txt
# Copied: LatiumX.txt
# Copied: LockTrip.txt
# Copied: Kryll.txt
# Copied: LIFE.txt
# Copied: LINA.txt
# Copied: Linfinity.txt
# Copied: Kambria.txt
# Copied: Kubera Coin.txt
# Copied: Krypton Galaxy Coin.txt
# Copied: KuCoin Shares.txt
# Copied: Lunes.txt
# Copied: LHT usdx.txt
# Copied: LemoChain.txt
# Copied: KICKECOSYSTEM.txt
# Copied: LocalCoinSwap.txt
# Copied: LGO Exchange.txt
# Copied: Luna Stars.txt
# Copied: Leverj.txt
# Copied: Level Up Coin.txt
# Copied: Locus Chain.txt
# Copied: Litecoin.txt
# Copied: LTO Network.txt
# Copied: Lucky Seven.txt
# Copied: Lightpaycoin.txt
# Copied: Kuende.txt
# Copied: Karma.txt
# Copied: KanadeCoin.txt
# Copied: Karatgold Coin.txt
# Copied: Kyber.txt
# Copied: Livenodes.txt
# Copied: Lunyr.txt
# Copied: Linda.txt
# Copied: Lambda.txt
# Copied: LOCIcoin.txt
# Copied: Kolion.txt
# Copied: Libra Credit.txt
# Copied: Knoxstertoken.txt
# Copied: Kcash.txt
# Copied: Loki.txt
# Copied: INO COIN.txt
# Copied: Hyperspace.txt
# Copied: HireMatch.txt
# Copied: Herbalist Token.txt
# Copied: Hero.txt
# Copied: Indorse.txt
# Copied: HitChain.txt
# Copied: Hellenic Node.txt
# Copied: Hade Platform.txt
# Copied: HelloGold.txt
# Copied: Ifoods Chain.txt
# Copied: HunterCoin.txt
# Copied: Infinitus.txt
# Copied: hyperion.txt
# Copied: Hedera pdf.txt
# Copied: Horizon State.txt
# Copied: INS Ecosystem.txt
# Copied: Hyper Speed Network.txt
# Copied: Hydro Protocol.txt
# Copied: Hive.txt
# Copied: Intelligent Trading Foundation.txt
# Copied: HyperCash.txt
# Copied: INMAX.txt
# Copied: HorusPay.txt
# Copied: HyperLoot.txt
# Copied: Hot.txt
# Copied: HalalChain.txt
# Copied: HYCON.txt
# Copied: Haven Protocol.txt
# Copied: Halo Platform.txt
# Copied: Innovative Bioresearch Classic.txt
# Copied: Humanscape.txt
# Copied: Idex.txt
# Copied: InnovaMinex.txt
# Copied: Horizen.txt
# Copied: Insight Chain.txt
# Copied: Harvest Masternode Coin.txt
# Copied: HNB.txt
# Copied: Harmony.txt
# Copied: Hacken.txt
# Copied: ILCoin.txt
# Copied: Hypnoxys.txt
# Copied: ICON.txt
# Copied: HedgeTrade.txt
# Copied: IHT Real Estate Protocol.txt
# Copied: Ink Protocol.txt
# Copied: HashCoin.txt
# Copied: HTMLCoin.txt
# Copied: Idealcoin.txt
# Copied: Hydrogen.txt
# Copied: Hempcoin.txt
# Copied: Hedgetoken.txt
# Copied: huddl.txt
# Copied: HEAT.txt
# Copied: Havven.txt
# Copied: Holo.txt
# Copied: Hybrid Block.txt
# Copied: Imbrex.txt
# Copied: High Performance Blockchain.txt
# Copied: iExec.txt
# Copied: Ignis.txt
# Copied: IGNITE.txt
# Copied: Ignition.txt
# Copied: Ink.txt
# Copied: HomeBlockCoin.txt
# Copied: InsurChain.txt
# Copied: Hashgard.txt
# Copied: IntelliShare.txt
# Copied: HEROcoin.txt
# Copied: Impleum.txt
# Copied: Honest.txt
# Copied: Hubii Network.txt
# Copied: Humaniq.txt
# Copied: Japan Content Token.txt
# Copied: iotex.txt
# Copied: IONChain.txt
# Copied: IQ.cash.txt
# Copied: IOTW.txt
# Copied: Ivy.txt
# Copied: InterCrone.txt
# Copied: Internet of People.txt
# Copied: IoT Chain.txt
# Copied: Iungo.txt
# Copied: IXT.txt
# Copied: IQeon.txt
# Copied: Jesus Coin.txt
# Copied: Jewel.txt
# Copied: IZIChain.txt
# Copied: IntenseCoin.txt
# Copied: Joint Ventures.txt
# Copied: Jarvis.txt
# Copied: Jibrel Network.txt
# Copied: Internet Node Token.txt
# Copied: IOTA.txt
# Copied: IOU.txt
# Copied: InterValue.txt
# Copied: IP Exchange.txt
# Copied: IOSToken.txt
# Copied: Fire Lotto.txt
# Copied: GAMB.txt
# Copied: Filecoin.txt
# Copied: GINcoin.txt
# Copied: GridCoin.txt
# Copied: Fortuna.txt
# Copied: Global Social Chain.txt
# Copied: Gulden.txt
# Copied: Gatcoin.txt
# Copied: FLIP.txt
# Copied: GoldenFever.txt
# Copied: Fast Access Blockchain.txt
# Copied: gratzio wp.txt
# Copied: Gold Poker.txt
# Copied: GOmics.txt
# Copied: FUSION.txt
# Copied: Gene Source Code Chain.txt
# Copied: Gexan.txt
# Copied: GSENetwork.txt
# Copied: Gibraltar.txt
# Copied: Flowchain.txt
# Copied: GlitzKoin.txt
# Copied: FoodCoin.txt
# Copied: Fabric Token.txt
# Copied: Fantom.txt
# Copied: Gnosis.txt
# Copied: fscp.txt
# Copied: FootballCoin.txt
# Copied: FolmCoin.txt
# Copied: Fitrova.txt
# Copied: Facebook Libra.txt
# Copied: Gold Bits Coin.txt
# Copied: FuzeX.txt
# Copied: Flexacoin.txt
# Copied: Genaro Network.txt
# Copied: Globalvillage Ecosystem.txt
# Copied: Graviocoin.txt
# Copied: Farad.txt
# Copied: GoChain.txt
# Copied: Gaps Chain.txt
# Copied: Friendz.txt
# Copied: FTX Token.txt
# Copied: Formosa Financial.txt
# Copied: Fleta.txt
# Copied: FOAM.txt
# Copied: Factom.txt
# Copied: GNY.txt
# Copied: Freicoin.txt
# Copied: FuckToken.txt
# Copied: Gosama Final.txt
# Copied: FansTime.txt
# Copied: Flash.txt
# Copied: Galactrum.txt
# Copied: Gifto.txt
# Copied: GateChain.txt
# Copied: GET Protocol.txt
# Copied: GoWithMi.txt
# Copied: Future1coin.txt
# Copied: GameCredits.txt
# Copied: Gainer.txt
# Copied: Global Jobcoin.txt
# Copied: fintrux.txt
# Copied: Function X.txt
# Copied: FidentiaX.txt
# Copied: Gemini Dollar.txt
# Copied: Galaxy eSolutions.txt
# Copied: FundYourselfNow.txt
# Copied: Fabrk.txt
# Copied: GoByte.txt
# Copied: Flixxo.txt
# Copied: FairCoin.txt
# Copied: Genesis vision.txt
# Copied: FREE Coin.txt
# Copied: Giant.txt
# Copied: Golem.txt
# Copied: FunFair.txt
# Copied: Folding Coin.txt
# Copied: GlassCoin.txt
# Copied: Groestlcoin.txt
# Copied: Gems.txt
# Copied: GreenPower.txt
# Copied: GazeCoi.txt
# Copied: GanjaCoin.txt
# Copied: Fetch.txt
# Copied: GXChain.txt
# Copied: FOINS.txt
# Copied: Denarius.txt
# Copied: DAOstack.txt
# Copied: Dero.txt
# Copied: Datawallet.txt
# Copied: Datum.txt
# Copied: Dapp Token.txt
# Copied: Databits.txt
# Copied: DeepOnion.txt
# Copied: Devify.txt
# Copied: Devery.txt
# Copied: DeepCloudAI.txt
# Copied: DasCoin.txt
# Copied: DCTO.txt
# Copied: DashCash.txt
# Copied: DACH Coin.txt
# Copied: Decentralized Vulnerability Platform.txt
# Copied: Delphy.txt
# Copied: DACC.txt
# Copied: Darcrus.txt
# Copied: DeepBrain Chain.txt
# Copied: Dentacoin.txt
# Copied: Delizia.txt
# Copied: Daneel.txt
# Copied: Davinci Coin.txt
# Copied: DENT ICO.txt
# Copied: Decentralized Machine Learning.txt
# Copied: DECENT.txt
# Copied: DecentBet.txt
# Copied: DeusCoin.txt
# Copied: Dash.txt
# Copied: DaTa eXchange.txt
# Copied: DAEX.txt
# Copied: Datarius.txt
# Copied: Decentraland.txt
# Copied: Dai.txt
# Copied: DAV Coin.txt
# Copied: DDKoin.txt
# Copied: DashDiamond.txt
# Copied: Decred.txt
# Copied: Dinero.txt
# Copied: ESBC.txt
# Copied: evedo.txt
# Copied: Effect.ai.txt
# Copied: Dimecoin.txt
# Copied: Distributed Credit Chain.txt
# Copied: EnterCoin.txt
# Copied: EDC Blockchain.txt
# Copied: Digitex Futures.txt
# Copied: DOS Network.txt
# Copied: Expanse.txt
# Copied: DogeCash.txt
# Copied: district0x.txt
# Copied: Dusk Network.txt
# Copied: Divi.txt
# Copied: DxChain.txt
# Copied: Eryllium.txt
# Copied: ethereum classic.txt
# Copied: Einsteinium.txt
# Copied: Elastos.txt
# Copied: Electrify.Asia.txt
# Copied: DUO Network.txt
# Copied: Enjin Coin.txt
# Copied: ENERGI.txt
# Copied: Dragon Coins.txt
# Copied: EQUI.txt
# Copied: EPLUS Coin.txt
# Copied: DigitalDevelopersFund.txt
# Copied: Elixir.txt
# Copied: EveriToken.txt
# Copied: Ether Zero.txt
# Copied: EBCoin.txt
# Copied: DigitalPrice.txt
# Copied: EthBet.txt
# Copied: Etherparty.txt
# Copied: Ezoow.txt
# Copied: Dimension Chain.txt
# Copied: Eroscoin.txt
# Copied: EthereumX.txt
# Copied: DraftCoin.txt
# Copied: EdenChain.txt
# Copied: Enecuum.txt
# Copied: Elastic.txt
# Copied: Ethorse.txt
# Copied: Etherinc.txt
# Copied: Eva Cash.txt
# Copied: Experience points.txt
# Copied: Emanate.txt
# Copied: DogeCoin.txt
# Copied: DIMCOIN.txt
# Copied: DigiPulse.txt
# Copied: EJOY.txt
# Copied: Electroneum.txt
# Copied: DreamTeam.txt
# Copied: Ethereum.txt
# Copied: Essentia.txt
# Copied: EXMR FDN.txt
# Copied: Enigma.txt
# Copied: Diamond Network.txt
# Copied: Dropil.txt
# Copied: Eximchain.txt
# Copied: Egretia.txt
# Copied: Everex.txt
# Copied: ETERNAL TOKEN.txt
# Copied: EscrowCoin.txt
# Copied: DomRaider.txt
# Copied: DREP.txt
# Copied: DOWCOIN.txt
# Copied: Ether Social Network.txt
# Copied: Diruna.txt
# Copied: Ecoreal Estate.txt
# Copied: Ether Kingdom.txt
# Copied: Etherlegends.txt
# Copied: Digiwage.txt
# Copied: Everus.txt
# Copied: EUNO Coin.txt
# Copied: Elitium.txt
# Copied: Dragonchain.txt
# Copied: ELTCOIN.txt
# Copied: Envion.txt
# Copied: Ethos.txt
# Copied: Docademic.txt
# Copied: Edgeless.txt
# Copied: Esports Token.txt
# Copied: Energo.txt
# Copied: EOS.IO.txt
# Copied: Digital Fantasy Sports.txt
# Copied: DMarket.txt
# Copied: Electra.txt
# Copied: Electronic Energy Coin.txt
# Copied: EncryptoTel.txt
# Copied: Ethereum Gold Project.txt
# Copied: Diamond.txt
# Copied: Experty.txt
# Copied: Eligma.txt
# Copied: Digitalbits.txt
# Copied: DigiByte.txt
# Copied: Eterbase.txt
# Copied: EveryCoin.txt
# Copied: Espers.txt
# Copied: ENTCash.txt
# Copied: eBoost.txt
# Copied: Eristica.txt
# Copied: Emercoin.txt
# Copied: Dock.txt
# Copied: Elrond.txt
# Copied: Etheroll.txt
# Copied: ECC.txt
# Copied: Endor Protocol.txt
# Copied: Engine.txt
# Copied: Ethbits.txt
# Copied: DigitalNote.txt
# Copied: Asch.txt
# Copied: BawNetwork.txt
# Copied: Bayan Token.txt
# Copied: AirFox.txt
# Copied: Ampleforth.txt
# Copied: apM Coin.txt
# Copied: Aditus.txt
# Copied: Aidus.txt
# Copied: Agrocoin.txt
# Copied: ArcBlock.txt
# Copied: Aryacoin.txt
# Copied: Almeela.txt
# Copied: 0xcert.txt
# Copied: 1irstcoin.txt
# Copied: 1X2 Coin.txt
# Copied: Aurora.txt
# Copied: Adzcoin.txt
# Copied: ALQO.txt
# Copied: Bastonet.txt
# Copied: Apex.txt
# Copied: Atonomi.txt
# Copied: Achain.txt
# Copied: AgrolifeCoin.txt
# Copied: AVINOC.txt
# Copied: Bankcoin.txt
# Copied: Basic Attention Token.txt
# Copied: Aitheon.txt
# Copied: AICHAIN.txt
# Copied: Banca.txt
# Copied: Anchor.txt
# Copied: Aeron.txt
# Copied: Absolute.txt
# Copied: Arionum.txt
# Copied: Adtoken.txt
# Copied: Aventus.txt
# Copied: AdShares.txt
# Copied: Banyan Network.txt
# Copied: AdEx.txt
# Copied: Aidos Kuneen.txt
# Copied: Ambrosus.txt
# Copied: All Sports.txt
# Copied: 0chain.txt
# Copied: Auctus.txt
# Copied: alphacoin.txt
# Copied: B91.txt
# Copied: Aladdin.txt
# Copied: ArtByte.txt
# Copied: AirSwap.txt
# Copied: Afin.txt
# Copied: Acute Angle Cloud.txt
# Copied: Band Protocol.txt
# Copied: Apollo.txt
# Copied: AceD.txt
# Copied: Appcoins.txt
# Copied: Acoin.txt
# Copied: AirWire.txt
# Copied: BABB.txt
# Copied: AMO Coin.txt
# Copied: Amino Network.txt
# Copied: Alibabacoin.txt
# Copied: ABBC Foundation.txt
# Copied: ATN.txt
# Copied: Aencoin.txt
# Copied: aion.txt
# Copied: APIS.txt
# Copied: 0x.txt
# Copied: Arbidex.txt
# Copied: ABCC Token.txt
# Copied: Apollon.txt
# Copied: Bankera.txt
# Copied: ADN.txt
# Copied: Aave.txt
# Copied: APOT.txt
# Copied: Alchemint.txt
# Copied: AiLink Token.txt
# Copied: Algorand.txt
# Copied: aeternity.txt
# Copied: Alphacon.txt
# Copied: AuroraCoin.txt
# Copied: B2B.txt
# Copied: Arepacoin.txt
# Copied: Aergo.txt
# Copied: Augur.txt
# Copied: Airbloc.txt
# Copied: BBSCoin.txt
# Copied: BaaSid.txt
# Copied: ABLE.txt
# Copied: 999.txt
# Copied: Atlant.txt
# Copied: Altlas Protocol.txt
# Copied: Akroma.txt
# Copied: ATBCoin.txt
# Copied: ALAX.txt
# Copied: Bankex.txt
# Copied: ACRE.txt
# Copied: Ark.io.txt
# Copied: AI Doctor.txt
# Copied: AmonD.txt
# Copied: Alphacat.txt
# Copied: Agrolot.txt
# Copied: 1World.txt
# Copied: Asgard.txt
# Copied: Abjcoin.txt
# Copied: Ardor.txt
# Copied: Atlantis Blue Digital Token.txt
# Copied: 2014.5_word_to_int.txt
# Copied: Asian Dragon.txt
# Copied: Agrello.txt
# Copied: Aston.txt
# Copied: adbank.txt
# Copied: Authorship.txt
# Copied: AMARK.txt
# Copied: Bizkey.txt
# Copied: BCDiploma.txt
# Copied: Bezant.txt
# Copied: BlockStamp.txt
# Copied: Bethereum.txt
# Copied: BitNewChain.txt
# Copied: BnkToTheFuture.txt
# Copied: BTCMoon.txt
# Copied: Bitcoin Cash.txt
# Copied: BuzzCoin.txt
# Copied: BlockMesh.txt
# Copied: Binance.txt
# Copied: Blockstack.txt
# Copied: BOSAGORA.txt
# Copied: BitBean.txt
# Copied: Bitcoiin2Gen.txt
# Copied: BOScoin.txt
# Copied: BitScreener.txt
# Copied: Bittwatt.txt
# Copied: BitcoinSV.txt
# Copied: Beldex.txt
# Copied: BitcoinHD.txt
# Copied: Bytom.txt
# Copied: Bitblocks.txt
# Copied: Blockmason Link.txt
# Copied: BitWhite.txt
# Copied: BORA.txt
# Copied: BitShares.txt
# Copied: Bloom.txt
# Copied: BQT.txt
# Copied: BunnyToken.txt
# Copied: BidiPass.txt
# Copied: Bitcoin Green.txt
# Copied: Bidooh.txt
# Copied: BitStash.txt
# Copied: BitcoiNote.txt
# Copied: BitDegree.txt
# Copied: Beetle Coin.txt
# Copied: Boutspro.txt
# Copied: Byteball.txt
# Copied: Bionic.txt
# Copied: Bitcoin Token.txt
# Copied: Bitcoin Turbo Koin.txt
# Copied: Bee Token.txt
# Copied: BiNGOFun.txt
# Copied: BlockBurn.txt
# Copied: Bounty0x.txt
# Copied: Bodhi.txt
# Copied: BHP Network.txt
# Copied: bitCEO.txt
# Copied: Bismuth.txt
# Copied: beat.txt
# Copied: Bilaxy.txt
# Copied: BookingTokenUnit.txt
# Copied: Bitdeal.txt
# Copied: Blue Whale.txt
# Copied: BitBay.txt
# Copied: BitCash.txt
# Copied: bitJob.txt
# Copied: bitqy.txt
# Copied: Billionaire Token.txt
# Copied: BitRewards.txt
# Copied: BoatPilot.txt
# Copied: Bitcloud Pro.txt
# Copied: Block Chain.txt
# Copied: Bela.txt
# Copied: BetterBetting.txt
# Copied: Burst Coin.txt
# Copied: Bulleon.txt
# Copied: Bytecoin.txt
# Copied: BeeKan.txt
# Copied: BLUE.txt
# Copied: Bread.txt
# Copied: Blackmoon.txt
# Copied: Blockport.txt
# Copied: Blocktix.txt
# Copied: Bitmax Token.txt
# Copied: Budbo.txt
# Copied: BlackCoin.txt
# Copied: BlockMason Credit.txt
# Copied: BEAM.txt
# Copied: Bibox.txt
# Copied: Bluzelle.txt
# Copied: Blocklancer.txt
# Copied: BipCoin.txt
# Copied: BrazilCoin.txt
# Copied: BioCoin.txt
# Copied: Bitcoin W Spectrum.txt
# Copied: bitnautic.txt
# Copied: Bitcoin Red.txt
# Copied: Bitcoin Dark.txt
# Copied: Bitcoin Gold.txt
# Copied: Bulwark.txt
# Copied: Blockcloud.txt
# Copied: Boolberry.txt
# Copied: Blocktrade.txt
# Copied: Bottos.txt
# Copied: Bitsdaq.txt
# Copied: bitcoin.txt
# Copied: Blocknet.txt
# Copied: Blockium.txt
# Copied: Bitbook Gambling.txt
# Copied: BiblePay.txt
# Copied: Bgogo token.txt
# Copied: BitUP.txt
# Copied: Bitforex.txt
# Copied: Bittorrent.txt
# Copied: BitRent.txt
# Copied: Bitspark.txt
# Copied: Bigbom.txt
# Copied: Bitcoin Private.txt
# Copied: BitCoen.txt
# Copied: Blockpass.txt
# Copied: Block Logic.txt
# Copied: BlockCAT.txt
# Copied: BrahmaOS.txt
# Copied: BonusCloud.txt
# Copied: Bridge.txt
# Copied: botXcoin.txt
# Copied: BFFDoom.txt
# Copied: Bitcoin Rhodium.txt
# Copied: Beaxy Exchange.txt
# Copied: cashaa.txt
# Copied: CPChain.txt
# Copied: carVertical.txt
# Copied: CEDEX.txt
# Copied: Compound Coin.txt
# Copied: CHEX.txt
# Copied: CMITCOIN.txt
# Copied: ChainLink.txt
# Copied: CardStack.txt
# Copied: Consentium.txt
# Copied: Callisto Network.txt
# Copied: Content and Ad Network.txt
# Copied: Constellation.txt
# Copied: Clipper Coin.txt
# Copied: Celer Network.txt
# Copied: Coimatic.txt
# Copied: Cajutel.txt
# Copied: Colu Local Network.txt
# Copied: Caspian.txt
# Copied: Couchain.txt
# Copied: CoinMeet.txt
# Copied: Covesting.txt
# Copied: Centrality.txt
# Copied: Cortex.txt
# Copied: Cosmo Chain.txt
# Copied: Credit.txt
# Copied: CottonCoin.txt
# Copied: CryptoFlow.txt
# Copied: Chromapolis.txt
# Copied: ChatCoin.txt
# Copied: CryptoCarbon.txt
# Copied: Coinlancer.txt
# Copied: COTI.txt
# Copied: Cryptocean.txt
# Copied: ClearPoll.txt
# Copied: CARDbuyers.txt
# Copied: CNNS.txt
# Copied: ChainX.txt
# Copied: Cobinhood.txt
# Copied: Cocos BCX.txt
# Copied: Credits.txt
# Copied: Crycash.txt
# Copied: Crowdvilla.txt
# Copied: Castle.txt
# Copied: Constant.txt
# Copied: CannaCoin.txt
# Copied: Contentos.txt
# Copied: Cloud.txt
# Copied: ColossusXT.txt
# Copied: Capdax.txt
# Copied: Cloudbric.txt
# Copied: CommerceBlock.txt
# Copied: CloakCoin.txt
# Copied: Chiliz.txt
# Copied: Coinchase.txt
# Copied: CARAT.txt
# Copied: CasinoCoin.txt
# Copied: Chronologic.txt
# Copied: Celsius.txt
# Copied: Canlead.txt
# Copied: Carry.txt
# Copied: Concierge Coin.txt
# Copied: Connect Coin.txt
# Copied: CFun.txt
# Copied: CoinUs.txt
# Copied: Cruisebit.txt
# Copied: Crypterium.txt
# Copied: Chronobank.txt
# Copied: CEEK VR.txt
# Copied: Cosmos.txt
# Copied: Condominium.txt
# Copied: COSS.txt
# Copied: CampusCoin.txt
# Copied: ContentBox.txt
# Copied: Cryptaur.txt
# Copied: Cindicator.txt
# Copied: CRYPTO20.txt
# Copied: Crypto.com.txt
# Copied: CompoundEthereum.txt
# Copied: Cardano.txt
# Copied: Cazcoin.txt
# Copied: Ccore.txt
# Copied: CoinMetro.txt
# Copied: CYCLEAN.txt
# Copied: cryptopay.txt
# Copied: CYBR Token.txt
# Copied: Curriculum Vitae.txt
# Copied: Cutcoin.txt
# Copied: CrypViser.txt
# Copied: CryptoNote Coin.txt
# Copied: Cybermiles.txt
# Copied: Custody Token.txt
# Copied: CryptoPing.txt
# Copied: CyberVein.txt
# Copied: Currency Analytics.txt
# Copied: CryptoFranc.txt
# Copied: aave-v2-whitepaper_extracted.txt
# Copied: www.investopedia.com_cleaned.txt
# Copied: 10-1108_978-1-80455-320-620221017_processed.txt
# Copied: www.sanctions.io_cleaned.txt
# Copied: Achain Whitepaper 2.0_EN_extracted.txt
# Copied: AeronWhitepaper_extracted.txt
# Copied: dascp_processed.txt
# Copied: ssrn-4414080_processed.txt
# Copied: Operational Due Diligence on crypto_processed.txt
# Copied: The Influence of Cryptocurrency on International_processed.txt
# Copied: Aditus-Whitepaper_extracted.txt
# Copied: SSRN-id4594467.txt
# Copied: blogs.cisco.com_cleaned.txt
# Copied: information-14-00171_processed.txt
# Copied: cryptoinvestigators.com_cleaned.txt
# Copied: 1110830.1.0 Introduction to Digital Assets for Institutional Investors_FINAL_0.txt
# Copied: What are the legal rights and obligations of token holders__processed.txt
# Copied: WEF_Digital_Assets_Regulation_2024_cleaned.txt
# Copied: vetting_guide_raw.txt
# Copied: whitepaper_v_2.01_eng_extracted.txt
# Copied: www.scorechain.com_cleaned.txt
# Copied: crypto.com_cleaned.txt
# Copied: aelf_whitepaper_v1.2_extracted.txt
# Copied: 24+Noel+B.+Agustin+et+al.,+pp.+269-281_processed.txt
# Copied: AdEx-Whitepaper-v.7_extracted.txt
# Copied: ey-token-due-diligence-a-structured-approach-to-evaluate-digital-asset-risk (1).txt
# Copied: 108364 PLE_Digital Assets_Deck 290724.txt
# Copied: www.centrl.ai_cleaned.txt
# Copied: steemit.com_cleaned.txt
# Copied: Aave_Protocol_Whitepaper_v1_0_extracted.txt
# Copied: www.ftitechnology.com_cleaned.txt
# Copied: Cryptocurrency and Macro-Economic Stability_processed.txt
# Copied: www.integrityriskintl.com_cleaned.txt
# Copied: cravath_raw.txt
# Copied: Complexity - 2022 - Chen - Cryptocurrency Financial Risk Analysis Based on Deep Machine Learning_processed.txt
# Copied: white-paper_extracted.txt
# Copied: us-crypto-regulatory-whitepaper_cleaned.txt
# Copied: bitaml.com_cleaned.txt
# Copied: cravath_processed.txt
# Copied: document-1_processed.txt
# Copied: dascp_raw.txt
# Copied: vetting_guide_processed.txt
# Copied: Cryptocurrency Returns_processed.txt
# Copied: ssrn-3305362_processed.txt
# Copied: theholycoins.com_cleaned.txt
# Copied: Wirex Token.txt
# Copied: VeriBlock.txt
# Copied: ValueChain.txt
# Copied: WPP TOKEN.txt
# Copied: Wink.txt
# Copied: VITE.txt
# Copied: Volume Network.txt
# Copied: Voise.txt
# Copied: Worldcore.txt
# Copied: vSportCoin.txt
# Copied: VouchForMe.txt
# Copied: Wings.txt
# Copied: WePower.txt
# Copied: Vipstar Coin.txt
# Copied: Vanta Network.txt
# Copied: Waves.txt
# Copied: Waltonchain.txt
# Copied: WaykiChain.txt
# Copied: Welltrado.txt
# Copied: Verge.txt
# Copied: WaBi.txt
# Copied: Xaurum.txt
# Copied: Versess.txt
# Copied: VikkyToken.txt
# Copied: Viberate.txt
# Copied: VisionX.txt
# Copied: Vitae.txt
# Copied: Vezt.txt
# Copied: vTorrent.txt
# Copied: WINCOIN.txt
# Copied: Whole Network.txt
# Copied: WITChain.txt
# Copied: VIBE.txt
# Copied: xCrypt.txt
# Copied: WazirX.txt
# Copied: Vega Protocol.txt
# Copied: wetoken.txt
# Copied: Wrapped Bitcoin.txt
# Copied: X12 Coin.txt
# Copied: White Standard.txt
# Copied: VNT Chain.txt
# Copied: WAX.txt
# Copied: Viacoin.txt
# Copied: Vetri.txt
# Copied: Verasity.txt
# Copied: Vechain.txt
# Copied: WhaleCoin.txt
# Copied: Woodcoin.txt
# Copied: WinToken.txt
# Copied: Velas.txt
# Copied: VINchain.txt
# Copied: WHEN Token.txt
# Copied: Vites.txt
# Copied: Vexanium.txt
# Copied: wys Token.txt
# Copied: WABnetwork.txt
# Copied: Xenoverse.txt
# Copied: Wowoo.txt
# Copied: X8X Token.txt
# Copied: vestchain.txt
# Copied: Webcoin.txt
# Copied: XinFin Network.txt
# Copied: WeTrust.txt
# Copied: V Systems.txt
# Copied: Viuly.txt
# Copied: Viewly.txt
# Copied: W Green Pay.txt
# Copied: Wavesbet.txt
# Copied: Wanchain.txt
# Copied: WebDollar.txt
# Copied: wagerr.txt
# Copied: VideoCoin.txt
# Copied: Wild Crypto.txt
# Copied: XPA.txt
# Copied: x42.txt
# Copied: VoteCoin.txt
# Copied: XRT token.txt
# Copied: Zebi.txt
# Copied: Zap.txt
# Copied: Zen Protocol.txt
# Copied: YOYOW.txt
# Copied: ZrCoin.txt
# Copied: Zilla.txt
# Copied: YENTEN.txt
# Copied: YUKI.txt
# Copied: ZeuxCoin.txt
# Copied: Yuan Chain Coin.txt
# Copied: Zephyr.txt
# Copied: ZenCash.txt
# Copied: Zilliqa.txt
# Copied: Yggdrash.txt
# Copied: Xriba.txt
# Copied: YEE.txt
# Copied: Zcoin.txt
# Copied: YottaChain.txt
# Copied: YOUChain.txt
# Copied: Zealium.txt
# Copied: ZeusCrowdfunding.txt
# Copied: Zcash.txt
# Copied: XYO Network.txt
# Copied: XTRD.txt
# Copied: ZENZO.txt
# Copied: ZEON.txt
# Copied: Yap Stone.txt
# Copied: zvChain.txt
# Copied: ZMINE.txt
# Copied: Zeepin.txt
# Copied: Zeusshield.txt
# Copied: XTRABYTES.txt
# Copied: ZCore.txt
# Copied: Zipper.txt
# Copied: Target Coin.txt
# Copied: TaaS.txt
# Copied: tagz.txt
# Copied: Taklimakan Network.txt
# Copied: Tap.txt
# Copied: Tarush.txt
# Copied: Tao.txt
# Copied: True Chain.txt
# Copied: Trittium.txt
# Copied: Typerium.txt
# Copied: TCOIN.txt
# Copied: Upfiring.txt
# Copied: Timicoin.txt
# Copied: Twinkle.txt
# Copied: TenX.txt
# Copied: Ties.DB.txt
# Copied: United Traders Token.txt
# Copied: Trinity.txt
# Copied: TimeBox.txt
# Copied: Travelflex.txt
# Copied: TrezarCoin.txt
# Copied: The WoT.City original.txt
# Copied: Unikoin Gold.txt
# Copied: Tigereum.txt
# Copied: USD Coin.txt
# Copied: Universa.txt
# Copied: Tripio.txt
# Copied: Tokenbox.txt
# Copied: Telcoin.txt
# Copied: Terra.txt
# Copied: Themis.txt
# Copied: Tokenstars.txt
# Copied: Uquid Coin.txt
# Copied: TV.txt
# Copied: TimeMoney.txt
# Copied: Tether.txt
# Copied: Traxia.txt
# Copied: U Network.txt
# Copied: Treelion.txt
# Copied: Tether Gold.txt
# Copied: TRON.txt
# Copied: Uos.txt
# Copied: Thrive Token.txt
# Copied: UltraNote Coin.txt
# Copied: turbinator.cpython-37m-x86_64-linux-gnu.so
# Copied: Tokia.txt
# Copied: Transcodium.txt
# Copied: TopChain.txt
# Copied: TrustVerse.txt
# Copied: UTRUST.txt
# Copied: Tezos.txt
# Copied: Tratok.txt
# Copied: travala.txt
# Copied: Tracto.txt
# Copied: Time New Bank.txt
# Copied: TWIST.txt
# Copied: Ubcoin Market.txt
# Copied: Unification.txt
# Copied: TokenPay.txt
# Copied: Theta.txt
# Copied: The tokenized hardware.txt
# Copied: Ticko.txt
# Copied: TrueFeedBack.txt
# Copied: ugChain.txt
# Copied: Truegame.txt
# Copied: THEKEY.txt
# Copied: Traceability Chain.txt
# Copied: Uptrennd.txt
# Copied: TomoChain.txt
# Copied: TE FOOD.txt
# Copied: TTC Protocol.txt
# Copied: UnlimitedIP.txt
# Copied: UltrAlpha.txt
# Copied: TeslaCoilCoin.txt
# Copied: Ultiledger.txt
# Copied: Ubricoin.txt
# Copied: TaTaTu.txt
# Copied: True USD.txt
# Copied: ThunderCore.txt
# Copied: Tokenomy.txt
# Copied: Unibright.txt
# Copied: Tokugawa.txt
# Copied: Turtlecoin.txt
# Copied: Ultrain.txt
# Copied: Usechain Token.txt
# Copied: TrakInvest.txt
# Copied: TrueFlip.txt
# Copied: Tera.txt
# Copied: USC.txt
# Copied: Thar Token.txt
# Copied: Tierion.txt
# Copied: Ultra.txt
# Copied: TokenCard.txt
# Copied: Telos.txt
# Copied: Titanium Blockchain.txt
# Copied: Uranus.txt
# Copied: Traid.txt
# Copied: Titan Coin.txt
# Copied: RefToken.txt
# Copied: QASH.txt
# Copied: RECORD.txt
# Copied: Qbao.txt
# Copied: Qiibee.txt
# Copied: RealTract.txt
# Copied: Red Pulse.txt
# Copied: REDFOXLABS.txt
# Copied: Qvolta.txt
# Copied: Refereum.txt
# Copied: Radium.txt
# Copied: Quantum Resistance Ledger.txt
# Copied: regalcoin.txt
# Copied: Rchain.txt
# Copied: Rally.txt
# Copied: Ren.txt
# Copied: QuarkChain.txt
# Copied: Quinads.txt
# Copied: Raiden Network.txt
# Copied: qchi.txt
# Copied: RealityClash.txt
# Copied: QuasarCoin.txt
# Copied: REBL.txt
# Copied: Quant.txt
# Copied: Quantstamp.txt
# Copied: Ravencoin.txt
# Copied: Rate3.txt
# Copied: Reddcoin.txt
# Copied: Rankingball Gold.txt
# Copied: RealChain.txt
# Copied: QunQun.txt
# Copied: Rentberry.txt
# Copied: Qtum.txt
# Copied: Ragnarok.txt
# Copied: Remme.txt
# Copied: Real Estate Investment Token.txt
# Copied: QuadrantProtocol.txt
# Copied: RED.txt
# Copied: Quanta Utility Token.txt
# Copied: Qbic.txt
# Copied: QLCchain.txt
# Copied: Shadow Token.txt
# Copied: SCRIV NETWORK.txt
# Copied: Storm.txt
# Copied: Shift.txt
# Copied: SpaceChain.txt
# Copied: Sociall.txt
# Copied: Simone Coin.txt
# Copied: Super Zero.txt
# Copied: SwftCoin.txt
# Copied: Sharechain.txt
# Copied: Stellar Gold.txt
# Copied: StakeNet.txt
# Copied: Shivers.txt
# Copied: Sp8de.txt
# Copied: SKYFchain.txt
# Copied: SIBCoin.txt
# Copied: StarterCoin.txt
# Copied: SealChain.txt
# Copied: SnipCoin.txt
# Copied: SunContract.txt
# Copied: SteepCoin.txt
# Copied: Safein.txt
# Copied: Sakura Bloom.txt
# Copied: selfkey en.txt
# Copied: SureRemit.txt
# Copied: Ripple.txt
# Copied: Stellite.txt
# Copied: Skychain.txt
# Copied: SRCoin.txt
# Copied: Repme.txt
# Copied: Stox.txt
# Copied: suqa.txt
# Copied: SoMee.Social.txt
# Copied: Spectiv.txt
# Copied: subx.txt
# Copied: SwissBorg.txt
# Copied: SmartsFox.txt
# Copied: Ripio Credit Network.txt
# Copied: Storj.txt
# Copied: Reserve Stabilization Protocol.txt
# Copied: Salt Lending.txt
# Copied: Sessia.txt
# Copied: SpreadCoin.txt
# Copied: STASIS.txt
# Copied: Soverain.txt
# Copied: Smartup.txt
# Copied: Silent Notary.txt
# Copied: STPT.txt
# Copied: Stellar.txt
# Copied: Substratum.txt
# Copied: SDChain.txt
# Copied: Request Network.txt
# Copied: Rocket Pool.txt
# Copied: Status.txt
# Copied: SophiaTX.txt
# Copied: SpankChain.txt
# Copied: Rento.txt
# Copied: Safe Haven.txt
# Copied: Rotharium.txt
# Copied: Sense.txt
# Copied: Sparkster.txt
# Copied: Republic Protocol.txt
# Copied: Steem.txt
# Copied: Rivetz.txt
# Copied: SagaCoin.txt
# Copied: Shard.txt
# Copied: Storeum.txt
# Copied: ROIyal Coin.txt
# Copied: Smart Bitcoin.txt
# Copied: Suretly.txt
# Copied: Storiqa.txt
# Copied: Staker.txt
# Copied: SaluS.txt
# Copied: Safecoin.txt
# Copied: Sentinel Protocol.txt
# Copied: Stratis.txt
# Copied: Sweetbridge.txt
# Copied: REPO.txt
# Copied: Signatum.txt
# Copied: Stem Cell Coin.txt
# Copied: Restart Energy MWAT.txt
# Copied: Russian Miner Coin.txt
# Copied: SpaceCoin.txt
# Copied: Ryo Currency.txt
# Copied: Sola Token.txt
# Copied: Sharpay.txt
# Copied: Stellar Classic.txt
# Copied: StableUSD.txt
# Copied: SHPING.txt
# Copied: Shivom.txt
# Copied: STK.txt
# Copied: Sphere.txt
# Copied: SingularityNET.txt
# Copied: RightMesh.txt
# Copied: savedroid.txt
# Copied: Sharpe Platform Token.txt
# Copied: SMART VALOR.txt
# Copied: Six Domain Chain.txt
# Copied: ShowHand.txt
# Copied: Seele.txt
# Copied: streamr.txt
# Copied: Safeguard.txt
# Copied: SelfSell.txt
# Copied: Swipe.txt
# Copied: SPIN Protocol.txt
# Copied: Swarm.txt
# Copied: SIRIN LABS.txt
# Copied: Skycoin.txt
# Copied: SOOM.txt
# Copied: SwiftCash.txt
# Copied: SGPay.txt
# Copied: Signals Network.txt
# Copied: SEER.txt
# Copied: Sentinel.txt
# Copied: Sugar Exchange.txt
# Copied: Rif Token.txt
# Copied: SF Capital.txt
# Copied: Rupiah Token.txt
# Copied: Super Game Chain.txt
# Copied: SmartCash.txt
# Copied: SafeInsure.txt
# Copied: SoPay.txt
# Copied: Siacoin.txt
# Copied: SnowGem.txt
# Copied: Simmitri.txt
# Copied: Silverway Token.txt
# Copied: SmartMesh.txt
# Copied: ShipChain.txt
# Copied: Swace.txt
# Copied: S4FE.txt
# Copied: Solve Care.txt
# Copied: Sport and Leisure.txt
# Copied: StockChain.txt
#
# Successfully copied 1428 files to data/cleaned_texts
# Target directory now has 1428 files

# %% [markdown]
# **Finance Utility Class**

# %%
class FinanceUtility:
    """Utility functions for financial and cryptocurrency text processing"""

    FINANCE_TERMS = {
        "cryptocurrency": [
            "crypto", "bitcoin", "ethereum", "blockchain", "token", "coin", "altcoin",
            "defi", "mining", "wallet", "exchange", "nft", "smart contract", "node", "hash"
        ],
        "compliance": [
            "kyc", "aml", "know your customer", "anti-money laundering", "cft",
            "regulations", "regtech", "audit", "sanctions", "pep", "fincen", "ofac"
        ],
        "due_diligence": [
            "dd", "edd", "cdd", "risk assessment", "screening", "onboarding", "identity verification"
        ],
        "risk_analysis": [
            "risk", "fraud", "vulnerability", "score", "exposure", "mitigation", "sar", "suspicious activity"
        ],
        "transactions": [
            "payment", "transfer", "transaction", "wire", "p2p", "volume", "liquidity", "custody"
        ],
        "financial_crime": [
            "money laundering", "terrorism financing", "phishing", "darknet", "tumbler", "illicit", "sanction evasion"
        ]
    }

    @classmethod
    def get_domain_specific_terms(cls):
        """Flatten terms across all categories"""
        terms = []
        for group in cls.FINANCE_TERMS.values():
            terms.extend(group)
        return terms

    @classmethod
    def is_relevant_chunk(cls, chunk_text, min_terms=2):
        """Determine if a text chunk contains at least `min_terms` finance-domain words"""
        terms = cls.get_domain_specific_terms()
        return sum(1 for term in terms if term.lower() in chunk_text.lower()) >= min_terms

    @classmethod
    def enhance_query(cls, query):
        """Append additional related terms based on original query"""
        query = query.lower()
        extras = []

        for category, terms in cls.FINANCE_TERMS.items():
            for term in terms:
                if term in query:
                    related = [t for t in terms if t != term][:3]
                    extras.extend(related)

        if extras:
            return f"{query} {' '.join(extras[:5])}"
        return query

# %% [markdown]
# **Entity Extraction Module**

# %%
import spacy
from spacy.matcher import PhraseMatcher
import re
from typing import List, Dict, Tuple, Set
from collections import defaultdict

class EntityExtractor:
    """Extract named entities and other features from financial texts"""

    # Load NLP model
    nlp = spacy.load("en_core_web_lg")
    nlp.add_pipe("sentencizer")

    # Define entity configurations
    KNOWN_ENTITIES = {
        "crypto_projects": [
            "Bitcoin", "Ethereum", "Solana", "Ripple", "Cardano", "Binance",
            "Uniswap", "Compound", "Aave", "MakerDAO", "Chainlink", "Polygon",
            "Avalanche", "Tezos", "Polkadot", "Algorand", "Stellar", "Cosmos"
        ],
        "crypto_terms": [
            "blockchain", "cryptocurrency", "token", "protocol", "mining", "staking",
            "defi", "dao", "consensus", "wallet", "exchange", "yield", "liquidity"
        ],
        "organizations": [
            "Circle", "Coinbase", "Kraken", "FTX", "Binance", "Chainalysis", "Fireblocks",
            "BlockFi", "BitGo", "Gemini", "ConsenSys", "Tether", "CoinMarketCap"
        ],
        "locations": [
            "United States", "China", "Russia", "European Union", "Singapore", "Switzerland",
            "Malta", "Dubai", "Hong Kong", "Japan", "South Korea", "Cayman Islands"
        ],
        "risk_terms": {
            "regulatory": [
                "compliance violation", "unregistered", "non-compliant", "illegal", "banned",
                "unlicensed", "regulatory", "oversight", "fine", "penalty", "investigation"
            ],
            "technical": [
                "hack", "breach", "exploit", "vulnerability", "backdoor", "exposure",
                "bug", "malware", "phishing", "stolen keys", "51% attack"
            ],
            "financial": [
                "bankruptcy", "insolvency", "liquidity crisis", "bank run", "rugpull",
                "collapse", "fraud", "ponzi", "scam", "unsustainable", "hyperinflation"
            ],
            "operational": [
                "downtime", "outage", "suspended", "locked", "frozen assets",
                "withdrawal issues", "technical difficulties", "service disruption"
            ]
        }
    }

    BLACKLISTS = {
        "person_blacklist": ["administrator", "user", "customer", "client", "founder", "ceo"],
        "person_suffixes": ["corp", "inc", "llc", "ltd", "foundation", "group", "team"],
        "org_blacklist": ["the", "and", "that", "this", "these", "those"],
        "org_suffixes": ["ing", "ed", "ly", "day", "time", "year"],
        "org_prefixes": ["mr", "mrs", "ms", "dr", "prof"],
        "crypto_blacklist": ["the", "blockchain", "a", "an", "crypto", "mining"],
        "crypto_suffixes": ["ing", "ed", "s", "ly"]
    }

    # Patterns
    EMAIL_PATTERN = r"\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b"
    CRYPTO_ADDRESS_PATTERN = r"\b(0x)?[0-9a-fA-F]{40}\b"
    PHONE_PATTERN = r"\(?\d{3}\)?[-.\s]?\d{3}[-.\s]?\d{4}"

    def __init__(self):
        """Initialize entity extraction with phrase matchers"""
        self.matchers = self._setup_matchers()

    def _setup_matchers(self) -> Dict[str, PhraseMatcher]:
        """Create phrase matchers for known entities"""
        matchers = {}

        # Crypto project matcher
        crypto_matcher = PhraseMatcher(self.nlp.vocab)
        patterns = [self.nlp(text) for text in self.KNOWN_ENTITIES["crypto_projects"]]
        crypto_matcher.add("CRYPTO_PROJECT", patterns)
        matchers["crypto"] = crypto_matcher

        # Organization matcher
        org_matcher = PhraseMatcher(self.nlp.vocab)
        patterns = [self.nlp(text) for text in self.KNOWN_ENTITIES["organizations"]]
        org_matcher.add("ORG", patterns)
        matchers["org"] = org_matcher

        return matchers

    def is_valid_person(self, text: str) -> bool:
        """Validate person names with strict rules"""
        text_lower = text.lower()

        # Must have at least 2 words, proper capitalization, no numbers
        conditions = [
            len(text.split()) >= 2,
            text.istitle(),
            not any(c.isdigit() for c in text),
            not any(term in text_lower for term in self.BLACKLISTS["person_blacklist"]),
            not any(text_lower.endswith(suffix) for suffix in self.BLACKLISTS["person_suffixes"])
        ]

        return all(conditions)

    def is_valid_org(self, text: str) -> bool:
        """Validate organization names"""
        text_lower = text.lower()

        conditions = [
            3 <= len(text) <= 50,
            text[0].isupper(),
            not any(b in text_lower for b in self.BLACKLISTS["org_blacklist"]),
            not any(text_lower.endswith(suffix) for suffix in self.BLACKLISTS["org_suffixes"]),
            not any(text_lower.startswith(prefix) for prefix in self.BLACKLISTS["org_prefixes"])
        ]

        return all(conditions)

    def is_valid_crypto_project(self, text: str) -> bool:
        """Validate cryptocurrency projects"""
        text_lower = text.lower()

        # Check against known projects first
        if any(proj.lower() == text_lower for proj in self.KNOWN_ENTITIES["crypto_projects"]):
            return True

        # Generic project validation
        conditions = [
            2 <= len(text.split()) <= 4,
            not any(b in text_lower for b in self.BLACKLISTS["crypto_blacklist"]),
            not any(text_lower.endswith(suffix) for suffix in self.BLACKLISTS["crypto_suffixes"])
        ]

        # Must contain at least one known crypto term
        conditions.append(
            any(term in text_lower for term in self.KNOWN_ENTITIES["crypto_terms"])
        )

        return all(conditions)

    def is_valid_location(self, text: str) -> bool:
        """Validate locations against known list"""
        return text.lower() in {loc.lower() for loc in self.KNOWN_ENTITIES["locations"]}

    def normalize_entity(self, entity_type: str, text: str) -> str:
        """Standardize entity formatting"""
        # Apply type-specific normalization
        if entity_type == "person":
            # Standardize name formatting (Title Case)
            return " ".join(word.capitalize() for word in text.split())

        elif entity_type in ["crypto_project", "organization"]:
            # Remove common suffixes and standardize casing
            text = re.sub(r'\b(LLC|Inc|Ltd|Foundation|Labs|DAO|DeFi|Network|Protocol)\b', '', text, flags=re.IGNORECASE)
            return text.strip()

        return text

    def post_process_entities(self, entities: Dict[str, Set[str]]) -> Dict[str, List[str]]:
        """Clean and deduplicate extracted entities"""
        processed = {}

        for entity_type, entity_set in entities.items():
            # Normalize each entity
            normalized = {self.normalize_entity(entity_type, e) for e in entity_set}

            # Remove subsumed entities (shorter versions of longer entities)
            final_entities = set()
            for entity in sorted(normalized, key=len, reverse=True):
                if not any(e != entity and entity.lower() in e.lower() for e in final_entities):
                    if entity:  # Skip empty strings
                        final_entities.add(entity)

            processed[entity_type] = sorted(final_entities)

        return processed

    def extract_named_entities(self, text: str) -> Dict[str, List[str]]:
        """Comprehensive entity extraction pipeline"""
        doc = self.nlp(text)
        entities = defaultdict(set)

        # Stage 1: spaCy NER extraction with strict validation
        for ent in doc.ents:
            clean_text = ' '.join(ent.text.strip().split())

            if ent.label_ == "PERSON" and self.is_valid_person(clean_text):
                entities["person"].add(clean_text)

            elif ent.label_ == "ORG":
                if self.is_valid_crypto_project(clean_text):
                    entities["crypto_project"].add(clean_text)
                elif self.is_valid_org(clean_text):
                    entities["organization"].add(clean_text)

            elif ent.label_ == "GPE" and self.is_valid_location(clean_text):
                entities["location"].add(clean_text)

        # Stage 2: Phrase matching for known entities
        for match_id, start, end in self.matchers["crypto"](doc):
            entities["crypto_project"].add(doc[start:end].text)

        for match_id, start, end in self.matchers["org"](doc):
            entities["organization"].add(doc[start:end].text)

        # Stage 3: Pattern-based extraction
        entities["email"] = set(re.findall(self.EMAIL_PATTERN, text))
        entities["crypto_address"] = set(re.findall(self.CRYPTO_ADDRESS_PATTERN, text))

        # Stage 4: Post-processing
        processed_entities = self.post_process_entities(entities)

        return processed_entities

    def extract_risk_features(self, text: str) -> Tuple[Dict[str, List[str]], float]:
        """Enhanced risk term extraction"""
        risk_categories = {
            "regulatory": self.KNOWN_ENTITIES["risk_terms"]["regulatory"],
            "technical": self.KNOWN_ENTITIES["risk_terms"]["technical"],
            "financial": self.KNOWN_ENTITIES["risk_terms"]["financial"],
            "operational": self.KNOWN_ENTITIES["risk_terms"]["operational"]
        }

        found = {k: set() for k in risk_categories}
        doc = self.nlp(text.lower())

        for category, terms in risk_categories.items():
            for term in terms:
                if term.lower() in doc.text:
                    found[category].add(term)

        # Calculate weighted risk score
        weights = {"regulatory": 1.2, "technical": 1.1, "financial": 1.0, "operational": 0.9}
        score = min(sum(len(v) * 10 * weights[k] for k, v in found.items()), 100)

        return {k: sorted(v) for k, v in found.items()}, round(score, 2)

# %% [markdown]
# **Smart Chunker Class**

# %%
import os
import glob
import re
import hashlib
import json
from pathlib import Path
from typing import List, Dict, Union, Any
from langchain.text_splitter import RecursiveCharacterTextSplitter

class SmartChunker:
    """Advanced document processing with domain-specific chunking and search capabilities"""

    def __init__(self, chunk_size=1000, chunk_overlap=200, data_dir="faiss_index"):
        """Initialize chunker with optional configs"""
        self.splitter = RecursiveCharacterTextSplitter(
            chunk_size=chunk_size,
            chunk_overlap=chunk_overlap,
            separators=["\n\n", "\n", ". ", " ", ""]
        )
        self.data_dir = data_dir
        self.entity_extractor = EntityExtractor()
        self.utility = FinanceUtility()
        self.vectordb = None
        self.embeddings = None

    def preprocess_text(self, text: str) -> str:
        """Cleans up raw text before chunking."""
        text = re.sub(r'\s+', ' ', text)
        text = re.sub(r'\b\d+\s*\|\s*[pP]age\b', '', text)
        text = re.sub(r'\[\d+\]', '', text)
        return text.replace('•', '* ').strip()

    def chunk_text(self, text: str, metadata: Dict[str, str] = None) -> List[Dict[str, Union[str, Dict]]]:
        """Splits and filters text into meaningful domain-specific chunks with entity extraction."""
        chunks = self.splitter.split_text(text)
        relevant_chunks = []

        for i, chunk in enumerate(chunks):
            if self.utility.is_relevant_chunk(chunk):
                # Extract entities and risk features
                extracted_entities = self.entity_extractor.extract_named_entities(chunk)
                risk_features, risk_score = self.entity_extractor.extract_risk_features(chunk)

                # Combine metadata
                chunk_metadata = {
                    "chunk_id": hashlib.md5(chunk.encode()).hexdigest(),
                    "entities": extracted_entities,
                    "risk_features": risk_features,
                    "risk_score": risk_score,
                    **(metadata or {})
                }

                relevant_chunks.append({
                    "text": f"[Section {i+1}] {chunk}",
                    "metadata": chunk_metadata
                })

        print(f"✅ Kept {len(relevant_chunks)} relevant chunks from {len(chunks)} total.")
        return relevant_chunks

    def save_chunks_to_json(self, chunks, output_path, drive_output_folder="/content/drive/MyDrive/chunks"):
        """Saves chunks to both local and drive directories."""
        # Ensure the local directory exists
        Path(output_path).parent.mkdir(parents=True, exist_ok=True)
        # Save to local path
        with open(output_path, "w", encoding="utf-8") as f:
            json.dump(chunks, f, indent=2, ensure_ascii=False)
        print(f"📦 Saved chunks to {output_path}")

        # Ensure the drive directory exists
        drive_folder = Path(drive_output_folder)
        drive_folder.mkdir(parents=True, exist_ok=True)  # Make sure the folder exists

        # Save to Google Drive path
        drive_path = os.path.join(drive_output_folder, os.path.basename(output_path))
        with open(drive_path, "w", encoding="utf-8") as f:
            json.dump(chunks, f, indent=2, ensure_ascii=False)
        print(f"📦 Saved chunks to {drive_path}")

    def load_chunks_from_json(self, input_path):
        """Loads previously saved chunks."""
        with open(input_path, "r", encoding="utf-8") as f:
            return json.load(f)

    def load_cleaned_texts(self, folder="data/cleaned_texts") -> Dict[str, str]:
        """Loads all .txt files from a folder."""
        texts = {}
        for file_path in glob.glob(os.path.join(folder, "*.txt")):
            try:
                with open(file_path, "r", encoding="utf-8") as f:
                    texts[os.path.basename(file_path)] = f.read()
            except UnicodeDecodeError:
                # Try with different encoding if UTF-8 fails
                with open(file_path, "r", encoding="latin-1") as f:
                    texts[os.path.basename(file_path)] = f.read()
        return texts

    def process_all_texts(self, input_folder="data/cleaned_texts", output_folder="chunks"):
        """Process all texts in a folder and save chunks"""
        print(f"Looking for text files in: {input_folder}")
        texts = self.load_cleaned_texts(input_folder)

        if not texts:
            print(f"⚠️ No text files found in {input_folder}. Please check the path and file extensions.")
            return 0

        print(f"Found {len(texts)} text files to process")
        Path(output_folder).mkdir(parents=True, exist_ok=True)

        for filename, content in texts.items():
            print(f"\n📄 Processing {filename} (content length: {len(content)})")
            cleaned = self.preprocess_text(content)
            chunks = self.chunk_text(cleaned, metadata={"source": filename})
            self.save_chunks_to_json(chunks, f"{output_folder}/{filename.replace('.txt', '_chunks.json')}")

        print(f"\n✅ Completed processing {len(texts)} files")
        return len(texts)

# %% [markdown]
# **Vector Store and Embeddings**

# %%
from langchain.vectorstores import FAISS
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain.schema import Document

def load_chunks_from_folder(folder: str) -> List[Document]:
    """Load all chunks from JSON files in a folder and convert to LangChain Documents"""
    documents = []
    folder_path = Path(folder)

    for json_file in folder_path.glob("*_chunks.json"):
        with open(json_file, "r", encoding="utf-8") as f:
            chunks = json.load(f)
            for chunk in chunks:
                documents.append(
                    Document(
                        page_content=chunk["text"],
                        metadata=chunk["metadata"]
                    )
                )
        print(f"✅ Loaded {len(chunks)} chunks from {json_file.name}")
    return documents

# Add vector store methods to SmartChunker class
def add_vector_store_methods(SmartChunker):
    def _init_embeddings(self):
        """Initialize embeddings model if not already done"""
        if self.embeddings is None:
            print("🔍 Initializing embeddings model...")
            self.embeddings = HuggingFaceEmbeddings(
                model_name="sentence-transformers/all-mpnet-base-v2",
                model_kwargs={'device': 'cpu'}  # Use GPU if available by changing to 'cuda'
            )

    def create_vectorstore(self, chunks_folder="chunks", save_path=None):
        """Create FAISS vectorstore from processed chunks"""
        save_path = save_path or self.data_dir
        documents = load_chunks_from_folder(chunks_folder)

        if not documents:
            raise ValueError(f"No documents found in {chunks_folder}. Please process texts first.")

        # Initialize embeddings
        self._init_embeddings()

        print(f"🔍 Creating vectorstore with {len(documents)} documents...")
        self.vectordb = FAISS.from_documents(documents, self.embeddings)

        # Save FAISS index
        os.makedirs(save_path, exist_ok=True)
        self.vectordb.save_local(save_path)
        print(f"✅ FAISS index saved to '{save_path}/'")

        # Save metadata as JSON
        metadata_path = os.path.join(save_path, "index_metadata.json")
        with open(metadata_path, "w", encoding="utf-8") as f:
            json.dump([doc.metadata for doc in documents], f, indent=2, ensure_ascii=False)
        print(f"✅ Metadata saved to '{metadata_path}' (JSON)")

        return len(documents)

    def load_index(self, path=None):
        """Load existing FAISS index"""
        path = path or self.data_dir

        if not os.path.exists(path):
            raise FileNotFoundError(f"Index directory '{path}' not found.")

        # Initialize embeddings
        self._init_embeddings()

        print(f"📂 Loading FAISS index from {path}...")
        self.vectordb = FAISS.load_local(path, self.embeddings)

        # Load metadata
        metadata_path = os.path.join(path, "index_metadata.json")
        if os.path.exists(metadata_path):
            with open(metadata_path, "r", encoding="utf-8") as f:
                metadata = json.load(f)
                print(f"✅ Loaded metadata for {len(metadata)} documents")
        else:
            print("⚠️ No metadata file found.")

        return self.vectordb is not None

    def search(self, query: str, k: int = 3, enhance_query: bool = True) -> List[Dict]:
        """Search the vectorstore with an enhanced query"""
        if not self.vectordb:
            raise ValueError("No vectorstore loaded. Call load_index() first.")

        # Enhance query with domain terms if enabled
        if enhance_query:
            enhanced = self.utility.enhance_query(query)
            print(f"Enhanced query: '{enhanced}'")
            query = enhanced

        # Perform search
        results = self.vectordb.similarity_search_with_score(query, k=k)

        # Format results
        formatted_results = []
        for doc, score in results:
            result = {
                "text": doc.page_content,
                "score": 1.0 - score,  # Convert distance to similarity score
                "file_name": doc.metadata.get("source", "Unknown"),
                "entities": doc.metadata.get("entities", {}),
                "risk_score": doc.metadata.get("risk_score", 0)
            }
            formatted_results.append(result)

        return formatted_results

    # Add methods to class
    SmartChunker._init_embeddings = _init_embeddings
    SmartChunker.create_vectorstore = create_vectorstore
    SmartChunker.load_index = load_index
    SmartChunker.search = search

    return SmartChunker

# Extend SmartChunker with vector store methods
SmartChunker = add_vector_store_methods(SmartChunker)

# %% [markdown]
# **Processing Pipeline**

# %% [markdown]
# **Cell 1: Text Processing and Chunking**

# %%
def process_texts_to_chunks(input_folder="data/cleaned_texts",
                           chunks_folder="chunks"):
    """Process text files into chunks and save to JSON"""
    print("🚀 Starting document chunking pipeline...")

    # Create directories
    for folder in [input_folder, chunks_folder]:
        os.makedirs(folder, exist_ok=True)

    # Initialize chunker
    chunker = SmartChunker()

    # Process texts
    print(f"\n📑 Processing texts from {input_folder}...")
    num_processed = chunker.process_all_texts(input_folder, chunks_folder)
    print(f"✅ Processed {num_processed} document(s) into chunks")

    return chunker

# Test with a small text file
with open("data/cleaned_texts/sample.txt", "w") as f:
    f.write("""
    Cryptocurrency compliance has become a major concern for blockchain projects. Bitcoin and Ethereum transactions require proper KYC and AML procedures.
    Financial institutions partnering with crypto exchanges need to implement risk assessment protocols to prevent money laundering.
    Blockchain technology enables transparency but also presents unique regulatory challenges.
    Many DeFi protocols operate in regulatory gray areas which increases their risk profile.
    """)

# Run the chunking pipeline
chunker = process_texts_to_chunks()

# %% [markdown]
# This cell imports tge chunks from the directory chunks save in the drive ("use thsi if you did not run the cell Text Processing and Chunking")

# %%
import os
import shutil
from pathlib import Path

def sync_chunks_from_drive():
    """
    Copy all files from the 'chunks' folder in Google Drive to the local 'chunks' folder.
    Creates required directories if they don't exist.
    """
    # Define source and target directories
    source_dir = "/content/drive/MyDrive/chunks"
    target_dir = "chunks"

    # Create the target directory if it doesn't exist
    os.makedirs(target_dir, exist_ok=True)

    # Check if source directory exists
    if not os.path.exists(source_dir):
        print(f"Source directory {source_dir} does not exist. Please check the path.")
        return False

    # Get list of files in source directory
    try:
        files = os.listdir(source_dir)
        print(f"Found {len(files)} files in {source_dir}")
    except Exception as e:
        print(f"Error accessing source directory: {e}")
        return False

    # Copy each file to the target directory
    copied_count = 0
    for filename in files:
        source_path = os.path.join(source_dir, filename)
        target_path = os.path.join(target_dir, filename)

        # Only copy files, not directories
        if os.path.isfile(source_path):
            try:
                shutil.copy2(source_path, target_path)
                copied_count += 1
                print(f"Copied: {filename}")
            except Exception as e:
                print(f"Error copying {filename}: {e}")

    print(f"\nSuccessfully copied {copied_count} files to {target_dir}")

    # Verify files in target directory
    target_files = os.listdir(target_dir)
    print(f"Target directory now has {len(target_files)} files")

    return True

# Run the synchronization
sync_result = sync_chunks_from_drive()
print(f"Sync completed: {'✅ Success' if sync_result else '❌ Failed'}")
# Out:
# Found 1428 files in /content/drive/MyDrive/chunks
# Copied: Ether Zero_chunks.json
# Copied: CoinMetro_chunks.json
# Copied: DeusCoin_chunks.json
# Copied: Curriculum Vitae_chunks.json
# Copied: ArtByte_chunks.json
# Copied: aave-v2-whitepaper_extracted_chunks.json
# Copied: BOScoin_chunks.json
# Copied: MinexCoin_chunks.json
# Copied: VNT Chain_chunks.json
# Copied: Beetle Coin_chunks.json
# Copied: Safein_chunks.json
# Copied: DCTO_chunks.json
# Copied: ZeusCrowdfunding_chunks.json
# Copied: Opennity_chunks.json
# Copied: ValueChain_chunks.json
# Copied: Restart Energy MWAT_chunks.json
# Copied: Ultra_chunks.json
# Copied: FootballCoin_chunks.json
# Copied: FTX Token_chunks.json
# Copied: REDFOXLABS_chunks.json
# Copied: Bitblocks_chunks.json
# Copied: Bitmax Token_chunks.json
# Copied: Ripple_chunks.json
# Copied: HelloGold_chunks.json
# Copied: HireMatch_chunks.json
# Copied: patientory_chunks.json
# Copied: Blockport_chunks.json
# Copied: INS Ecosystem_chunks.json
# Copied: Dero_chunks.json
# Copied: Stratis_chunks.json
# Copied: BlockMesh_chunks.json
# Copied: Safeguard_chunks.json
# Copied: information-14-00171_processed_chunks.json
# Copied: Opal_chunks.json
# Copied: Absolute_chunks.json
# Copied: Qbao_chunks.json
# Copied: PumaPay_chunks.json
# Copied: BitRent_chunks.json
# Copied: Pathhive_chunks.json
# Copied: Globalvillage Ecosystem_chunks.json
# Copied: Power_chunks.json
# Copied: ZENZO_chunks.json
# Copied: XYO Network_chunks.json
# Copied: Probit_chunks.json
# Copied: PIVX_chunks.json
# Copied: PLATINCOIN_chunks.json
# Copied: Enjin Coin_chunks.json
# Copied: TenX_chunks.json
# Copied: ProximaX_chunks.json
# Copied: netkoin_chunks.json
# Copied: ssrn-4414080_processed_chunks.json
# Copied: DasCoin_chunks.json
# Copied: Compound Coin_chunks.json
# Copied: ELTCOIN_chunks.json
# Copied: Patron_chunks.json
# Copied: ugChain_chunks.json
# Copied: Oceanlab_chunks.json
# Copied: DeepOnion_chunks.json
# Copied: ODEM_chunks.json
# Copied: Phore_chunks.json
# Copied: Gene Source Code Chain_chunks.json
# Copied: Bankcoin_chunks.json
# Copied: Atonomi_chunks.json
# Copied: StableUSD_chunks.json
# Copied: Gulden_chunks.json
# Copied: Blockpass_chunks.json
# Copied: KICKECOSYSTEM_chunks.json
# Copied: Linkey_chunks.json
# Copied: Phantasma_chunks.json
# Copied: Spendcoin_chunks.json
# Copied: Kleros_chunks.json
# Copied: TokenCard_chunks.json
# Copied: HNB_chunks.json
# Copied: DigitalNote_chunks.json
# Copied: Propy_chunks.json
# Copied: Tracto_chunks.json
# Copied: suqa_chunks.json
# Copied: Oasis City_chunks.json
# Copied: MOAC_chunks.json
# Copied: Ampleforth_chunks.json
# Copied: bitCEO_chunks.json
# Copied: Bela_chunks.json
# Copied: EXMR FDN_chunks.json
# Copied: Simmitri_chunks.json
# Copied: Dentacoin_chunks.json
# Copied: Aidus_chunks.json
# Copied: FairCoin_chunks.json
# Copied: Phonecoin_chunks.json
# Copied: Divi_chunks.json
# Copied: Elrond_chunks.json
# Copied: Paxos_chunks.json
# Copied: Dapp Token_chunks.json
# Copied: Afin_chunks.json
# Copied: Pivot_chunks.json
# Copied: APOT_chunks.json
# Copied: MenaPay_chunks.json
# Copied: SIBCoin_chunks.json
# Copied: Livenodes_chunks.json
# Copied: Refereum_chunks.json
# Copied: EDC Blockchain_chunks.json
# Copied: Effect.ai_chunks.json
# Copied: Unibright_chunks.json
# Copied: Bitcoin Cash_chunks.json
# Copied: DACH Coin_chunks.json
# Copied: Basic Attention Token_chunks.json
# Copied: Peercoin_chunks.json
# Copied: Blackmoon_chunks.json
# Copied: BlackCoin_chunks.json
# Copied: Live Stars_chunks.json
# Copied: SwiftCash_chunks.json
# Copied: Mithril_chunks.json
# Copied: Block Logic_chunks.json
# Copied: SHIELD_chunks.json
# Copied: COTI_chunks.json
# Copied: Tao_chunks.json
# Copied: PKG Token_chunks.json
# Copied: DigiPulse_chunks.json
# Copied: FREE Coin_chunks.json
# Copied: Expanse_chunks.json
# Copied: Peerplays_chunks.json
# Copied: WEF_Digital_Assets_Regulation_2024_cleaned_chunks.json
# Copied: W Green Pay_chunks.json
# Copied: Litex_chunks.json
# Copied: EthBet_chunks.json
# Copied: Ultrain_chunks.json
# Copied: Bitcoiin2Gen_chunks.json
# Copied: SHPING_chunks.json
# Copied: SealChain_chunks.json
# Copied: Credit_chunks.json
# Copied: PUBLYTO_chunks.json
# Copied: Russian Miner Coin_chunks.json
# Copied: Woodcoin_chunks.json
# Copied: Hedgetoken_chunks.json
# Copied: Sharpe Platform Token_chunks.json
# Copied: Linfinity_chunks.json
# Copied: Medibit_chunks.json
# Copied: EveryCoin_chunks.json
# Copied: Gainer_chunks.json
# Copied: sample_chunks.json
# Copied: Nervos_chunks.json
# Copied: BrahmaOS_chunks.json
# Copied: Bismuth_chunks.json
# Copied: Polymath_chunks.json
# Copied: Hot_chunks.json
# Copied: Dock_chunks.json
# Copied: Docademic_chunks.json
# Copied: Cosmo Chain_chunks.json
# Copied: OriginTrail_chunks.json
# Copied: Haven Protocol_chunks.json
# Copied: Cazcoin_chunks.json
# Copied: Celer Network_chunks.json
# Copied: MX Token_chunks.json
# Copied: Raiden Network_chunks.json
# Copied: bitJob_chunks.json
# Copied: Nxt_chunks.json
# Copied: Karatgold Coin_chunks.json
# Copied: Content and Ad Network_chunks.json
# Copied: cravath_processed_chunks.json
# Copied: Horizon State_chunks.json
# Copied: Ladder Network_chunks.json
# Copied: FuckToken_chunks.json
# Copied: Everex_chunks.json
# Copied: Tierion_chunks.json
# Copied: DAV Coin_chunks.json
# Copied: Sentinel_chunks.json
# Copied: blogs.cisco.com_cleaned_chunks.json
# Copied: XRT token_chunks.json
# Copied: Aurora_chunks.json
# Copied: Bitcoin Turbo Koin_chunks.json
# Copied: Delphy_chunks.json
# Copied: Bgogo token_chunks.json
# Copied: Aryacoin_chunks.json
# Copied: Crowdvilla_chunks.json
# Copied: DACC_chunks.json
# Copied: x42_chunks.json
# Copied: Sweetbridge_chunks.json
# Copied: Silent Notary_chunks.json
# Copied: Hydrogen_chunks.json
# Copied: Shivers_chunks.json
# Copied: ZrCoin_chunks.json
# Copied: Indorse_chunks.json
# Copied: InterCrone_chunks.json
# Copied: Jarvis_chunks.json
# Copied: TrustVerse_chunks.json
# Copied: ENTCash_chunks.json
# Copied: wetoken_chunks.json
# Copied: TrezarCoin_chunks.json
# Copied: WaBi_chunks.json
# Copied: SOOM_chunks.json
# Copied: Zcoin_chunks.json
# Copied: ATN_chunks.json
# Copied: Rentberry_chunks.json
# Copied: Bottos_chunks.json
# Copied: Typerium_chunks.json
# Copied: PACcoin_chunks.json
# Copied: white-paper_extracted_chunks.json
# Copied: Nectar_chunks.json
# Copied: Alphacat_chunks.json
# Copied: aion_chunks.json
# Copied: Denarius_chunks.json
# Copied: Zipper_chunks.json
# Copied: Gexan_chunks.json
# Copied: BitNewChain_chunks.json
# Copied: Ticko_chunks.json
# Copied: EscrowCoin_chunks.json
# Copied: Volume Network_chunks.json
# Copied: MicroBitcoin_chunks.json
# Copied: bitnautic_chunks.json
# Copied: Turtlecoin_chunks.json
# Copied: On.Live_chunks.json
# Copied: Bounty0x_chunks.json
# Copied: ethereum classic_chunks.json
# Copied: Energo_chunks.json
# Copied: Fantom_chunks.json
# Copied: Decentralized Machine Learning_chunks.json
# Copied: Rivetz_chunks.json
# Copied: BHP Network_chunks.json
# Copied: Kin_chunks.json
# Copied: CARDbuyers_chunks.json
# Copied: Blocktrade_chunks.json
# Copied: Enecuum_chunks.json
# Copied: apM Coin_chunks.json
# Copied: Traceability Chain_chunks.json
# Copied: Hypnoxys_chunks.json
# Copied: AICHAIN_chunks.json
# Copied: OneGame_chunks.json
# Copied: Storeum_chunks.json
# Copied: VikkyToken_chunks.json
# Copied: Blocklancer_chunks.json
# Copied: UltraNote Coin_chunks.json
# Copied: UltrAlpha_chunks.json
# Copied: CARAT_chunks.json
# Copied: Target Coin_chunks.json
# Copied: SPIN Protocol_chunks.json
# Copied: Ecoreal Estate_chunks.json
# Copied: www.integrityriskintl.com_cleaned_chunks.json
# Copied: TimeMoney_chunks.json
# Copied: IZIChain_chunks.json
# Copied: Elastic_chunks.json
# Copied: SSRN-id4594467_chunks.json
# Copied: Rally_chunks.json
# Copied: FunFair_chunks.json
# Copied: InterValue_chunks.json
# Copied: Bitcoin Red_chunks.json
# Copied: TaTaTu_chunks.json
# Copied: CompoundEthereum_chunks.json
# Copied: Treelion_chunks.json
# Copied: Neblio_chunks.json
# Copied: Viuly_chunks.json
# Copied: alphacoin_chunks.json
# Copied: Jewel_chunks.json
# Copied: YENTEN_chunks.json
# Copied: PAX Gold_chunks.json
# Copied: Sharder_chunks.json
# Copied: Matchpool_chunks.json
# Copied: SwissBorg_chunks.json
# Copied: Plair_chunks.json
# Copied: Eximchain_chunks.json
# Copied: Privatix_chunks.json
# Copied: Aditus-Whitepaper_extracted_chunks.json
# Copied: GlitzKoin_chunks.json
# Copied: Atlantis Blue Digital Token_chunks.json
# Copied: Magic Cube_chunks.json
# Copied: EBCoin_chunks.json
# Copied: LGO Exchange_chunks.json
# Copied: Neox_chunks.json
# Copied: Akroma_chunks.json
# Copied: LiteDoge_chunks.json
# Copied: Request Network_chunks.json
# Copied: Motocoin_chunks.json
# Copied: BitCoen_chunks.json
# Copied: GazeCoi_chunks.json
# Copied: Halo Platform_chunks.json
# Copied: Couchain_chunks.json
# Copied: Pillar_chunks.json
# Copied: Six Domain Chain_chunks.json
# Copied: BitcoiNote_chunks.json
# Copied: The WoT.City original_chunks.json
# Copied: Tera_chunks.json
# Copied: Enigma_chunks.json
# Copied: Dinero_chunks.json
# Copied: Quinads_chunks.json
# Copied: Gosama Final_chunks.json
# Copied: Emercoin_chunks.json
# Copied: HashCoin_chunks.json
# Copied: RefToken_chunks.json
# Copied: qchi_chunks.json
# Copied: IQ.cash_chunks.json
# Copied: Origo_chunks.json
# Copied: 0chain_chunks.json
# Copied: Telcoin_chunks.json
# Copied: Vezt_chunks.json
# Copied: Silverway Token_chunks.json
# Copied: Metronome_chunks.json
# Copied: UnlimitedIP_chunks.json
# Copied: Cutcoin_chunks.json
# Copied: Rif Token_chunks.json
# Copied: Blockmason Link_chunks.json
# Copied: Ethorse_chunks.json
# Copied: Ripio Credit Network_chunks.json
# Copied: Digital Fantasy Sports_chunks.json
# Copied: Cobinhood_chunks.json
# Copied: Maya Preferred_chunks.json
# Copied: Galaxy eSolutions_chunks.json
# Copied: OATH protocol_chunks.json
# Copied: WinToken_chunks.json
# Copied: Bizkey_chunks.json
# Copied: www.centrl.ai_cleaned_chunks.json
# Copied: eBoost_chunks.json
# Copied: membrana_chunks.json
# Copied: CardStack_chunks.json
# Copied: Cryptaur_chunks.json
# Copied: Qbic_chunks.json
# Copied: Ocean Protocol_chunks.json
# Copied: Tokenbox_chunks.json
# Copied: MetaHash_chunks.json
# Copied: Diamond Network_chunks.json
# Copied: www.investopedia.com_cleaned_chunks.json
# Copied: Electronic Energy Coin_chunks.json
# Copied: GreenPower_chunks.json
# Copied: ParkGene_chunks.json
# Copied: ZeuxCoin_chunks.json
# Copied: Uranus_chunks.json
# Copied: KanadeCoin_chunks.json
# Copied: NeoWorld Cash_chunks.json
# Copied: StockChain_chunks.json
# Copied: Sola Token_chunks.json
# Copied: ShowHand_chunks.json
# Copied: Clipper Coin_chunks.json
# Copied: GridCoin_chunks.json
# Copied: Noku_chunks.json
# Copied: Crypto.com_chunks.json
# Copied: Ezoow_chunks.json
# Copied: Payfair_chunks.json
# Copied: KuCoin Shares_chunks.json
# Copied: Stellite_chunks.json
# Copied: PiplCoin_chunks.json
# Copied: travala_chunks.json
# Copied: Etherinc_chunks.json
# Copied: MediBloc_chunks.json
# Copied: HitChain_chunks.json
# Copied: Diruna_chunks.json
# Copied: DigitalPrice_chunks.json
# Copied: Lambda_chunks.json
# Copied: Asgard_chunks.json
# Copied: DDKoin_chunks.json
# Copied: Gifto_chunks.json
# Copied: Project Coin_chunks.json
# Copied: Status_chunks.json
# Copied: SKYFchain_chunks.json
# Copied: MultiVAC Tech_chunks.json
# Copied: CryptoFranc_chunks.json
# Copied: Bitcoin W Spectrum_chunks.json
# Copied: Dragon Coins_chunks.json
# Copied: CMITCOIN_chunks.json
# Copied: Banca_chunks.json
# Copied: VoteCoin_chunks.json
# Copied: Spectiv_chunks.json
# Copied: mcashchain_chunks.json
# Copied: VeriBlock_chunks.json
# Copied: Stellar Gold_chunks.json
# Copied: NOW Token_chunks.json
# Copied: VITE_chunks.json
# Copied: Measurable Data Token_chunks.json
# Copied: Origami_chunks.json
# Copied: WINCOIN_chunks.json
# Copied: Zeusshield_chunks.json
# Copied: Hive_chunks.json
# Copied: 999_chunks.json
# Copied: Wrapped Bitcoin_chunks.json
# Copied: PolySwarm_chunks.json
# Copied: EveriToken_chunks.json
# Copied: BOSAGORA_chunks.json
# Copied: DOWCOIN_chunks.json
# Copied: Zealium_chunks.json
# Copied: ZenCash_chunks.json
# Copied: SmartsFox_chunks.json
# Copied: Databits_chunks.json
# Copied: BookingTokenUnit_chunks.json
# Copied: DeepCloudAI_chunks.json
# Copied: Electra_chunks.json
# Copied: Agrello_chunks.json
# Copied: LikeCoin_chunks.json
# Copied: Tokia_chunks.json
# Copied: Sociall_chunks.json
# Copied: Pedity_chunks.json
# Copied: Zilla_chunks.json
# Copied: Iungo_chunks.json
# Copied: BoatPilot_chunks.json
# Copied: ORS Group_chunks.json
# Copied: FidentiaX_chunks.json
# Copied: hyperion_chunks.json
# Copied: Burst Coin_chunks.json
# Copied: No BS Crypto_chunks.json
# Copied: EPLUS Coin_chunks.json
# Copied: AiLink Token_chunks.json
# Copied: STEX_chunks.json
# Copied: Tratok_chunks.json
# Copied: Pura_chunks.json
# Copied: COSS_chunks.json
# Copied: Gold Poker_chunks.json
# Copied: SpaceCoin_chunks.json
# Copied: legolas_chunks.json
# Copied: Primecoin_chunks.json
# Copied: Zcash_chunks.json
# Copied: Aave_Protocol_Whitepaper_v1_0_extracted_chunks.json
# Copied: Poseidon Network_chunks.json
# Copied: Mindexcoin_chunks.json
# Copied: DigiByte_chunks.json
# Copied: The tokenized hardware_chunks.json
# Copied: Luna Stars_chunks.json
# Copied: Wirex Token_chunks.json
# Copied: AceD_chunks.json
# Copied: Binance_chunks.json
# Copied: LatiumX_chunks.json
# Copied: Medicalchain_chunks.json
# Copied: Innovative Bioresearch Classic_chunks.json
# Copied: Ethbits_chunks.json
# Copied: INO COIN_chunks.json
# Copied: Adtoken_chunks.json
# Copied: Tokenstars_chunks.json
# Copied: SafeInsure_chunks.json
# Copied: Publica_chunks.json
# Copied: Datawallet_chunks.json
# Copied: Ultiledger_chunks.json
# Copied: Experty_chunks.json
# Copied: subx_chunks.json
# Copied: DOS Network_chunks.json
# Copied: Reddcoin_chunks.json
# Copied: WPP TOKEN_chunks.json
# Copied: ZCore_chunks.json
# Copied: Transcodium_chunks.json
# Copied: Emanate_chunks.json
# Copied: Aventus_chunks.json
# Copied: PWR Coin_chunks.json
# Copied: BuzzCoin_chunks.json
# Copied: Nexty_chunks.json
# Copied: AmonD_chunks.json
# Copied: Project Pai_chunks.json
# Copied: Qvolta_chunks.json
# Copied: DENT ICO_chunks.json
# Copied: VideoCoin_chunks.json
# Copied: Abjcoin_chunks.json
# Copied: Puregold_chunks.json
# Copied: FolmCoin_chunks.json
# Copied: beat_chunks.json
# Copied: FOINS_chunks.json
# Copied: Beaxy Exchange_chunks.json
# Copied: MESG_chunks.json
# Copied: Daneel_chunks.json
# Copied: Alibabacoin_chunks.json
# Copied: theholycoins.com_cleaned_chunks.json
# Copied: Playgroundz_chunks.json
# Copied: Function X_chunks.json
# Copied: Ether Kingdom_chunks.json
# Copied: ChainLink_chunks.json
# Copied: document-1_processed_chunks.json
# Copied: PotCoin_chunks.json
# Copied: Boolberry_chunks.json
# Copied: Sessia_chunks.json
# Copied: Bytom_chunks.json
# Copied: Zebi_chunks.json
# Copied: Auctus_chunks.json
# Copied: www.scorechain.com_cleaned_chunks.json
# Copied: WaykiChain_chunks.json
# Copied: Wings_chunks.json
# Copied: BawNetwork_chunks.json
# Copied: Carry_chunks.json
# Copied: ProChain_chunks.json
# Copied: Ignis_chunks.json
# Copied: RealChain_chunks.json
# Copied: Agrolot_chunks.json
# Copied: Olyseum_chunks.json
# Copied: LeviarCoin_chunks.json
# Copied: Mirai_chunks.json
# Copied: OWNDATA_chunks.json
# Copied: Super Zero_chunks.json
# Copied: Time New Bank_chunks.json
# Copied: Idex_chunks.json
# Copied: SophiaTX_chunks.json
# Copied: Magnet_chunks.json
# Copied: WhaleCoin_chunks.json
# Copied: Coimatic_chunks.json
# Copied: S4FE_chunks.json
# Copied: Natmin_chunks.json
# Copied: DUO Network_chunks.json
# Copied: vSportCoin_chunks.json
# Copied: adbank_chunks.json
# Copied: OracleChain_chunks.json
# Copied: Devify_chunks.json
# Copied: Lition_chunks.json
# Copied: Signals Network_chunks.json
# Copied: CommerceBlock_chunks.json
# Copied: Wild Crypto_chunks.json
# Copied: High Performance Blockchain_chunks.json
# Copied: Blocknet_chunks.json
# Copied: Nebulas_chunks.json
# Copied: Bankex_chunks.json
# Copied: Vipstar Coin_chunks.json
# Copied: Cosmos_chunks.json
# Copied: Neural Protocol_chunks.json
# Copied: Pibble_chunks.json
# Copied: STPT_chunks.json
# Copied: TrueFlip_chunks.json
# Copied: GET Protocol_chunks.json
# Copied: SRCoin_chunks.json
# Copied: Byteball_chunks.json
# Copied: BioCoin_chunks.json
# Copied: NewYork Exchange Coin_chunks.json
# Copied: Gold Bits Coin_chunks.json
# Copied: Bilaxy_chunks.json
# Copied: Storiqa_chunks.json
# Copied: metal Pay_chunks.json
# Copied: Observer Technical Note_chunks.json
# Copied: Esports Token_chunks.json
# Copied: Bluzelle_chunks.json
# Copied: Egretia_chunks.json
# Copied: Hashgard_chunks.json
# Copied: SONM_chunks.json
# Copied: Monster Byte_chunks.json
# Copied: DxChain_chunks.json
# Copied: Siacoin_chunks.json
# Copied: XTRABYTES_chunks.json
# Copied: 1X2 Coin_chunks.json
# Copied: OOOBTC Token_chunks.json
# Copied: Noir_chunks.json
# Copied: ZEON_chunks.json
# Copied: Synthetix Network_chunks.json
# Copied: Zen Protocol_chunks.json
# Copied: V Systems_chunks.json
# Copied: YUKI_chunks.json
# Copied: Stellar_chunks.json
# Copied: Hybrid Block_chunks.json
# Copied: Rankingball Gold_chunks.json
# Copied: Lunyr_chunks.json
# Copied: ChainX_chunks.json
# Copied: Mithril Ore_chunks.json
# Copied: messe_chunks.json
# Copied: Apollo_chunks.json
# Copied: Condominium_chunks.json
# Copied: Nasdacoin_chunks.json
# Copied: Nuls_chunks.json
# Copied: Aston_chunks.json
# Copied: ssrn-3305362_processed_chunks.json
# Copied: Rocket Pool_chunks.json
# Copied: pEOS_chunks.json
# Copied: Maggie_chunks.json
# Copied: EncryptoTel_chunks.json
# Copied: Arepacoin_chunks.json
# Copied: Rento_chunks.json
# Copied: Joint Ventures_chunks.json
# Copied: Swace_chunks.json
# Copied: Zeepin_chunks.json
# Copied: Internet of People_chunks.json
# Copied: Pirate Chain_chunks.json
# Copied: Waves_chunks.json
# Copied: Fleta_chunks.json
# Copied: GlassCoin_chunks.json
# Copied: Jibrel Network_chunks.json
# Copied: Global Social Chain_chunks.json
# Copied: Hydro Protocol_chunks.json
# Copied: BitcoinSV_chunks.json
# Copied: Kcash_chunks.json
# Copied: Wavesbet_chunks.json
# Copied: BitBay_chunks.json
# Copied: BitStash_chunks.json
# Copied: X8X Token_chunks.json
# Copied: Bitdeal_chunks.json
# Copied: WAX_chunks.json
# Copied: HEROcoin_chunks.json
# Copied: MovieBloc_chunks.json
# Copied: www.sanctions.io_cleaned_chunks.json
# Copied: TimeBox_chunks.json
# Copied: Hellenic Node_chunks.json
# Copied: Kuende_chunks.json
# Copied: CHEX_chunks.json
# Copied: Endor Protocol_chunks.json
# Copied: Blockstack_chunks.json
# Copied: TomoChain_chunks.json
# Copied: Block Chain_chunks.json
# Copied: Farad_chunks.json
# Copied: Cortex_chunks.json
# Copied: AMO Coin_chunks.json
# Copied: Next.Exchange_chunks.json
# Copied: MB8_chunks.json
# Copied: FundYourselfNow_chunks.json
# Copied: ROIyal Coin_chunks.json
# Copied: Ormeus Coin_chunks.json
# Copied: Canlead_chunks.json
# Copied: Ethereum_chunks.json
# Copied: Micromines_chunks.json
# Copied: Jesus Coin_chunks.json
# Copied: Powerchain_chunks.json
# Copied: Bethereum_chunks.json
# Copied: carVertical_chunks.json
# Copied: Smartshare_chunks.json
# Copied: CrypViser_chunks.json
# Copied: FUSION_chunks.json
# Copied: LTO Network_chunks.json
# Copied: EnterCoin_chunks.json
# Copied: Gaps Chain_chunks.json
# Copied: LOCIcoin_chunks.json
# Copied: crypto.com_cleaned_chunks.json
# Copied: BiblePay_chunks.json
# Copied: streamr_chunks.json
# Copied: Tether_chunks.json
# Copied: Infinitus_chunks.json
# Copied: HyperLoot_chunks.json
# Copied: IntelliShare_chunks.json
# Copied: Capdax_chunks.json
# Copied: Knoxstertoken_chunks.json
# Copied: Bitcoin Dark_chunks.json
# Copied: VINchain_chunks.json
# Copied: SaluS_chunks.json
# Copied: NOIZ_chunks.json
# Copied: Lykke_chunks.json
# Copied: Opus_chunks.json
# Copied: Bytecoin_chunks.json
# Copied: CEDEX_chunks.json
# Copied: Zilliqa_chunks.json
# Copied: MTC Mesh Network_chunks.json
# Copied: Harvest Masternode Coin_chunks.json
# Copied: Loki_chunks.json
# Copied: Loopring_chunks.json
# Copied: Bibox_chunks.json
# Copied: BLUE_chunks.json
# Copied: MixMarvel_chunks.json
# Copied: IOTA_chunks.json
# Copied: Fast Access Blockchain_chunks.json
# Copied: GoWithMi_chunks.json
# Copied: Seele_chunks.json
# Copied: Fetch_chunks.json
# Copied: Universa_chunks.json
# Copied: netbox coin_chunks.json
# Copied: ENERGI_chunks.json
# Copied: HedgeTrade_chunks.json
# Copied: Factom_chunks.json
# Copied: district0x_chunks.json
# Copied: Cryptocurrency Returns_processed_chunks.json
# Copied: Bitcloud Pro_chunks.json
# Copied: Shadow Token_chunks.json
# Copied: BORA_chunks.json
# Copied: Parachute_chunks.json
# Copied: Currency Analytics_chunks.json
# Copied: EdenChain_chunks.json
# Copied: Niobium Coin_chunks.json
# Copied: Matic Network_chunks.json
# Copied: Locus Chain_chunks.json
# Copied: Dusk Network_chunks.json
# Copied: LemoChain_chunks.json
# Copied: savedroid_chunks.json
# Copied: bitcoin_chunks.json
# Copied: OneLedger_chunks.json
# Copied: Swarm_chunks.json
# Copied: 1110830.1.0 Introduction to Digital Assets for Institutional Investors_FINAL_0_chunks.json
# Copied: B2B_chunks.json
# Copied: botXcoin_chunks.json
# Copied: Voise_chunks.json
# Copied: DecentBet_chunks.json
# Copied: Vega Protocol_chunks.json
# Copied: Cajutel_chunks.json
# Copied: Molecular Future_chunks.json
# Copied: Qtum_chunks.json
# Copied: Trinity_chunks.json
# Copied: Sphere_chunks.json
# Copied: Bitcoin Green_chunks.json
# Copied: Mero_chunks.json
# Copied: osadc en_chunks.json
# Copied: cryptopay_chunks.json
# Copied: Twinkle_chunks.json
# Copied: Ambrosus_chunks.json
# Copied: Red Pulse_chunks.json
# Copied: DreamTeam_chunks.json
# Copied: fintrux_chunks.json
# Copied: FLIP_chunks.json
# Copied: LocalCoinSwap_chunks.json
# Copied: Planet_chunks.json
# Copied: Gnosis_chunks.json
# Copied: MGC_chunks.json
# Copied: LiquidApps_chunks.json
# Copied: Litecoin Cash_chunks.json
# Copied: DogeCash_chunks.json
# Copied: AirFox_chunks.json
# Copied: Waltonchain_chunks.json
# Copied: NKN_chunks.json
# Copied: WITChain_chunks.json
# Copied: Super Game Chain_chunks.json
# Copied: VouchForMe_chunks.json
# Copied: Internet Node Token_chunks.json
# Copied: Caspian_chunks.json
# Copied: QuadrantProtocol_chunks.json
# Copied: NAGA_chunks.json
# Copied: Bridge_chunks.json
# Copied: Algorand_chunks.json
# Copied: Hacken_chunks.json
# Copied: ThunderCore_chunks.json
# Copied: Traxia_chunks.json
# Copied: CampusCoin_chunks.json
# Copied: aelf_whitepaper_v1.2_extracted_chunks.json
# Copied: Odyssey_chunks.json
# Copied: CoinUs_chunks.json
# Copied: Billionaire Token_chunks.json
# Copied: CryptoPing_chunks.json
# Copied: Metaverse ETP_chunks.json
# Copied: TRON_chunks.json
# Copied: Lisk_chunks.json
# Copied: ShipChain_chunks.json
# Copied: Nestree_chunks.json
# Copied: Oyster_chunks.json
# Copied: Eva Cash_chunks.json
# Copied: dascp_processed_chunks.json
# Copied: IoT Chain_chunks.json
# Copied: 1World_chunks.json
# Copied: Graviocoin_chunks.json
# Copied: GoChain_chunks.json
# Copied: GateChain_chunks.json
# Copied: AdEx-Whitepaper-v.7_extracted_chunks.json
# Copied: BipCoin_chunks.json
# Copied: Ondori_chunks.json
# Copied: selfkey en_chunks.json
# Copied: Obitan Chain_chunks.json
# Copied: Xaurum_chunks.json
# Copied: Ink Protocol_chunks.json
# Copied: Appcoins_chunks.json
# Copied: Sugar Exchange_chunks.json
# Copied: IHT Real Estate Protocol_chunks.json
# Copied: Contentos_chunks.json
# Copied: Sparkster_chunks.json
# Copied: FoodCoin_chunks.json
# Copied: IGNITE_chunks.json
# Copied: RECORD_chunks.json
# Copied: Aditus_chunks.json
# Copied: Dash_chunks.json
# Copied: fscp_chunks.json
# Copied: Hade Platform_chunks.json
# Copied: Ether Social Network_chunks.json
# Copied: ALAX_chunks.json
# Copied: United Traders Token_chunks.json
# Copied: Bastonet_chunks.json
# Copied: Dropil_chunks.json
# Copied: iExec_chunks.json
# Copied: Pascal Coin_chunks.json
# Copied: Terra_chunks.json
# Copied: Folding Coin_chunks.json
# Copied: GoByte_chunks.json
# Copied: Ties.DB_chunks.json
# Copied: Complexity - 2022 - Chen - Cryptocurrency Financial Risk Analysis Based on Deep Machine Learning_processed_chunks.json
# Copied: Uquid Coin_chunks.json
# Copied: Levolution_chunks.json
# Copied: Apollon_chunks.json
# Copied: iotex_chunks.json
# Copied: Quanta Utility Token_chunks.json
# Copied: Sharpay_chunks.json
# Copied: Quantstamp_chunks.json
# Copied: Ravencoin_chunks.json
# Copied: Monero Original_chunks.json
# Copied: Suretly_chunks.json
# Copied: DashCash_chunks.json
# Copied: Pledgecamp_chunks.json
# Copied: Modum_chunks.json
# Copied: TTC Protocol_chunks.json
# Copied: Substratum_chunks.json
# Copied: Bitcoin Gold_chunks.json
# Copied: Merculet_chunks.json
# Copied: Chronologic_chunks.json
# Copied: Monero Classic_chunks.json
# Copied: EOS.IO_chunks.json
# Copied: MobilinkToken_chunks.json
# Copied: Stox_chunks.json
# Copied: Vanta Network_chunks.json
# Copied: Cruisebit_chunks.json
# Copied: Remme_chunks.json
# Copied: Cardano_chunks.json
# Copied: Herbalist Token_chunks.json
# Copied: SEER_chunks.json
# Copied: Coinlancer_chunks.json
# Copied: Aidos Kuneen_chunks.json
# Copied: Kubera Coin_chunks.json
# Copied: XTRD_chunks.json
# Copied: Republic Protocol_chunks.json
# Copied: TaaS_chunks.json
# Copied: YEE_chunks.json
# Copied: Lucky Seven_chunks.json
# Copied: Flash_chunks.json
# Copied: evedo_chunks.json
# Copied: Future1coin_chunks.json
# Copied: XPA_chunks.json
# Copied: MEXC Token_chunks.json
# Copied: Pylon Network_chunks.json
# Copied: ESBC_chunks.json
# Copied: Maincoin_chunks.json
# Copied: True Chain_chunks.json
# Copied: Cloud_chunks.json
# Copied: Cybermiles_chunks.json
# Copied: DAEX_chunks.json
# Copied: Operational Due Diligence on crypto_processed_chunks.json
# Copied: ATBCoin_chunks.json
# Copied: YOYOW_chunks.json
# Copied: Asian Dragon_chunks.json
# Copied: Experience points_chunks.json
# Copied: Bionic_chunks.json
# Copied: MineBee_chunks.json
# Copied: Ubcoin Market_chunks.json
# Copied: Cloudbric_chunks.json
# Copied: Hubii Network_chunks.json
# Copied: Pecunio_chunks.json
# Copied: Polis_chunks.json
# Copied: Acoin_chunks.json
# Copied: HorusPay_chunks.json
# Copied: PAXEX_chunks.json
# Copied: CryptoCarbon_chunks.json
# Copied: Elixir_chunks.json
# Copied: Swipe_chunks.json
# Copied: WazirX_chunks.json
# Copied: Zephyr_chunks.json
# Copied: SalPay_chunks.json
# Copied: Newton_chunks.json
# Copied: Staker_chunks.json
# Copied: Mossland_chunks.json
# Copied: Bodhi_chunks.json
# Copied: Tokenomy_chunks.json
# Copied: Credits_chunks.json
# Copied: TrueFeedBack_chunks.json
# Copied: DAOstack_chunks.json
# Copied: YottaChain_chunks.json
# Copied: Yuan Chain Coin_chunks.json
# Copied: X12 Coin_chunks.json
# Copied: Worldcore_chunks.json
# Copied: Repme_chunks.json
# Copied: NEO_chunks.json
# Copied: Fabrk_chunks.json
# Copied: Humaniq_chunks.json
# Copied: Apex_chunks.json
# Copied: HEAT_chunks.json
# Copied: IOTW_chunks.json
# Copied: LHT usdx_chunks.json
# Copied: Ragnarok_chunks.json
# Copied: Shivom_chunks.json
# Copied: IOU_chunks.json
# Copied: TV_chunks.json
# Copied: Soverain_chunks.json
# Copied: AirWire_chunks.json
# Copied: Sport and Leisure_chunks.json
# Copied: Proton_chunks.json
# Copied: Cindicator_chunks.json
# Copied: Welltrado_chunks.json
# Copied: Sp8de_chunks.json
# Copied: BunnyToken_chunks.json
# Copied: RightMesh_chunks.json
# Copied: Fabric Token_chunks.json
# Copied: SingularityNET_chunks.json
# Copied: Constant_chunks.json
# Copied: Xenoverse_chunks.json
# Copied: IOSToken_chunks.json
# Copied: OAX_chunks.json
# Copied: DraftCoin_chunks.json
# Copied: Bulleon_chunks.json
# Copied: Edgeless_chunks.json
# Copied: Bezant_chunks.json
# Copied: Paytomat_chunks.json
# Copied: TopChain_chunks.json
# Copied: TeslaCoilCoin_chunks.json
# Copied: Switcheo_chunks.json
# Copied: Muzika_chunks.json
# Copied: Havven_chunks.json
# Copied: PoSToken_chunks.json
# Copied: ECC_chunks.json
# Copied: BaaSid_chunks.json
# Copied: Anchor_chunks.json
# Copied: ACRE_chunks.json
# Copied: Blocktix_chunks.json
# Copied: Monero_chunks.json
# Copied: Thrive Token_chunks.json
# Copied: Bitcoin Rhodium_chunks.json
# Copied: Bigbom_chunks.json
# Copied: wys Token_chunks.json
# Copied: Telos_chunks.json
# Copied: Traid_chunks.json
# Copied: TCOIN_chunks.json
# Copied: SwftCoin_chunks.json
# Copied: Thar Token_chunks.json
# Copied: LUXCoin_chunks.json
# Copied: Dai_chunks.json
# Copied: MARK.SPACE_chunks.json
# Copied: Hero_chunks.json
# Copied: MEET.ONE_chunks.json
# Copied: WHEN Token_chunks.json
# Copied: Augur_chunks.json
# Copied: www.ftitechnology.com_cleaned_chunks.json
# Copied: Bread_chunks.json
# Copied: IONChain_chunks.json
# Copied: STK_chunks.json
# Copied: Safecoin_chunks.json
# Copied: Eristica_chunks.json
# Copied: PundiX_chunks.json
# Copied: Olympus Labs_chunks.json
# Copied: OIO_chunks.json
# Copied: LEOcoin_chunks.json
# Copied: Presearch_chunks.json
# Copied: Petro_chunks.json
# Copied: SmartCash_chunks.json
# Copied: InsurChain_chunks.json
# Copied: Blockium_chunks.json
# Copied: Litecoin_chunks.json
# Copied: FuzeX_chunks.json
# Copied: Tripio_chunks.json
# Copied: NeuroChain_chunks.json
# Copied: OmiseGO_chunks.json
# Copied: SpaceChain_chunks.json
# Copied: Trittium_chunks.json
# Copied: Flixxo_chunks.json
# Copied: CannaCoin_chunks.json
# Copied: Opiria PDATA_chunks.json
# Copied: Pluton_chunks.json
# Copied: Freicoin_chunks.json
# Copied: PlayChip_chunks.json
# Copied: LockTrip_chunks.json
# Copied: Humanscape_chunks.json
# Copied: Aeron_chunks.json
# Copied: BFFDoom_chunks.json
# Copied: Aladdin_chunks.json
# Copied: Rchain_chunks.json
# Copied: Bayan Token_chunks.json
# Copied: SnipCoin_chunks.json
# Copied: StarterCoin_chunks.json
# Copied: TE FOOD_chunks.json
# Copied: Gatcoin_chunks.json
# Copied: SDChain_chunks.json
# Copied: Bitbook Gambling_chunks.json
# Copied: SmartMesh_chunks.json
# Copied: InnovaMinex_chunks.json
# Copied: Libra Credit_chunks.json
# Copied: Delizia_chunks.json
# Copied: Ifoods Chain_chunks.json
# Copied: CPChain_chunks.json
# Copied: Tigereum_chunks.json
# Copied: Groestlcoin_chunks.json
# Copied: QLCchain_chunks.json
# Copied: Upfiring_chunks.json
# Copied: Viberate_chunks.json
# Copied: huddl_chunks.json
# Copied: STASIS_chunks.json
# Copied: Bitcoin Token_chunks.json
# Copied: Verge_chunks.json
# Copied: Rate3_chunks.json
# Copied: Nitro_chunks.json
# Copied: Piction_chunks.json
# Copied: Fire Lotto_chunks.json
# Copied: OptiToken_chunks.json
# Copied: Cryptocurrency and Macro-Economic Stability_processed_chunks.json
# Copied: Tokugawa_chunks.json
# Copied: Etheroll_chunks.json
# Copied: Consentium_chunks.json
# Copied: SagaCoin_chunks.json
# Copied: Storj_chunks.json
# Copied: NANJCOIN_chunks.json
# Copied: Crycash_chunks.json
# Copied: Facebook Libra_chunks.json
# Copied: PressOne_chunks.json
# Copied: Bitspark_chunks.json
# Copied: AdEx_chunks.json
# Copied: PayPie_chunks.json
# Copied: Viewly_chunks.json
# Copied: CryptoNote Coin_chunks.json
# Copied: Decentraland_chunks.json
# Copied: BitBean_chunks.json
# Copied: RealityClash_chunks.json
# Copied: Nano_chunks.json
# Copied: DaTa eXchange_chunks.json
# Copied: SpreadCoin_chunks.json
# Copied: Kryll_chunks.json
# Copied: Melon_chunks.json
# Copied: Devery_chunks.json
# Copied: Phi_chunks.json
# Copied: LoyalCoin_chunks.json
# Copied: Covesting_chunks.json
# Copied: PAYCENT_chunks.json
# Copied: ILCoin_chunks.json
# Copied: Shard_chunks.json
# Copied: dascp_raw_chunks.json
# Copied: Level Up Coin_chunks.json
# Copied: Insight Chain_chunks.json
# Copied: NOIA Network_chunks.json
# Copied: Real Estate Investment Token_chunks.json
# Copied: Vites_chunks.json
# Copied: MyBit Token_chunks.json
# Copied: TokenPay_chunks.json
# Copied: GoldenFever_chunks.json
# Copied: Beldex_chunks.json
# Copied: Friendz_chunks.json
# Copied: DIMCOIN_chunks.json
# Copied: Storm_chunks.json
# Copied: PlusCoin_chunks.json
# Copied: Titan Coin_chunks.json
# Copied: NewsToken_chunks.json
# Copied: cravath_raw_chunks.json
# Copied: Ardor_chunks.json
# Copied: Digitex Futures_chunks.json
# Copied: MassGrid_chunks.json
# Copied: Agrocoin_chunks.json
# Copied: GNY_chunks.json
# Copied: B91_chunks.json
# Copied: Global Jobcoin_chunks.json
# Copied: StakeNet_chunks.json
# Copied: Stellar Classic_chunks.json
# Copied: AeronWhitepaper_extracted_chunks.json
# Copied: NoLimitCoin_chunks.json
# Copied: BEAM_chunks.json
# Copied: DeepBrain Chain_chunks.json
# Copied: MCPC_chunks.json
# Copied: BrazilCoin_chunks.json
# Copied: Decred_chunks.json
# Copied: GSENetwork_chunks.json
# Copied: CYCLEAN_chunks.json
# Copied: Monaco_chunks.json
# Copied: Numeraire_chunks.json
# Copied: ColossusXT_chunks.json
# Copied: BABB_chunks.json
# Copied: NEM_chunks.json
# Copied: SteepCoin_chunks.json
# Copied: komodo_chunks.json
# Copied: Platin_chunks.json
# Copied: Ivy_chunks.json
# Copied: Lisk Machine Learning_chunks.json
# Copied: Decentralized Vulnerability Platform_chunks.json
# Copied: WebDollar_chunks.json
# Copied: MFCoin_chunks.json
# Copied: Essentia_chunks.json
# Copied: BCDiploma_chunks.json
# Copied: Eroscoin_chunks.json
# Copied: Steem_chunks.json
# Copied: vTorrent_chunks.json
# Copied: Genesis vision_chunks.json
# Copied: VIBE_chunks.json
# Copied: ALQO_chunks.json
# Copied: wagerr_chunks.json
# Copied: Intelligent Trading Foundation_chunks.json
# Copied: Signatum_chunks.json
# Copied: Amino Network_chunks.json
# Copied: BitScreener_chunks.json
# Copied: BlockStamp_chunks.json
# Copied: DREP_chunks.json
# Copied: Hempcoin_chunks.json
# Copied: Giant_chunks.json
# Copied: Omnitude_chunks.json
# Copied: QuarkChain_chunks.json
# Copied: BitCash_chunks.json
# Copied: cashaa_chunks.json
# Copied: Monetha_chunks.json
# Copied: Polkadot_chunks.json
# Copied: Dragonchain_chunks.json
# Copied: Einsteinium_chunks.json
# Copied: Golem_chunks.json
# Copied: HunterCoin_chunks.json
# Copied: RealTract_chunks.json
# Copied: regalcoin_chunks.json
# Copied: ContentBox_chunks.json
# Copied: Espers_chunks.json
# Copied: All Sports_chunks.json
# Copied: Coinchase_chunks.json
# Copied: QunQun_chunks.json
# Copied: Vechain_chunks.json
# Copied: Netrum_chunks.json
# Copied: Rupiah Token_chunks.json
# Copied: Velas_chunks.json
# Copied: AdShares_chunks.json
# Copied: Kyber_chunks.json
# Copied: Achain_chunks.json
# Copied: MobileGo_chunks.json
# Copied: Skychain_chunks.json
# Copied: QASH_chunks.json
# Copied: BnkToTheFuture_chunks.json
# Copied: Pesetacoin_chunks.json
# Copied: Engine_chunks.json
# Copied: DigitalDevelopersFund_chunks.json
# Copied: Power Ledger_chunks.json
# Copied: 24+Noel+B.+Agustin+et+al.,+pp.+269-281_processed_chunks.json
# Copied: Formosa Financial_chunks.json
# Copied: White Standard_chunks.json
# Copied: FansTime_chunks.json
# Copied: Bloom_chunks.json
# Copied: Adzcoin_chunks.json
# Copied: MaidSafeCoin_chunks.json
# Copied: Almeela_chunks.json
# Copied: Mozo Token_chunks.json
# Copied: CyberVein_chunks.json
# Copied: Colu Local Network_chunks.json
# Copied: PlayFuel_chunks.json
# Copied: OTCBTC Token_chunks.json
# Copied: Mainframe_chunks.json
# Copied: 1irstcoin_chunks.json
# Copied: Theta_chunks.json
# Copied: Bitsdaq_chunks.json
# Copied: Flexacoin_chunks.json
# Copied: vetting_guide_raw_chunks.json
# Copied: Ryo Currency_chunks.json
# Copied: Mysterium_chunks.json
# Copied: Gems_chunks.json
# Copied: Truegame_chunks.json
# Copied: Themis_chunks.json
# Copied: Blue Whale_chunks.json
# Copied: ArcBlock_chunks.json
# Copied: The Influence of Cryptocurrency on International_processed_chunks.json
# Copied: THEKEY_chunks.json
# Copied: ETERNAL TOKEN_chunks.json
# Copied: Banyan Network_chunks.json
# Copied: WeTrust_chunks.json
# Copied: Leo Token_chunks.json
# Copied: Acute Angle Cloud_chunks.json
# Copied: Gemini Dollar_chunks.json
# Copied: Celsius_chunks.json
# Copied: Polybius_chunks.json
# Copied: Envion_chunks.json
# Copied: BTCMoon_chunks.json
# Copied: ABCC Token_chunks.json
# Copied: BitDegree_chunks.json
# Copied: Quantum Resistance Ledger_chunks.json
# Copied: Orchid_chunks.json
# Copied: Sharechain_chunks.json
# Copied: Alchemint_chunks.json
# Copied: Etherlegends_chunks.json
# Copied: Obyte_chunks.json
# Copied: Crypterium_chunks.json
# Copied: Authorship_chunks.json
# Copied: HYCON_chunks.json
# Copied: Zap_chunks.json
# Copied: EUNO Coin_chunks.json
# Copied: CEEK VR_chunks.json
# Copied: Smartup_chunks.json
# Copied: Bitforex_chunks.json
# Copied: Provoco_chunks.json
# Copied: Playkey_chunks.json
# Copied: ABLE_chunks.json
# Copied: MIR COIN_chunks.json
# Copied: SureRemit_chunks.json
# Copied: CYBR Token_chunks.json
# Copied: BlockCAT_chunks.json
# Copied: AuroraCoin_chunks.json
# Copied: Bittwatt_chunks.json
# Copied: CFun_chunks.json
# Copied: Qiibee_chunks.json
# Copied: Maecenas_chunks.json
# Copied: Bulwark_chunks.json
# Copied: Bittorrent_chunks.json
# Copied: Smart Bitcoin_chunks.json
# Copied: MedicCoin_chunks.json
# Copied: Travelflex_chunks.json
# Copied: MINDOL_chunks.json
# Copied: Bee Token_chunks.json
# Copied: OneRoot Network_chunks.json
# Copied: Fortuna_chunks.json
# Copied: 0xcert_chunks.json
# Copied: Linda_chunks.json
# Copied: Peerguess_chunks.json
# Copied: Webcoin_chunks.json
# Copied: BeeKan_chunks.json
# Copied: Radium_chunks.json
# Copied: Band Protocol_chunks.json
# Copied: Etherparty_chunks.json
# Copied: Digiwage_chunks.json
# Copied: BlockMason Credit_chunks.json
# Copied: BQT_chunks.json
# Copied: HyperCash_chunks.json
# Copied: Alphacon_chunks.json
# Copied: 108364 PLE_Digital Assets_Deck 290724_chunks.json
# Copied: Taklimakan Network_chunks.json
# Copied: YOUChain_chunks.json
# Copied: Po.et_chunks.json
# Copied: MMOCoin_chunks.json
# Copied: bitqy_chunks.json
# Copied: aeternity_chunks.json
# Copied: Primalbase_chunks.json
# Copied: CasinoCoin_chunks.json
# Copied: CoinMeet_chunks.json
# Copied: RED_chunks.json
# Copied: Ethereum Gold Project_chunks.json
# Copied: NEVERDIE_chunks.json
# Copied: SyncFab_chunks.json
# Copied: MergeCoin_chunks.json
# Copied: Safe Haven_chunks.json
# Copied: Eryllium_chunks.json
# Copied: Datarius_chunks.json
# Copied: Arbidex_chunks.json
# Copied: Leverj_chunks.json
# Copied: Monero Gold_chunks.json
# Copied: AVINOC_chunks.json
# Copied: Ink_chunks.json
# Copied: CNNS_chunks.json
# Copied: GXChain_chunks.json
# Copied: NapoleonX_chunks.json
# Copied: Sense_chunks.json
# Copied: PlayerOne_chunks.json
# Copied: 10-1108_978-1-80455-320-620221017_processed_chunks.json
# Copied: Genaro Network_chunks.json
# Copied: FOAM_chunks.json
# Copied: Tether Gold_chunks.json
# Copied: LinkEye_chunks.json
# Copied: Marginless_chunks.json
# Copied: Tezos_chunks.json
# Copied: APIS_chunks.json
# Copied: Ark.io_chunks.json
# Copied: Lightpaycoin_chunks.json
# Copied: Nos_chunks.json
# Copied: us-crypto-regulatory-whitepaper_cleaned_chunks.json
# Copied: Kambria_chunks.json
# Copied: EthereumX_chunks.json
# Copied: Gibraltar_chunks.json
# Copied: Asch_chunks.json
# Copied: Promotion Coin_chunks.json
# Copied: Bitcoin Private_chunks.json
# Copied: EJOY_chunks.json
# Copied: UTRUST_chunks.json
# Copied: Aitheon_chunks.json
# Copied: U Network_chunks.json
# Copied: BBSCoin_chunks.json
# Copied: Dimension Chain_chunks.json
# Copied: Ren_chunks.json
# Copied: Idealcoin_chunks.json
# Copied: Verasity_chunks.json
# Copied: CryptoFlow_chunks.json
# Copied: Hyper Speed Network_chunks.json
# Copied: 0x_chunks.json
# Copied: Cocos BCX_chunks.json
# Copied: Altlas Protocol_chunks.json
# Copied: steemit.com_cleaned_chunks.json
# Copied: BiNGOFun_chunks.json
# Copied: REPO_chunks.json
# Copied: SMART VALOR_chunks.json
# Copied: Krypton Galaxy Coin_chunks.json
# Copied: Bidooh_chunks.json
# Copied: SCRIV NETWORK_chunks.json
# Copied: Elitium_chunks.json
# Copied: ey-token-due-diligence-a-structured-approach-to-evaluate-digital-asset-risk (1)_chunks.json
# Copied: TWIST_chunks.json
# Copied: BetterBetting_chunks.json
# Copied: Filecoin_chunks.json
# Copied: Ethos_chunks.json
# Copied: HalalChain_chunks.json
# Copied: GameCredits_chunks.json
# Copied: BitUP_chunks.json
# Copied: Constellation_chunks.json
# Copied: Galactrum_chunks.json
# Copied: Everus_chunks.json
# Copied: Arionum_chunks.json
# Copied: Atlant_chunks.json
# Copied: Boutspro_chunks.json
# Copied: Kolion_chunks.json
# Copied: Timicoin_chunks.json
# Copied: Connect Coin_chunks.json
# Copied: Nash Exchange Token_chunks.json
# Copied: GINcoin_chunks.json
# Copied: Modultrade_chunks.json
# Copied: Eligma_chunks.json
# Copied: Diamond_chunks.json
# Copied: Ignition_chunks.json
# Copied: Nexo_chunks.json
# Copied: Mothership_chunks.json
# Copied: GOmics_chunks.json
# Copied: REBL_chunks.json
# Copied: Davinci Coin_chunks.json
# Copied: Japan Content Token_chunks.json
# Copied: Custody Token_chunks.json
# Copied: SIRIN LABS_chunks.json
# Copied: IntenseCoin_chunks.json
# Copied: Mytoken_chunks.json
# Copied: Mobius_chunks.json
# Copied: Honest_chunks.json
# Copied: Sentinel Protocol_chunks.json
# Copied: Darcrus_chunks.json
# Copied: Digitalbits_chunks.json
# Copied: Shift_chunks.json
# Copied: Solve Care_chunks.json
# Copied: NPCoin_chunks.json
# Copied: Karma_chunks.json
# Copied: Nexus_chunks.json
# Copied: DMarket_chunks.json
# Copied: CloakCoin_chunks.json
# Copied: Nebula AI_chunks.json
# Copied: Neumark_chunks.json
# Copied: ICON_chunks.json
# Copied: AI Doctor_chunks.json
# Copied: BitShares_chunks.json
# Copied: Ontology_chunks.json
# Copied: Electrify.Asia_chunks.json
# Copied: Prometeus_chunks.json
# Copied: Uptrennd_chunks.json
# Copied: Chromapolis_chunks.json
# Copied: Unification_chunks.json
# Copied: Elastos_chunks.json
# Copied: Yap Stone_chunks.json
# Copied: Lympo_chunks.json
# Copied: USC_chunks.json
# Copied: ABBC Foundation_chunks.json
# Copied: Dimecoin_chunks.json
# Copied: DogeCoin_chunks.json
# Copied: CRYPTO20_chunks.json
# Copied: Populous_chunks.json
# Copied: Hyperspace_chunks.json
# Copied: Horizen_chunks.json
# Copied: bitaml.com_cleaned_chunks.json
# Copied: SunContract_chunks.json
# Copied: DECENT_chunks.json
# Copied: Hedera pdf_chunks.json
# Copied: Orbs_chunks.json
# Copied: gratzio wp_chunks.json
# Copied: Imbrex_chunks.json
# Copied: Electroneum_chunks.json
# Copied: Path_chunks.json
# Copied: tagz_chunks.json
# Copied: namecoin_chunks.json
# Copied: ClearPoll_chunks.json
# Copied: Simone Coin_chunks.json
# Copied: MediShares_chunks.json
# Copied: Perlin_chunks.json
# Copied: Bankera_chunks.json
# Copied: Liquidity Network_chunks.json
# Copied: Viacoin_chunks.json
# Copied: DomRaider_chunks.json
# Copied: Fitrova_chunks.json
# Copied: SGPay_chunks.json
# Copied: Pixie Coin_chunks.json
# Copied: HTMLCoin_chunks.json
# Copied: Aave_chunks.json
# Copied: Chronobank_chunks.json
# Copied: Vexanium_chunks.json
# Copied: Xriba_chunks.json
# Copied: TrakInvest_chunks.json
# Copied: DashDiamond_chunks.json
# Copied: Tarush_chunks.json
# Copied: Matrix AI Network_chunks.json
# Copied: Flowchain_chunks.json
# Copied: ONO_chunks.json
# Copied: Whole Network_chunks.json
# Copied: BitWhite_chunks.json
# Copied: Usechain Token_chunks.json
# Copied: zvChain_chunks.json
# Copied: IQeon_chunks.json
# Copied: SoMee.Social_chunks.json
# Copied: Achain Whitepaper 2.0_EN_extracted_chunks.json
# Copied: USD Coin_chunks.json
# Copied: Unikoin Gold_chunks.json
# Copied: cryptoinvestigators.com_cleaned_chunks.json
# Copied: Datum_chunks.json
# Copied: Concierge Coin_chunks.json
# Copied: Cryptocean_chunks.json
# Copied: Airbloc_chunks.json
# Copied: Noah Coin_chunks.json
# Copied: Holo_chunks.json
# Copied: Sakura Bloom_chunks.json
# Copied: WABnetwork_chunks.json
# Copied: Stem Cell Coin_chunks.json
# Copied: SpankChain_chunks.json
# Copied: ADN_chunks.json
# Copied: GanjaCoin_chunks.json
# Copied: Ubricoin_chunks.json
# Copied: AMARK_chunks.json
# Copied: Primas_chunks.json
# Copied: Vetri_chunks.json
# Copied: AgrolifeCoin_chunks.json
# Copied: IXT_chunks.json
# Copied: Distributed Credit Chain_chunks.json
# Copied: Yggdrash_chunks.json
# Copied: BonusCloud_chunks.json
# Copied: vetting_guide_processed_chunks.json
# Copied: Uos_chunks.json
# Copied: Blockcloud_chunks.json
# Copied: Centrality_chunks.json
# Copied: VisionX_chunks.json
# Copied: Robotina_chunks.json
# Copied: Lunes_chunks.json
# Copied: MoneroV_chunks.json
# Copied: Wowoo_chunks.json
# Copied: AirSwap_chunks.json
# Copied: IP Exchange_chunks.json
# Copied: INMAX_chunks.json
# Copied: Mixin_chunks.json
# Copied: Impleum_chunks.json
# Copied: SF Capital_chunks.json
# Copied: BidiPass_chunks.json
# Copied: Castle_chunks.json
# Copied: Wanchain_chunks.json
# Copied: PalletOne_chunks.json
# Copied: ZMINE_chunks.json
# Copied: WePower_chunks.json
# Copied: Tap_chunks.json
# Copied: SakuraCoin_chunks.json
# Copied: 2014.5_word_to_int_chunks.json
# Copied: Eterbase_chunks.json
# Copied: XinFin Network_chunks.json
# Copied: What are the legal rights and obligations of token holders__processed_chunks.json
# Copied: SpiderVPS_chunks.json
# Copied: Vitae_chunks.json
# Copied: whitepaper_v_2.01_eng_extracted_chunks.json
# Copied: HomeBlockCoin_chunks.json
# Copied: xCrypt_chunks.json
# Copied: Mercury Protocol_chunks.json
# Copied: Budbo_chunks.json
# Copied: SoPay_chunks.json
# Copied: BitcoinHD_chunks.json
# Copied: Reserve Stabilization Protocol_chunks.json
# Copied: Wink_chunks.json
# Copied: Chiliz_chunks.json
# Copied: Titanium Blockchain_chunks.json
# Copied: Versess_chunks.json
# Copied: LIFE_chunks.json
# Copied: Skycoin_chunks.json
# Copied: OST_chunks.json
# Copied: SelfSell_chunks.json
# Copied: Ccore_chunks.json
# Copied: EQUI_chunks.json
# Copied: BlockBurn_chunks.json
# Copied: True USD_chunks.json
# Copied: CottonCoin_chunks.json
# Copied: vestchain_chunks.json
# Copied: ChatCoin_chunks.json
# Copied: Quant_chunks.json
# Copied: Aencoin_chunks.json
# Copied: SnowGem_chunks.json
# Copied: BitRewards_chunks.json
# Copied: Salt Lending_chunks.json
# Copied: NIX_chunks.json
# Copied: GAMB_chunks.json
# Copied: Callisto Network_chunks.json
# Copied: QuasarCoin_chunks.json
# Copied: Harmony_chunks.json
# Copied: LINA_chunks.json
# Copied: Aergo_chunks.json
# Copied: Rotharium_chunks.json
#
# Successfully copied 1428 files to chunks
# Target directory now has 1428 files
# Sync completed: ✅ Success

# %% [markdown]
# **Cell 2: Vectorization and Embeddings**

# %%
def create_vector_index_batched(chunks_folder="chunks",
                               index_folder="faiss_index",
                               batch_size=5000):
    """Create vector embeddings and index from chunks using batching"""
    print("\n🔍 Starting vectorization pipeline with batching...")

    # Create index directory
    os.makedirs(index_folder, exist_ok=True)

    # Initialize chunker with data directory
    chunker = SmartChunker(data_dir=index_folder)
    chunker._init_embeddings()

    # Load all documents
    documents = load_chunks_from_folder(chunks_folder)
    total_docs = len(documents)
    print(f"Loaded {total_docs} documents for vectorization")

    # Create empty FAISS index first time
    vectordb = None
    processed = 0

    # Process in batches
    for i in range(0, total_docs, batch_size):
        batch = documents[i:i+batch_size]
        print(f"Processing batch {i//batch_size + 1}/{(total_docs-1)//batch_size + 1} with {len(batch)} documents")

        # Create new index or add to existing
        if vectordb is None:
            vectordb = FAISS.from_documents(batch, chunker.embeddings)
        else:
            batch_db = FAISS.from_documents(batch, chunker.embeddings)
            vectordb.merge_from(batch_db)

        processed += len(batch)
        print(f"Progress: {processed}/{total_docs} documents ({processed/total_docs*100:.1f}%)")

        # Save checkpoint after each batch
        checkpoint_path = f"{index_folder}_checkpoint_{processed}"
        os.makedirs(checkpoint_path, exist_ok=True)
        vectordb.save_local(checkpoint_path)
        print(f"Saved checkpoint at {processed}/{total_docs} documents")

    # Save final index
    chunker.vectordb = vectordb
    chunker.vectordb.save_local(index_folder)
    print(f"✅ Indexed {total_docs} chunks into vector database")

    # Save metadata
    metadata_path = os.path.join(index_folder, "index_metadata.json")
    with open(metadata_path, "w", encoding="utf-8") as f:
        json.dump([doc.metadata for doc in documents], f, indent=2, ensure_ascii=False)
    print(f"✅ Metadata saved to '{metadata_path}' (JSON)")

    return chunker

# TPU Optimization for embeddings
def optimize_for_tpu(SmartChunker):
    """Replace the _init_embeddings method with TPU-optimized version"""

    original_init_embeddings = SmartChunker._init_embeddings

    def _init_embeddings_tpu(self):
        """Initialize embeddings model optimized for TPU if available"""
        if self.embeddings is None:
            print("🔍 Initializing embeddings model with hardware acceleration...")

            # Check if TPU is available
            device = 'cpu'
            try:
                import torch_xla
                import torch_xla.core.xla_model as xm
                device = xm.xla_device()
                print("✅ Using XLA TPU device")
            except ImportError:
                try:
                    import torch
                    if torch.cuda.is_available():
                        device = 'cuda'
                        print("✅ Using CUDA GPU device")
                except:
                    print("⚠️ No GPU/TPU detected, using CPU")

            self.embeddings = HuggingFaceEmbeddings(
                model_name="sentence-transformers/all-mpnet-base-v2",
                model_kwargs={'device': device}
            )

    # Replace the method
    SmartChunker._init_embeddings = _init_embeddings_tpu
    return SmartChunker

# Apply TPU optimization to the SmartChunker class
SmartChunker = optimize_for_tpu(SmartChunker)

# Function to run the full pipeline
def run_vector_indexing():
    # Run the batched vectorization pipeline
    chunker = create_vector_index_batched(
        chunks_folder="chunks",
        index_folder="faiss_index",
        batch_size=2500  # Adjust based on your memory constraints
    )

    # Test a search query to verify functionality
    print("\n🔍 Testing search functionality...")
    test_search(chunker, "What are KYC requirements for crypto exchanges?", k=3)

    return chunker

# Execute the pipeline
vector_db = run_vector_indexing()
# Out:
# 🔍 Starting vectorization pipeline with batching...
# 🔍 Initializing embeddings model with hardware acceleration...
# ✅ Using CUDA GPU device
# ✅ Loaded 9 chunks from MicroBitcoin_chunks.json
# ✅ Loaded 51 chunks from Netrum_chunks.json
# ✅ Loaded 39 chunks from IZIChain_chunks.json
# ✅ Loaded 36 chunks from BitDegree_chunks.json
# ✅ Loaded 20 chunks from Galactrum_chunks.json
# ✅ Loaded 20 chunks from gratzio wp_chunks.json
# ✅ Loaded 15 chunks from suqa_chunks.json
# ✅ Loaded 16 chunks from Herbalist Token_chunks.json
# ✅ Loaded 34 chunks from Monaco_chunks.json
# ✅ Loaded 28 chunks from IoT Chain_chunks.json
# ✅ Loaded 29 chunks from Bread_chunks.json
# ✅ Loaded 55 chunks from Gatcoin_chunks.json
# ✅ Loaded 20 chunks from Electrify.Asia_chunks.json
# ✅ Loaded 27 chunks from Experty_chunks.json
# ✅ Loaded 50 chunks from Ladder Network_chunks.json
# ✅ Loaded 22 chunks from Galaxy eSolutions_chunks.json
# ✅ Loaded 44 chunks from Sessia_chunks.json
# ✅ Loaded 8 chunks from Titan Coin_chunks.json
# ✅ Loaded 49 chunks from TimeBox_chunks.json
# ✅ Loaded 172 chunks from Orbs_chunks.json
# ✅ Loaded 37 chunks from Fantom_chunks.json
# ✅ Loaded 45 chunks from GXChain_chunks.json
# ✅ Loaded 38 chunks from BitcoiNote_chunks.json
# ✅ Loaded 23 chunks from Bodhi_chunks.json
# ✅ Loaded 39 chunks from Diamond Network_chunks.json
# ✅ Loaded 58 chunks from BipCoin_chunks.json
# ✅ Loaded 77 chunks from 1World_chunks.json
# ✅ Loaded 11 chunks from ESBC_chunks.json
# ✅ Loaded 68 chunks from CoinUs_chunks.json
# ✅ Loaded 46 chunks from Karma_chunks.json
# ✅ Loaded 38 chunks from Gnosis_chunks.json
# ✅ Loaded 28 chunks from Callisto Network_chunks.json
# ✅ Loaded 9 chunks from ECC_chunks.json
# ✅ Loaded 24 chunks from RED_chunks.json
# ✅ Loaded 28 chunks from No BS Crypto_chunks.json
# ✅ Loaded 12 chunks from XTRABYTES_chunks.json
# ✅ Loaded 52 chunks from Ripio Credit Network_chunks.json
# ✅ Loaded 76 chunks from VITE_chunks.json
# ✅ Loaded 34 chunks from Delphy_chunks.json
# ✅ Loaded 4 chunks from Sakura Bloom_chunks.json
# ✅ Loaded 15 chunks from Monero Classic_chunks.json
# ✅ Loaded 37 chunks from Tether_chunks.json
# ✅ Loaded 8 chunks from Lisk Machine Learning_chunks.json
# ✅ Loaded 17 chunks from SF Capital_chunks.json
# ✅ Loaded 36 chunks from Pylon Network_chunks.json
# ✅ Loaded 15 chunks from MedicCoin_chunks.json
# ✅ Loaded 91 chunks from GoByte_chunks.json
# ✅ Loaded 28 chunks from RefToken_chunks.json
# ✅ Loaded 40 chunks from ColossusXT_chunks.json
# ✅ Loaded 17 chunks from FootballCoin_chunks.json
# ✅ Loaded 25 chunks from Ticko_chunks.json
# ✅ Loaded 15 chunks from Substratum_chunks.json
# ✅ Loaded 30 chunks from Kyber_chunks.json
# ✅ Loaded 43 chunks from LockTrip_chunks.json
# ✅ Loaded 36 chunks from ssrn-3305362_processed_chunks.json
# ✅ Loaded 39 chunks from Bytecoin_chunks.json
# ✅ Loaded 32 chunks from GoChain_chunks.json
# ✅ Loaded 77 chunks from Modultrade_chunks.json
# ✅ Loaded 56 chunks from Bidooh_chunks.json
# ✅ Loaded 22 chunks from MEET.ONE_chunks.json
# ✅ Loaded 44 chunks from Uquid Coin_chunks.json
# ✅ Loaded 7 chunks from Ccore_chunks.json
# ✅ Loaded 61 chunks from Aditus-Whitepaper_extracted_chunks.json
# ✅ Loaded 50 chunks from HTMLCoin_chunks.json
# ✅ Loaded 17 chunks from Bitspark_chunks.json
# ✅ Loaded 24 chunks from ugChain_chunks.json
# ✅ Loaded 73 chunks from Alchemint_chunks.json
# ✅ Loaded 10 chunks from Oasis City_chunks.json
# ✅ Loaded 35 chunks from BioCoin_chunks.json
# ✅ Loaded 41 chunks from Tokia_chunks.json
# ✅ Loaded 97 chunks from Ark.io_chunks.json
# ✅ Loaded 35 chunks from NEVERDIE_chunks.json
# ✅ Loaded 30 chunks from QuarkChain_chunks.json
# ✅ Loaded 9 chunks from Pesetacoin_chunks.json
# ✅ Loaded 35 chunks from DIMCOIN_chunks.json
# ✅ Loaded 15 chunks from Bitcoin W Spectrum_chunks.json
# ✅ Loaded 77 chunks from Blocknet_chunks.json
# ✅ Loaded 22 chunks from MovieBloc_chunks.json
# ✅ Loaded 54 chunks from Libra Credit_chunks.json
# ✅ Loaded 68 chunks from Stox_chunks.json
# ✅ Loaded 37 chunks from PolySwarm_chunks.json
# ✅ Loaded 12 chunks from FREE Coin_chunks.json
# ✅ Loaded 59 chunks from iExec_chunks.json
# ✅ Loaded 33 chunks from Synthetix Network_chunks.json
# ✅ Loaded 33 chunks from Rotharium_chunks.json
# ✅ Loaded 78 chunks from Piction_chunks.json
# ✅ Loaded 31 chunks from Effect.ai_chunks.json
# ✅ Loaded 15 chunks from Expanse_chunks.json
# ✅ Loaded 14 chunks from Reddcoin_chunks.json
# ✅ Loaded 40 chunks from patientory_chunks.json
# ✅ Loaded 31 chunks from OneLedger_chunks.json
# ✅ Loaded 32 chunks from Electra_chunks.json
# ✅ Loaded 19 chunks from bitqy_chunks.json
# ✅ Loaded 60 chunks from Aidus_chunks.json
# ✅ Loaded 23 chunks from Experience points_chunks.json
# ✅ Loaded 10 chunks from TrezarCoin_chunks.json
# ✅ Loaded 44 chunks from StockChain_chunks.json
# ✅ Loaded 14 chunks from Gold Poker_chunks.json
# ✅ Loaded 47 chunks from Loopring_chunks.json
# ✅ Loaded 52 chunks from Celsius_chunks.json
# ✅ Loaded 65 chunks from Jarvis_chunks.json
# ✅ Loaded 78 chunks from Filecoin_chunks.json
# ✅ Loaded 39 chunks from Pathhive_chunks.json
# ✅ Loaded 24 chunks from Aladdin_chunks.json
# ✅ Loaded 27 chunks from COSS_chunks.json
# ✅ Loaded 8 chunks from PAXEX_chunks.json
# ✅ Loaded 16 chunks from STK_chunks.json
# ✅ Loaded 31 chunks from Etheroll_chunks.json
# ✅ Loaded 36 chunks from Nash Exchange Token_chunks.json
# ✅ Loaded 46 chunks from Hot_chunks.json
# ✅ Loaded 14 chunks from STASIS_chunks.json
# ✅ Loaded 18 chunks from OracleChain_chunks.json
# ✅ Loaded 54 chunks from BaaSid_chunks.json
# ✅ Loaded 8 chunks from Radium_chunks.json
# ✅ Loaded 31 chunks from Humanscape_chunks.json
# ✅ Loaded 20 chunks from Gexan_chunks.json
# ✅ Loaded 113 chunks from Aencoin_chunks.json
# ✅ Loaded 35 chunks from SwftCoin_chunks.json
# ✅ Loaded 15 chunks from Global Social Chain_chunks.json
# ✅ Loaded 19 chunks from FolmCoin_chunks.json
# ✅ Loaded 25 chunks from Playgroundz_chunks.json
# ✅ Loaded 57 chunks from DOS Network_chunks.json
# ✅ Loaded 31 chunks from ATBCoin_chunks.json
# ✅ Loaded 82 chunks from Aergo_chunks.json
# ✅ Loaded 2 chunks from BTCMoon_chunks.json
# ✅ Loaded 37 chunks from The Influence of Cryptocurrency on International_processed_chunks.json
# ✅ Loaded 30 chunks from Olyseum_chunks.json
# ✅ Loaded 27 chunks from Alphacat_chunks.json
# ✅ Loaded 29 chunks from Constellation_chunks.json
# ✅ Loaded 42 chunks from NoLimitCoin_chunks.json
# ✅ Loaded 76 chunks from osadc en_chunks.json
# ✅ Loaded 52 chunks from Traceability Chain_chunks.json
# ✅ Loaded 10 chunks from Target Coin_chunks.json
# ✅ Loaded 7 chunks from DashDiamond_chunks.json
# ✅ Loaded 20 chunks from AMARK_chunks.json
# ✅ Loaded 81 chunks from SpaceCoin_chunks.json
# ✅ Loaded 46 chunks from Iungo_chunks.json
# ✅ Loaded 83 chunks from Nebula AI_chunks.json
# ✅ Loaded 12 chunks from Micromines_chunks.json
# ✅ Loaded 1 chunks from YUKI_chunks.json
# ✅ Loaded 10 chunks from Kolion_chunks.json
# ✅ Loaded 91 chunks from Byteball_chunks.json
# ✅ Loaded 38 chunks from Whole Network_chunks.json
# ✅ Loaded 42 chunks from Band Protocol_chunks.json
# ✅ Loaded 27 chunks from Pibble_chunks.json
# ✅ Loaded 17 chunks from Cryptocurrency Returns_processed_chunks.json
# ✅ Loaded 102 chunks from Vega Protocol_chunks.json
# ✅ Loaded 17 chunks from Tracto_chunks.json
# ✅ Loaded 22 chunks from Hypnoxys_chunks.json
# ✅ Loaded 41 chunks from VeriBlock_chunks.json
# ✅ Loaded 31 chunks from CPChain_chunks.json
# ✅ Loaded 42 chunks from BitWhite_chunks.json
# ✅ Loaded 170 chunks from SMART VALOR_chunks.json
# ✅ Loaded 36 chunks from Kleros_chunks.json
# ✅ Loaded 18 chunks from DeusCoin_chunks.json
# ✅ Loaded 94 chunks from Ubricoin_chunks.json
# ✅ Loaded 38 chunks from ZenCash_chunks.json
# ✅ Loaded 25 chunks from blogs.cisco.com_cleaned_chunks.json
# ✅ Loaded 17 chunks from ZrCoin_chunks.json
# ✅ Loaded 14 chunks from Idex_chunks.json
# ✅ Loaded 56 chunks from Kuende_chunks.json
# ✅ Loaded 60 chunks from Afin_chunks.json
# ✅ Loaded 21 chunks from Lambda_chunks.json
# ✅ Loaded 28 chunks from BitStash_chunks.json
# ✅ Loaded 39 chunks from Salt Lending_chunks.json
# ✅ Loaded 45 chunks from Bittorrent_chunks.json
# ✅ Loaded 30 chunks from Lightpaycoin_chunks.json
# ✅ Loaded 56 chunks from Basic Attention Token_chunks.json
# ✅ Loaded 13 chunks from Livenodes_chunks.json
# ✅ Loaded 15 chunks from EPLUS Coin_chunks.json
# ✅ Loaded 68 chunks from BnkToTheFuture_chunks.json
# ✅ Loaded 16 chunks from Agrocoin_chunks.json
# ✅ Loaded 42 chunks from Yggdrash_chunks.json
# ✅ Loaded 44 chunks from Propy_chunks.json
# ✅ Loaded 39 chunks from Colu Local Network_chunks.json
# ✅ Loaded 33 chunks from VNT Chain_chunks.json
# ✅ Loaded 76 chunks from 0xcert_chunks.json
# ✅ Loaded 25 chunks from FuzeX_chunks.json
# ✅ Loaded 30 chunks from cravath_processed_chunks.json
# ✅ Loaded 52 chunks from HitChain_chunks.json
# ✅ Loaded 47 chunks from Medicalchain_chunks.json
# ✅ Loaded 9 chunks from PotCoin_chunks.json
# ✅ Loaded 44 chunks from Leverj_chunks.json
# ✅ Loaded 28 chunks from Petro_chunks.json
# ✅ Loaded 78 chunks from ONO_chunks.json
# ✅ Loaded 16 chunks from WazirX_chunks.json
# ✅ Loaded 10 chunks from Safecoin_chunks.json
# ✅ Loaded 157 chunks from Hedera pdf_chunks.json
# ✅ Loaded 13 chunks from True Chain_chunks.json
# ✅ Loaded 0 chunks from TaaS_chunks.json
# ✅ Loaded 53 chunks from HelloGold_chunks.json
# ✅ Loaded 31 chunks from Adtoken_chunks.json
# ✅ Loaded 82 chunks from Bulleon_chunks.json
# ✅ Loaded 22 chunks from Siacoin_chunks.json
# ✅ Loaded 59 chunks from ChainLink_chunks.json
# ✅ Loaded 79 chunks from Bezant_chunks.json
# ✅ Loaded 26 chunks from CFun_chunks.json
# ✅ Loaded 17 chunks from Ether Kingdom_chunks.json
# ✅ Loaded 37 chunks from hyperion_chunks.json
# ✅ Loaded 19 chunks from BFFDoom_chunks.json
# ✅ Loaded 58 chunks from Nxt_chunks.json
# ✅ Loaded 36 chunks from Etherlegends_chunks.json
# ✅ Loaded 30 chunks from EUNO Coin_chunks.json
# ✅ Loaded 6 chunks from Boolberry_chunks.json
# ✅ Loaded 25 chunks from Signals Network_chunks.json
# ✅ Loaded 48 chunks from Qbao_chunks.json
# ✅ Loaded 49 chunks from NEO_chunks.json
# ✅ Loaded 88 chunks from Future1coin_chunks.json
# ✅ Loaded 33 chunks from Primas_chunks.json
# ✅ Loaded 70 chunks from EQUI_chunks.json
# ✅ Loaded 53 chunks from Nexo_chunks.json
# ✅ Loaded 61 chunks from Mysterium_chunks.json
# ✅ Loaded 42 chunks from Spectiv_chunks.json
# ✅ Loaded 37 chunks from Request Network_chunks.json
# ✅ Loaded 27 chunks from Leo Token_chunks.json
# ✅ Loaded 22 chunks from Vezt_chunks.json
# ✅ Loaded 66 chunks from Phantasma_chunks.json
# ✅ Loaded 19 chunks from What are the legal rights and obligations of token holders__processed_chunks.json
# ✅ Loaded 14 chunks from VIBE_chunks.json
# ✅ Loaded 105 chunks from Cloud_chunks.json
# ✅ Loaded 32 chunks from ThunderCore_chunks.json
# ✅ Loaded 26 chunks from Jibrel Network_chunks.json
# ✅ Loaded 29 chunks from DreamTeam_chunks.json
# ✅ Loaded 54 chunks from ethereum classic_chunks.json
# ✅ Loaded 56 chunks from Fast Access Blockchain_chunks.json
# ✅ Loaded 26 chunks from Bitcoin Turbo Koin_chunks.json
# ✅ Loaded 16 chunks from aave-v2-whitepaper_extracted_chunks.json
# ✅ Loaded 63 chunks from Zcoin_chunks.json
# ✅ Loaded 15 chunks from HedgeTrade_chunks.json
# ✅ Loaded 43 chunks from Storiqa_chunks.json
# ✅ Loaded 78 chunks from Elrond_chunks.json
# ✅ Loaded 39 chunks from PayPie_chunks.json
# ✅ Loaded 99 chunks from Ocean Protocol_chunks.json
# ✅ Loaded 107 chunks from zvChain_chunks.json
# ✅ Loaded 47 chunks from Blockium_chunks.json
# ✅ Loaded 24 chunks from Asgard_chunks.json
# ✅ Loaded 51 chunks from Kubera Coin_chunks.json
# ✅ Loaded 52 chunks from Pledgecamp_chunks.json
# ✅ Loaded 8 chunks from Telcoin_chunks.json
# ✅ Loaded 48 chunks from Aurora_chunks.json
# ✅ Loaded 50 chunks from Usechain Token_chunks.json
# ✅ Loaded 57 chunks from SalPay_chunks.json
# ✅ Loaded 14 chunks from Pivot_chunks.json
# ✅ Loaded 35 chunks from Refereum_chunks.json
# ✅ Loaded 36 chunks from carVertical_chunks.json
# ✅ Loaded 14 chunks from Planet_chunks.json
# ✅ Loaded 141 chunks from Cardano_chunks.json
# ✅ Loaded 29 chunks from Silent Notary_chunks.json
# ✅ Loaded 17 chunks from Obitan Chain_chunks.json
# ✅ Loaded 6 chunks from BitBean_chunks.json
# ✅ Loaded 14 chunks from NOW Token_chunks.json
# ✅ Loaded 20 chunks from 108364 PLE_Digital Assets_Deck 290724_chunks.json
# ✅ Loaded 0 chunks from MaidSafeCoin_chunks.json
# ✅ Loaded 9 chunks from Polybius_chunks.json
# ✅ Loaded 18 chunks from GreenPower_chunks.json
# ✅ Loaded 73 chunks from QASH_chunks.json
# ✅ Loaded 16 chunks from Primalbase_chunks.json
# ✅ Loaded 12 chunks from Custody Token_chunks.json
# ✅ Loaded 53 chunks from 0chain_chunks.json
# ✅ Loaded 98 chunks from Envion_chunks.json
# ✅ Loaded 33 chunks from Transcodium_chunks.json
# ✅ Loaded 22 chunks from Bitcoiin2Gen_chunks.json
# ✅ Loaded 65 chunks from streamr_chunks.json
# ✅ Loaded 29 chunks from Eristica_chunks.json
# ✅ Loaded 25 chunks from DECENT_chunks.json
# ✅ Loaded 33 chunks from Rocket Pool_chunks.json
# ✅ Loaded 21 chunks from LinkEye_chunks.json
# ✅ Loaded 43 chunks from STEX_chunks.json
# ✅ Loaded 20 chunks from BlockMesh_chunks.json
# ✅ Loaded 26 chunks from Populous_chunks.json
# ✅ Loaded 20 chunks from Wavesbet_chunks.json
# ✅ Loaded 21 chunks from INMAX_chunks.json
# ✅ Loaded 40 chunks from Sentinel Protocol_chunks.json
# ✅ Loaded 11 chunks from OWNDATA_chunks.json
# ✅ Loaded 58 chunks from namecoin_chunks.json
# ✅ Loaded 18 chunks from Mithril Ore_chunks.json
# ✅ Loaded 13 chunks from MyBit Token_chunks.json
# ✅ Loaded 17 chunks from Tao_chunks.json
# ✅ Loaded 39 chunks from MixMarvel_chunks.json
# ✅ Loaded 19 chunks from Ecoreal Estate_chunks.json
# ✅ Loaded 58 chunks from Wanchain_chunks.json
# ✅ Loaded 33 chunks from eBoost_chunks.json
# ✅ Loaded 15 chunks from BitBay_chunks.json
# ✅ Loaded 7 chunks from Akroma_chunks.json
# ✅ Loaded 29 chunks from Achain_chunks.json
# ✅ Loaded 37 chunks from Flash_chunks.json
# ✅ Loaded 21 chunks from Neblio_chunks.json
# ✅ Loaded 21 chunks from Zilla_chunks.json
# ✅ Loaded 15 chunks from AdShares_chunks.json
# ✅ Loaded 11 chunks from Project Coin_chunks.json
# ✅ Loaded 143 chunks from Zcash_chunks.json
# ✅ Loaded 9 chunks from LeviarCoin_chunks.json
# ✅ Loaded 5 chunks from Magnet_chunks.json
# ✅ Loaded 21 chunks from Sugar Exchange_chunks.json
# ✅ Loaded 17 chunks from SafeInsure_chunks.json
# ✅ Loaded 37 chunks from Tierion_chunks.json
# ✅ Loaded 25 chunks from Maecenas_chunks.json
# ✅ Loaded 21 chunks from AiLink Token_chunks.json
# ✅ Loaded 22 chunks from Litecoin Cash_chunks.json
# ✅ Loaded 26 chunks from Qvolta_chunks.json
# ✅ Loaded 70 chunks from Ethereum_chunks.json
# ✅ Loaded 28 chunks from Tether Gold_chunks.json
# ✅ Loaded 18 chunks from FTX Token_chunks.json
# ✅ Loaded 50 chunks from OIO_chunks.json
# ✅ Loaded 23 chunks from Sociall_chunks.json
# ✅ Loaded 10 chunks from True USD_chunks.json
# ✅ Loaded 23 chunks from Datum_chunks.json
# ✅ Loaded 35 chunks from BitcoinHD_chunks.json
# ✅ Loaded 42 chunks from Hubii Network_chunks.json
# ✅ Loaded 18 chunks from Mithril_chunks.json
# ✅ Loaded 12 chunks from Ether Social Network_chunks.json
# ✅ Loaded 39 chunks from BetterBetting_chunks.json
# ✅ Loaded 30 chunks from DUO Network_chunks.json
# ✅ Loaded 55 chunks from Swarm_chunks.json
# ✅ Loaded 9 chunks from Phonecoin_chunks.json
# ✅ Loaded 16 chunks from Jesus Coin_chunks.json
# ✅ Loaded 36 chunks from White Standard_chunks.json
# ✅ Loaded 22 chunks from GridCoin_chunks.json
# ✅ Loaded 79 chunks from VouchForMe_chunks.json
# ✅ Loaded 3 chunks from www.integrityriskintl.com_cleaned_chunks.json
# ✅ Loaded 9 chunks from www.ftitechnology.com_cleaned_chunks.json
# ✅ Loaded 49 chunks from NOIZ_chunks.json
# ✅ Loaded 32 chunks from CrypViser_chunks.json
# ✅ Loaded 58 chunks from aelf_whitepaper_v1.2_extracted_chunks.json
# ✅ Loaded 43 chunks from botXcoin_chunks.json
# ✅ Loaded 47 chunks from TE FOOD_chunks.json
# ✅ Loaded 82 chunks from Vanta Network_chunks.json
# ✅ Loaded 144 chunks from SSRN-id4594467_chunks.json
# ✅ Loaded 47 chunks from Bismuth_chunks.json
# ✅ Loaded 61 chunks from Centrality_chunks.json
# ✅ Loaded 24 chunks from Ripple_chunks.json
# ✅ Loaded 39 chunks from Noah Coin_chunks.json
# ✅ Loaded 18 chunks from Traid_chunks.json
# ✅ Loaded 24 chunks from TeslaCoilCoin_chunks.json
# ✅ Loaded 41 chunks from Ink_chunks.json
# ✅ Loaded 19 chunks from OTCBTC Token_chunks.json
# ✅ Loaded 32 chunks from BitCoen_chunks.json
# ✅ Loaded 22 chunks from Stellar Gold_chunks.json
# ✅ Loaded 29 chunks from Bitcloud Pro_chunks.json
# ✅ Loaded 52 chunks from Hade Platform_chunks.json
# ✅ Loaded 54 chunks from Unibright_chunks.json
# ✅ Loaded 17 chunks from Binance_chunks.json
# ✅ Loaded 48 chunks from 24+Noel+B.+Agustin+et+al.,+pp.+269-281_processed_chunks.json
# ✅ Loaded 52 chunks from Cindicator_chunks.json
# ✅ Loaded 3 chunks from Thar Token_chunks.json
# ✅ Loaded 49 chunks from BitScreener_chunks.json
# ✅ Loaded 41 chunks from Pecunio_chunks.json
# ✅ Loaded 22 chunks from Path_chunks.json
# ✅ Loaded 62 chunks from KICKECOSYSTEM_chunks.json
# ✅ Loaded 74 chunks from IONChain_chunks.json
# ✅ Loaded 50 chunks from TV_chunks.json
# ✅ Loaded 41 chunks from EBCoin_chunks.json
# ✅ Loaded 41 chunks from Genaro Network_chunks.json
# ✅ Loaded 42 chunks from Enjin Coin_chunks.json
# ✅ Loaded 94 chunks from Platin_chunks.json
# ✅ Loaded 10 chunks from ZENZO_chunks.json
# ✅ Loaded 36 chunks from AeronWhitepaper_extracted_chunks.json
# ✅ Loaded 29 chunks from Zap_chunks.json
# ✅ Loaded 35 chunks from Genesis vision_chunks.json
# ✅ Loaded 57 chunks from Crypterium_chunks.json
# ✅ Loaded 0 chunks from Shivom_chunks.json
# ✅ Loaded 18 chunks from SagaCoin_chunks.json
# ✅ Loaded 22 chunks from Safeguard_chunks.json
# ✅ Loaded 93 chunks from Chromapolis_chunks.json
# ✅ Loaded 118 chunks from Cryptocean_chunks.json
# ✅ Loaded 95 chunks from DDKoin_chunks.json
# ✅ Loaded 29 chunks from Nervos_chunks.json
# ✅ Loaded 33 chunks from Havven_chunks.json
# ✅ Loaded 46 chunks from All Sports_chunks.json
# ✅ Loaded 27 chunks from ChatCoin_chunks.json
# ✅ Loaded 36 chunks from MOAC_chunks.json
# ✅ Loaded 33 chunks from MARK.SPACE_chunks.json
# ✅ Loaded 19 chunks from ABCC Token_chunks.json
# ✅ Loaded 81 chunks from Sweetbridge_chunks.json
# ✅ Loaded 13 chunks from HomeBlockCoin_chunks.json
# ✅ Loaded 30 chunks from Timicoin_chunks.json
# ✅ Loaded 30 chunks from Modum_chunks.json
# ✅ Loaded 51 chunks from WebDollar_chunks.json
# ✅ Loaded 6 chunks from CARDbuyers_chunks.json
# ✅ Loaded 32 chunks from Ambrosus_chunks.json
# ✅ Loaded 19 chunks from Lisk_chunks.json
# ✅ Loaded 110 chunks from FUSION_chunks.json
# ✅ Loaded 52 chunks from Muzika_chunks.json
# ✅ Loaded 15 chunks from InterCrone_chunks.json
# ✅ Loaded 23 chunks from BoatPilot_chunks.json
# ✅ Loaded 23 chunks from Luna Stars_chunks.json
# ✅ Loaded 22 chunks from USC_chunks.json
# ✅ Loaded 11 chunks from Coimatic_chunks.json
# ✅ Loaded 53 chunks from GSENetwork_chunks.json
# ✅ Loaded 19 chunks from vetting_guide_processed_chunks.json
# ✅ Loaded 77 chunks from SealChain_chunks.json
# ✅ Loaded 33 chunks from BlockCAT_chunks.json
# ✅ Loaded 66 chunks from SyncFab_chunks.json
# ✅ Loaded 20 chunks from Upfiring_chunks.json
# ✅ Loaded 43 chunks from REDFOXLABS_chunks.json
# ✅ Loaded 17 chunks from PoSToken_chunks.json
# ✅ Loaded 18 chunks from Beetle Coin_chunks.json
# ✅ Loaded 10 chunks from www.centrl.ai_cleaned_chunks.json
# ✅ Loaded 13 chunks from Eryllium_chunks.json
# ✅ Loaded 60 chunks from Bizkey_chunks.json
# ✅ Loaded 8 chunks from MESG_chunks.json
# ✅ Loaded 22 chunks from Lunyr_chunks.json
# ✅ Loaded 5 chunks from MMOCoin_chunks.json
# ✅ Loaded 45 chunks from Kambria_chunks.json
# ✅ Loaded 19 chunks from PlayFuel_chunks.json
# ✅ Loaded 11 chunks from FairCoin_chunks.json
# ✅ Loaded 56 chunks from Atlant_chunks.json
# ✅ Loaded 35 chunks from Trittium_chunks.json
# ✅ Loaded 22 chunks from wys Token_chunks.json
# ✅ Loaded 35 chunks from RealChain_chunks.json
# ✅ Loaded 74 chunks from information-14-00171_processed_chunks.json
# ✅ Loaded 26 chunks from Travelflex_chunks.json
# ✅ Loaded 23 chunks from Storm_chunks.json
# ✅ Loaded 9 chunks from Matic Network_chunks.json
# ✅ Loaded 19 chunks from Consentium_chunks.json
# ✅ Loaded 39 chunks from CyberVein_chunks.json
# ✅ Loaded 21 chunks from Probit_chunks.json
# ✅ Loaded 15 chunks from Billionaire Token_chunks.json
# ✅ Loaded 70 chunks from Decred_chunks.json
# ✅ Loaded 7 chunks from Hive_chunks.json
# ✅ Loaded 34 chunks from Themis_chunks.json
# ✅ Loaded 27 chunks from ZMINE_chunks.json
# ✅ Loaded 61 chunks from Wirex Token_chunks.json
# ✅ Loaded 51 chunks from Fetch_chunks.json
# ✅ Loaded 21 chunks from MinexCoin_chunks.json
# ✅ Loaded 38 chunks from Perlin_chunks.json
# ✅ Loaded 46 chunks from Reserve Stabilization Protocol_chunks.json
# ✅ Loaded 57 chunks from Bitsdaq_chunks.json
# ✅ Loaded 55 chunks from NapoleonX_chunks.json
# ✅ Loaded 35 chunks from Farad_chunks.json
# ✅ Loaded 32 chunks from W Green Pay_chunks.json
# ✅ Loaded 46 chunks from QuadrantProtocol_chunks.json
# ✅ Loaded 22 chunks from Blue Whale_chunks.json
# ✅ Loaded 44 chunks from VINchain_chunks.json
# ✅ Loaded 27 chunks from Etherinc_chunks.json
# ✅ Loaded 19 chunks from InsurChain_chunks.json
# ✅ Loaded 128 chunks from Celer Network_chunks.json
# ✅ Loaded 16 chunks from Pascal Coin_chunks.json
# ✅ Loaded 86 chunks from SHPING_chunks.json
# ✅ Loaded 9 chunks from Raiden Network_chunks.json
# ✅ Loaded 31 chunks from Eterbase_chunks.json
# ✅ Loaded 19 chunks from X8X Token_chunks.json
# ✅ Loaded 54 chunks from DxChain_chunks.json
# ✅ Loaded 28 chunks from Ifoods Chain_chunks.json
# ✅ Loaded 37 chunks from Folding Coin_chunks.json
# ✅ Loaded 44 chunks from Prometeus_chunks.json
# ✅ Loaded 52 chunks from Playkey_chunks.json
# ✅ Loaded 39 chunks from Tripio_chunks.json
# ✅ Loaded 28 chunks from XRT token_chunks.json
# ✅ Loaded 74 chunks from Ardor_chunks.json
# ✅ Loaded 40 chunks from Dock_chunks.json
# ✅ Loaded 40 chunks from Xaurum_chunks.json
# ✅ Loaded 49 chunks from Blockstack_chunks.json
# ✅ Loaded 51 chunks from Zeepin_chunks.json
# ✅ Loaded 23 chunks from Ravencoin_chunks.json
# ✅ Loaded 35 chunks from Shard_chunks.json
# ✅ Loaded 25 chunks from wetoken_chunks.json
# ✅ Loaded 43 chunks from OATH protocol_chunks.json
# ✅ Loaded 40 chunks from GoWithMi_chunks.json
# ✅ Loaded 71 chunks from Sentinel_chunks.json
# ✅ Loaded 64 chunks from Chiliz_chunks.json
# ✅ Loaded 124 chunks from Impleum_chunks.json
# ✅ Loaded 46 chunks from DAOstack_chunks.json
# ✅ Loaded 30 chunks from Etherparty_chunks.json
# ✅ Loaded 7 chunks from Numeraire_chunks.json
# ✅ Loaded 40 chunks from Zeusshield_chunks.json
# ✅ Loaded 25 chunks from Patron_chunks.json
# ✅ Loaded 47 chunks from BonusCloud_chunks.json
# ✅ Loaded 18 chunks from AuroraCoin_chunks.json
# ✅ Loaded 60 chunks from HEAT_chunks.json
# ✅ Loaded 43 chunks from OneRoot Network_chunks.json
# ✅ Loaded 53 chunks from wagerr_chunks.json
# ✅ Loaded 44 chunks from Dapp Token_chunks.json
# ✅ Loaded 0 chunks from WaBi_chunks.json
# ✅ Loaded 33 chunks from Couchain_chunks.json
# ✅ Loaded 13 chunks from GateChain_chunks.json
# ✅ Loaded 40 chunks from GameCredits_chunks.json
# ✅ Loaded 43 chunks from Egretia_chunks.json
# ✅ Loaded 5 chunks from alphacoin_chunks.json
# ✅ Loaded 56 chunks from MEXC Token_chunks.json
# ✅ Loaded 33 chunks from CannaCoin_chunks.json
# ✅ Loaded 63 chunks from HashCoin_chunks.json
# ✅ Loaded 35 chunks from TTC Protocol_chunks.json
# ✅ Loaded 34 chunks from Espers_chunks.json
# ✅ Loaded 50 chunks from GAMB_chunks.json
# ✅ Loaded 24 chunks from Trinity_chunks.json
# ✅ Loaded 28 chunks from YOYOW_chunks.json
# ✅ Loaded 44 chunks from Concierge Coin_chunks.json
# ✅ Loaded 14 chunks from Payfair_chunks.json
# ✅ Loaded 55 chunks from CYBR Token_chunks.json
# ✅ Loaded 12 chunks from MoneroV_chunks.json
# ✅ Loaded 80 chunks from RightMesh_chunks.json
# ✅ Loaded 23 chunks from MTC Mesh Network_chunks.json
# ✅ Loaded 8 chunks from Bgogo token_chunks.json
# ✅ Loaded 16 chunks from CompoundEthereum_chunks.json
# ✅ Loaded 38 chunks from Thrive Token_chunks.json
# ✅ Loaded 2 chunks from Parachute_chunks.json
# ✅ Loaded 64 chunks from Rate3_chunks.json
# ✅ Loaded 54 chunks from APOT_chunks.json
# ✅ Loaded 59 chunks from Rento_chunks.json
# ✅ Loaded 59 chunks from Rentberry_chunks.json
# ✅ Loaded 82 chunks from SingularityNET_chunks.json
# ✅ Loaded 45 chunks from SpaceChain_chunks.json
# ✅ Loaded 42 chunks from Linda_chunks.json
# ✅ Loaded 26 chunks from Voise_chunks.json
# ✅ Loaded 14 chunks from ELTCOIN_chunks.json
# ✅ Loaded 31 chunks from QuasarCoin_chunks.json
# ✅ Loaded 44 chunks from Power Ledger_chunks.json
# ✅ Loaded 8 chunks from ROIyal Coin_chunks.json
# ✅ Loaded 54 chunks from Safein_chunks.json
# ✅ Loaded 49 chunks from Seele_chunks.json
# ✅ Loaded 41 chunks from Welltrado_chunks.json
# ✅ Loaded 23 chunks from IntenseCoin_chunks.json
# ✅ Loaded 32 chunks from LoyalCoin_chunks.json
# ✅ Loaded 77 chunks from Covesting_chunks.json
# ✅ Loaded 43 chunks from Capdax_chunks.json
# ✅ Loaded 9 chunks from DraftCoin_chunks.json
# ✅ Loaded 27 chunks from Fleta_chunks.json
# ✅ Loaded 22 chunks from Nectar_chunks.json
# ✅ Loaded 24 chunks from Wrapped Bitcoin_chunks.json
# ✅ Loaded 36 chunks from BitUP_chunks.json
# ✅ Loaded 64 chunks from Essentia_chunks.json
# ✅ Loaded 26 chunks from XPA_chunks.json
# ✅ Loaded 92 chunks from Cocos BCX_chunks.json
# ✅ Loaded 20 chunks from Monster Byte_chunks.json
# ✅ Loaded 43 chunks from AdEx-Whitepaper-v.7_extracted_chunks.json
# ✅ Loaded 28 chunks from Innovative Bioresearch Classic_chunks.json
# ✅ Loaded 20 chunks from Paxos_chunks.json
# ✅ Loaded 9 chunks from ACRE_chunks.json
# ✅ Loaded 22 chunks from Niobium Coin_chunks.json
# ✅ Loaded 142 chunks from Vechain_chunks.json
# ✅ Loaded 27 chunks from MFCoin_chunks.json
# ✅ Loaded 9 chunks from Repme_chunks.json
# ✅ Loaded 14 chunks from SHIELD_chunks.json
# ✅ Loaded 8 chunks from GlassCoin_chunks.json
# ✅ Loaded 9 chunks from SpiderVPS_chunks.json
# ✅ Loaded 31 chunks from Wild Crypto_chunks.json
# ✅ Loaded 31 chunks from Coinlancer_chunks.json
# ✅ Loaded 18 chunks from x42_chunks.json
# ✅ Loaded 13 chunks from Vitae_chunks.json
# ✅ Loaded 32 chunks from MobilinkToken_chunks.json
# ✅ Loaded 14 chunks from Elastic_chunks.json
# ✅ Loaded 1 chunks from sample_chunks.json
# ✅ Loaded 21 chunks from Digital Fantasy Sports_chunks.json
# ✅ Loaded 67 chunks from Agrello_chunks.json
# ✅ Loaded 32 chunks from Status_chunks.json
# ✅ Loaded 37 chunks from SoPay_chunks.json
# ✅ Loaded 48 chunks from WPP TOKEN_chunks.json
# ✅ Loaded 15 chunks from Mozo Token_chunks.json
# ✅ Loaded 17 chunks from Matchpool_chunks.json
# ✅ Loaded 39 chunks from CryptoNote Coin_chunks.json
# ✅ Loaded 44 chunks from Electroneum_chunks.json
# ✅ Loaded 26 chunks from Diamond_chunks.json
# ✅ Loaded 53 chunks from Typerium_chunks.json
# ✅ Loaded 15 chunks from Waves_chunks.json
# ✅ Loaded 56 chunks from Waltonchain_chunks.json
# ✅ Loaded 13 chunks from Bitblocks_chunks.json
# ✅ Loaded 38 chunks from YOUChain_chunks.json
# ✅ Loaded 54 chunks from AMO Coin_chunks.json
# ✅ Loaded 49 chunks from Skychain_chunks.json
# ✅ Loaded 35 chunks from XinFin Network_chunks.json
# ✅ Loaded 60 chunks from TenX_chunks.json
# ✅ Loaded 23 chunks from SmartMesh_chunks.json
# ✅ Loaded 32 chunks from IQeon_chunks.json
# ✅ Loaded 61 chunks from Formosa Financial_chunks.json
# ✅ Loaded 32 chunks from EnterCoin_chunks.json
# ✅ Loaded 88 chunks from Robotina_chunks.json
# ✅ Loaded 8 chunks from bitaml.com_cleaned_chunks.json
# ✅ Loaded 33 chunks from Boutspro_chunks.json
# ✅ Loaded 5 chunks from DogeCash_chunks.json
# ✅ Loaded 70 chunks from Sparkster_chunks.json
# ✅ Loaded 49 chunks from Internet Node Token_chunks.json
# ✅ Loaded 11 chunks from SIBCoin_chunks.json
# ✅ Loaded 42 chunks from EOS.IO_chunks.json
# ✅ Loaded 39 chunks from LHT usdx_chunks.json
# ✅ Loaded 34 chunks from Origami_chunks.json
# ✅ Loaded 27 chunks from Republic Protocol_chunks.json
# ✅ Loaded 32 chunks from messe_chunks.json
# ✅ Loaded 51 chunks from Aitheon_chunks.json
# ✅ Loaded 19 chunks from BitShares_chunks.json
# ✅ Loaded 37 chunks from UltraNote Coin_chunks.json
# ✅ Loaded 129 chunks from COTI_chunks.json
# ✅ Loaded 64 chunks from evedo_chunks.json
# ✅ Loaded 49 chunks from TokenCard_chunks.json
# ✅ Loaded 39 chunks from FidentiaX_chunks.json
# ✅ Loaded 29 chunks from Webcoin_chunks.json
# ✅ Loaded 4 chunks from Arionum_chunks.json
# ✅ Loaded 95 chunks from MenaPay_chunks.json
# ✅ Loaded 26 chunks from apM Coin_chunks.json
# ✅ Loaded 39 chunks from BunnyToken_chunks.json
# ✅ Loaded 70 chunks from BlockMason Credit_chunks.json
# ✅ Loaded 71 chunks from Sp8de_chunks.json
# ✅ Loaded 6 chunks from DogeCoin_chunks.json
# ✅ Loaded 62 chunks from Factom_chunks.json
# ✅ Loaded 33 chunks from Swipe_chunks.json
# ✅ Loaded 42 chunks from Merculet_chunks.json
# ✅ Loaded 79 chunks from Apollon_chunks.json
# ✅ Loaded 38 chunks from TrueFlip_chunks.json
# ✅ Loaded 38 chunks from Ultra_chunks.json
# ✅ Loaded 61 chunks from Six Domain Chain_chunks.json
# ✅ Loaded 67 chunks from WinToken_chunks.json
# ✅ Loaded 28 chunks from huddl_chunks.json
# ✅ Loaded 28 chunks from Bitcoin Green_chunks.json
# ✅ Loaded 14 chunks from Uos_chunks.json
# ✅ Loaded 74 chunks from CEDEX_chunks.json
# ✅ Loaded 68 chunks from CNNS_chunks.json
# ✅ Loaded 28 chunks from WHEN Token_chunks.json
# ✅ Loaded 11 chunks from VikkyToken_chunks.json
# ✅ Loaded 8 chunks from WhaleCoin_chunks.json
# ✅ Loaded 42 chunks from DREP_chunks.json
# ✅ Loaded 29 chunks from DigitalNote_chunks.json
# ✅ Loaded 27 chunks from Omnitude_chunks.json
# ✅ Loaded 38 chunks from ALQO_chunks.json
# ✅ Loaded 51 chunks from Almeela_chunks.json
# ✅ Loaded 14 chunks from Cybermiles_chunks.json
# ✅ Loaded 73 chunks from Metronome_chunks.json
# ✅ Loaded 2 chunks from HyperLoot_chunks.json
# ✅ Loaded 65 chunks from Appcoins_chunks.json
# ✅ Loaded 105 chunks from StarterCoin_chunks.json
# ✅ Loaded 32 chunks from RECORD_chunks.json
# ✅ Loaded 25 chunks from CommerceBlock_chunks.json
# ✅ Loaded 25 chunks from PlusCoin_chunks.json
# ✅ Loaded 10 chunks from NANJCOIN_chunks.json
# ✅ Loaded 34 chunks from Humaniq_chunks.json
# ✅ Loaded 44 chunks from AI Doctor_chunks.json
# ✅ Loaded 46 chunks from Po.et_chunks.json
# ✅ Loaded 10 chunks from EthereumX_chunks.json
# ✅ Loaded 37 chunks from Linkey_chunks.json
# ✅ Loaded 45 chunks from ZeuxCoin_chunks.json
# ✅ Loaded 35 chunks from Tigereum_chunks.json
# ✅ Loaded 48 chunks from aion_chunks.json
# ✅ Loaded 88 chunks from GET Protocol_chunks.json
# ✅ Loaded 16 chunks from NeoWorld Cash_chunks.json
# ✅ Loaded 29 chunks from Tezos_chunks.json
# ✅ Loaded 74 chunks from Ignis_chunks.json
# ✅ Loaded 35 chunks from BeeKan_chunks.json
# ✅ Loaded 28 chunks from Amino Network_chunks.json
# ✅ Loaded 51 chunks from Bluzelle_chunks.json
# ✅ Loaded 22 chunks from ZCore_chunks.json
# ✅ Loaded 22 chunks from TimeMoney_chunks.json
# ✅ Loaded 81 chunks from HNB_chunks.json
# ✅ Loaded 40 chunks from aeternity_chunks.json
# ✅ Loaded 25 chunks from Switcheo_chunks.json
# ✅ Loaded 23 chunks from NOIA Network_chunks.json
# ✅ Loaded 27 chunks from Noku_chunks.json
# ✅ Loaded 26 chunks from BookingTokenUnit_chunks.json
# ✅ Loaded 10 chunks from The WoT.City original_chunks.json
# ✅ Loaded 25 chunks from Russian Miner Coin_chunks.json
# ✅ Loaded 72 chunks from TaTaTu_chunks.json
# ✅ Loaded 48 chunks from TRON_chunks.json
# ✅ Loaded 28 chunks from BiNGOFun_chunks.json
# ✅ Loaded 25 chunks from BHP Network_chunks.json
# ✅ Loaded 15 chunks from GanjaCoin_chunks.json
# ✅ Loaded 32 chunks from TomoChain_chunks.json
# ✅ Loaded 45 chunks from Dentacoin_chunks.json
# ✅ Loaded 14 chunks from Mero_chunks.json
# ✅ Loaded 35 chunks from ShipChain_chunks.json
# ✅ Loaded 43 chunks from OAX_chunks.json
# ✅ Loaded 30 chunks from Crycash_chunks.json
# ✅ Loaded 46 chunks from Docademic_chunks.json
# ✅ Loaded 32 chunks from Kin_chunks.json
# ✅ Loaded 36 chunks from ABLE_chunks.json
# ✅ Loaded 26 chunks from vTorrent_chunks.json
# ✅ Loaded 36 chunks from MediShares_chunks.json
# ✅ Loaded 20 chunks from SRCoin_chunks.json
# ✅ Loaded 79 chunks from Horizen_chunks.json
# ✅ Loaded 11 chunks from Altlas Protocol_chunks.json
# ✅ Loaded 27 chunks from Kryll_chunks.json
# ✅ Loaded 36 chunks from StableUSD_chunks.json
# ✅ Loaded 19 chunks from Graviocoin_chunks.json
# ✅ Loaded 99 chunks from Quant_chunks.json
# ✅ Loaded 7 chunks from CryptoPing_chunks.json
# ✅ Loaded 17 chunks from tagz_chunks.json
# ✅ Loaded 65 chunks from iotex_chunks.json
# ✅ Loaded 26 chunks from REPO_chunks.json
# ✅ Loaded 22 chunks from LGO Exchange_chunks.json
# ✅ Loaded 23 chunks from Unification_chunks.json
# ✅ Loaded 32 chunks from ProChain_chunks.json
# ✅ Loaded 44 chunks from Friendz_chunks.json
# ✅ Loaded 63 chunks from ey-token-due-diligence-a-structured-approach-to-evaluate-digital-asset-risk (1)_chunks.json
# ✅ Loaded 33 chunks from Volume Network_chunks.json
# ✅ Loaded 23 chunks from Bulwark_chunks.json
# ✅ Loaded 1 chunks from Bastonet_chunks.json
# ✅ Loaded 53 chunks from Caspian_chunks.json
# ✅ Loaded 40 chunks from Lympo_chunks.json
# ✅ Loaded 135 chunks from DasCoin_chunks.json
# ✅ Loaded 9 chunks from ArtByte_chunks.json
# ✅ Loaded 88 chunks from Gibraltar_chunks.json
# ✅ Loaded 32 chunks from Credits_chunks.json
# ✅ Loaded 47 chunks from Taklimakan Network_chunks.json
# ✅ Loaded 32 chunks from OriginTrail_chunks.json
# ✅ Loaded 17 chunks from Hero_chunks.json
# ✅ Loaded 46 chunks from Davinci Coin_chunks.json
# ✅ Loaded 77 chunks from Level Up Coin_chunks.json
# ✅ Loaded 42 chunks from Content and Ad Network_chunks.json
# ✅ Loaded 7 chunks from InnovaMinex_chunks.json
# ✅ Loaded 43 chunks from adbank_chunks.json
# ✅ Loaded 66 chunks from AdEx_chunks.json
# ✅ Loaded 62 chunks from WePower_chunks.json
# ✅ Loaded 27 chunks from whitepaper_v_2.01_eng_extracted_chunks.json
# ✅ Loaded 62 chunks from CYCLEAN_chunks.json
# ✅ Loaded 31 chunks from PlayerOne_chunks.json
# ✅ Loaded 28 chunks from Hacken_chunks.json
# ✅ Loaded 15 chunks from Abjcoin_chunks.json
# ✅ Loaded 43 chunks from Golem_chunks.json
# ✅ Loaded 47 chunks from HYCON_chunks.json
# ✅ Loaded 26 chunks from TrakInvest_chunks.json
# ✅ Loaded 40 chunks from cryptopay_chunks.json
# ✅ Loaded 17 chunks from Agrolot_chunks.json
# ✅ Loaded 31 chunks from Chronologic_chunks.json
# ✅ Loaded 9 chunks from EDC Blockchain_chunks.json
# ✅ Loaded 9 chunks from Cajutel_chunks.json
# ✅ Loaded 49 chunks from travala_chunks.json
# ✅ Loaded 30 chunks from IHT Real Estate Protocol_chunks.json
# ✅ Loaded 38 chunks from Stratis_chunks.json
# ✅ Loaded 64 chunks from XTRD_chunks.json
# ✅ Loaded 120 chunks from YottaChain_chunks.json
# ✅ Loaded 44 chunks from Qiibee_chunks.json
# ✅ Loaded 30 chunks from DashCash_chunks.json
# ✅ Loaded 66 chunks from DeepOnion_chunks.json
# ✅ Loaded 27 chunks from Dinero_chunks.json
# ✅ Loaded 12 chunks from CryptoCarbon_chunks.json
# ✅ Loaded 196 chunks from komodo_chunks.json
# ✅ Loaded 34 chunks from HalalChain_chunks.json
# ✅ Loaded 5 chunks from Wowoo_chunks.json
# ✅ Loaded 35 chunks from OneGame_chunks.json
# ✅ Loaded 34 chunks from BidiPass_chunks.json
# ✅ Loaded 12 chunks from bitJob_chunks.json
# ✅ Loaded 23 chunks from Operational Due Diligence on crypto_processed_chunks.json
# ✅ Loaded 21 chunks from DOWCOIN_chunks.json
# ✅ Loaded 21 chunks from Jewel_chunks.json
# ✅ Loaded 20 chunks from EncryptoTel_chunks.json
# ✅ Loaded 26 chunks from Credit_chunks.json
# ✅ Loaded 56 chunks from Dai_chunks.json
# ✅ Loaded 25 chunks from LIFE_chunks.json
# ✅ Loaded 5 chunks from Mothership_chunks.json
# ✅ Loaded 12 chunks from Absolute_chunks.json
# ✅ Loaded 9 chunks from Uptrennd_chunks.json
# ✅ Loaded 18 chunks from YEE_chunks.json
# ✅ Loaded 13 chunks from Peercoin_chunks.json
# ✅ Loaded 38 chunks from U Network_chunks.json
# ✅ Loaded 69 chunks from Stellar Classic_chunks.json
# ✅ Loaded 33 chunks from EthBet_chunks.json
# ✅ Loaded 64 chunks from Datawallet_chunks.json
# ✅ Loaded 48 chunks from Canlead_chunks.json
# ✅ Loaded 38 chunks from OmiseGO_chunks.json
# ✅ Loaded 18 chunks from Peerplays_chunks.json
# ✅ Loaded 44 chunks from Harmony_chunks.json
# ✅ Loaded 27 chunks from PWR Coin_chunks.json
# ✅ Loaded 13 chunks from Gold Bits Coin_chunks.json
# ✅ Loaded 58 chunks from Plair_chunks.json
# ✅ Loaded 30 chunks from Newton_chunks.json
# ✅ Loaded 20 chunks from Aave_chunks.json
# ✅ Loaded 37 chunks from Viberate_chunks.json
# ✅ Loaded 11 chunks from Bitdeal_chunks.json
# ✅ Loaded 73 chunks from MineBee_chunks.json
# ✅ Loaded 17 chunks from Soverain_chunks.json
# ✅ Loaded 22 chunks from Dimension Chain_chunks.json
# ✅ Loaded 14 chunks from AirSwap_chunks.json
# ✅ Loaded 79 chunks from Verasity_chunks.json
# ✅ Loaded 25 chunks from Cutcoin_chunks.json
# ✅ Loaded 36 chunks from PressOne_chunks.json
# ✅ Loaded 18 chunks from LiteDoge_chunks.json
# ✅ Loaded 33 chunks from Bounty0x_chunks.json
# ✅ Loaded 51 chunks from Tap_chunks.json
# ✅ Loaded 26 chunks from Fire Lotto_chunks.json
# ✅ Loaded 73 chunks from Metaverse ETP_chunks.json
# ✅ Loaded 61 chunks from SDChain_chunks.json
# ✅ Loaded 20 chunks from BitNewChain_chunks.json
# ✅ Loaded 25 chunks from GlitzKoin_chunks.json
# ✅ Loaded 38 chunks from Beaxy Exchange_chunks.json
# ✅ Loaded 8 chunks from TopChain_chunks.json
# ✅ Loaded 21 chunks from Pixie Coin_chunks.json
# ✅ Loaded 13 chunks from Solve Care_chunks.json
# ✅ Loaded 56 chunks from Locus Chain_chunks.json
# ✅ Loaded 50 chunks from Decentralized Machine Learning_chunks.json
# ✅ Loaded 60 chunks from CEEK VR_chunks.json
# ✅ Loaded 24 chunks from LEOcoin_chunks.json
# ✅ Loaded 47 chunks from Cryptaur_chunks.json
# ✅ Loaded 70 chunks from Flowchain_chunks.json
# ✅ Loaded 38 chunks from Storeum_chunks.json
# ✅ Loaded 7 chunks from Ignition_chunks.json
# ✅ Loaded 28 chunks from Lucky Seven_chunks.json
# ✅ Loaded 52 chunks from Clipper Coin_chunks.json
# ✅ Loaded 30 chunks from AgrolifeCoin_chunks.json
# ✅ Loaded 27 chunks from Augur_chunks.json
# ✅ Loaded 18 chunks from ClearPoll_chunks.json
# ✅ Loaded 55 chunks from Truegame_chunks.json
# ✅ Loaded 30 chunks from 0x_chunks.json
# ✅ Loaded 83 chunks from LTO Network_chunks.json
# ✅ Loaded 45 chunks from SKYFchain_chunks.json
# ✅ Loaded 82 chunks from S4FE_chunks.json
# ✅ Loaded 46 chunks from DAEX_chunks.json
# ✅ Loaded 24 chunks from Red Pulse_chunks.json
# ✅ Loaded 77 chunks from Datarius_chunks.json
# ✅ Loaded 37 chunks from Aventus_chunks.json
# ✅ Loaded 12 chunks from www.sanctions.io_cleaned_chunks.json
# ✅ Loaded 6 chunks from Gainer_chunks.json
# ✅ Loaded 111 chunks from ICON_chunks.json
# ✅ Loaded 7 chunks from Versess_chunks.json
# ✅ Loaded 27 chunks from Rupiah Token_chunks.json
# ✅ Loaded 28 chunks from Alibabacoin_chunks.json
# ✅ Loaded 10 chunks from Aryacoin_chunks.json
# ✅ Loaded 66 chunks from Fabric Token_chunks.json
# ✅ Loaded 8 chunks from Condominium_chunks.json
# ✅ Loaded 3 chunks from FuckToken_chunks.json
# ✅ Loaded 55 chunks from Fabrk_chunks.json
# ✅ Loaded 38 chunks from PlayChip_chunks.json
# ✅ Loaded 9 chunks from Mirai_chunks.json
# ✅ Loaded 35 chunks from NIX_chunks.json
# ✅ Loaded 34 chunks from Blackmoon_chunks.json
# ✅ Loaded 68 chunks from MetaHash_chunks.json
# ✅ Loaded 8 chunks from BrazilCoin_chunks.json
# ✅ Loaded 48 chunks from Yap Stone_chunks.json
# ✅ Loaded 34 chunks from Matrix AI Network_chunks.json
# ✅ Loaded 61 chunks from NEM_chunks.json
# ✅ Loaded 29 chunks from Mossland_chunks.json
# ✅ Loaded 55 chunks from Holo_chunks.json
# ✅ Loaded 45 chunks from ParkGene_chunks.json
# ✅ Loaded 79 chunks from Krypton Galaxy Coin_chunks.json
# ✅ Loaded 18 chunks from bitcoin_chunks.json
# ✅ Loaded 60 chunks from Molecular Future_chunks.json
# ✅ Loaded 23 chunks from OptiToken_chunks.json
# ✅ Loaded 4 chunks from qchi_chunks.json
# ✅ Loaded 23 chunks from Power_chunks.json
# ✅ Loaded 25 chunks from Pura_chunks.json
# ✅ Loaded 38 chunks from 1110830.1.0 Introduction to Digital Assets for Institutional Investors_FINAL_0_chunks.json
# ✅ Loaded 16 chunks from Ezoow_chunks.json
# ✅ Loaded 59 chunks from Linfinity_chunks.json
# ✅ Loaded 16 chunks from Arepacoin_chunks.json
# ✅ Loaded 16 chunks from Peerguess_chunks.json
# ✅ Loaded 17 chunks from Rally_chunks.json
# ✅ Loaded 49 chunks from MultiVAC Tech_chunks.json
# ✅ Loaded 76 chunks from Levolution_chunks.json
# ✅ Loaded 39 chunks from Beldex_chunks.json
# ✅ Loaded 53 chunks from AceD_chunks.json
# ✅ Loaded 55 chunks from membrana_chunks.json
# ✅ Loaded 81 chunks from Tokenomy_chunks.json
# ✅ Loaded 31 chunks from Sola Token_chunks.json
# ✅ Loaded 94 chunks from Polkadot_chunks.json
# ✅ Loaded 8 chunks from BlackCoin_chunks.json
# ✅ Loaded 78 chunks from PumaPay_chunks.json
# ✅ Loaded 31 chunks from Electronic Energy Coin_chunks.json
# ✅ Loaded 34 chunks from Paytomat_chunks.json
# ✅ Loaded 29 chunks from DecentBet_chunks.json
# ✅ Loaded 42 chunks from Bee Token_chunks.json
# ✅ Loaded 44 chunks from IOTA_chunks.json
# ✅ Loaded 64 chunks from BCDiploma_chunks.json
# ✅ Loaded 101 chunks from WEF_Digital_Assets_Regulation_2024_cleaned_chunks.json
# ✅ Loaded 104 chunks from NAGA_chunks.json
# ✅ Loaded 44 chunks from WaykiChain_chunks.json
# ✅ Loaded 29 chunks from Measurable Data Token_chunks.json
# ✅ Loaded 18 chunks from Hempcoin_chunks.json
# ✅ Loaded 33 chunks from Mytoken_chunks.json
# ✅ Loaded 15 chunks from Shivers_chunks.json
# ✅ Loaded 54 chunks from xCrypt_chunks.json
# ✅ Loaded 39 chunks from CHEX_chunks.json
# ✅ Loaded 18 chunks from Litecoin_chunks.json
# ✅ Loaded 73 chunks from Acute Angle Cloud_chunks.json
# ✅ Loaded 71 chunks from PUBLYTO_chunks.json
# ✅ Loaded 9 chunks from Fitrova_chunks.json
# ✅ Loaded 71 chunks from FansTime_chunks.json
# ✅ Loaded 30 chunks from vestchain_chunks.json
# ✅ Loaded 20 chunks from IP Exchange_chunks.json
# ✅ Loaded 51 chunks from Aditus_chunks.json
# ✅ Loaded 38 chunks from WINCOIN_chunks.json
# ✅ Loaded 41 chunks from Powerchain_chunks.json
# ✅ Loaded 32 chunks from Quantum Resistance Ledger_chunks.json
# ✅ Loaded 25 chunks from district0x_chunks.json
# ✅ Loaded 22 chunks from NewYork Exchange Coin_chunks.json
# ✅ Loaded 53 chunks from SakuraCoin_chunks.json
# ✅ Loaded 34 chunks from Enigma_chunks.json
# ✅ Loaded 18 chunks from ILCoin_chunks.json
# ✅ Loaded 42 chunks from XYO Network_chunks.json
# ✅ Loaded 9 chunks from Bela_chunks.json
# ✅ Loaded 64 chunks from AICHAIN_chunks.json
# ✅ Loaded 79 chunks from FunFair_chunks.json
# ✅ Loaded 5 chunks from Block Logic_chunks.json
# ✅ Loaded 30 chunks from Stem Cell Coin_chunks.json
# ✅ Loaded 126 chunks from MGC_chunks.json
# ✅ Loaded 44 chunks from Castle_chunks.json
# ✅ Loaded 20 chunks from Polis_chunks.json
# ✅ Loaded 23 chunks from Maya Preferred_chunks.json
# ✅ Loaded 34 chunks from Swace_chunks.json
# ✅ Loaded 17 chunks from Tera_chunks.json
# ✅ Loaded 47 chunks from Harvest Masternode Coin_chunks.json
# ✅ Loaded 53 chunks from beat_chunks.json
# ✅ Loaded 62 chunks from Bottos_chunks.json
# ✅ Loaded 53 chunks from Bethereum_chunks.json
# ✅ Loaded 5 chunks from Phi_chunks.json
# ✅ Loaded 11 chunks from PiplCoin_chunks.json
# ✅ Loaded 5 chunks from Pedity_chunks.json
# ✅ Loaded 29 chunks from Edgeless_chunks.json
# ✅ Loaded 23 chunks from Facebook Libra_chunks.json
# ✅ Loaded 29 chunks from Ethos_chunks.json
# ✅ Loaded 40 chunks from Sharpay_chunks.json
# ✅ Loaded 44 chunks from Opennity_chunks.json
# ✅ Loaded 41 chunks from Lykke_chunks.json
# ✅ Loaded 43 chunks from Freicoin_chunks.json
# ✅ Loaded 27 chunks from Dimecoin_chunks.json
# ✅ Loaded 17 chunks from BrahmaOS_chunks.json
# ✅ Loaded 6 chunks from cryptoinvestigators.com_cleaned_chunks.json
# ✅ Loaded 26 chunks from Gosama Final_chunks.json
# ✅ Loaded 66 chunks from RealTract_chunks.json
# ✅ Loaded 35 chunks from Tratok_chunks.json
# ✅ Loaded 31 chunks from Nano_chunks.json
# ✅ Loaded 75 chunks from CampusCoin_chunks.json
# ✅ Loaded 30 chunks from Cobinhood_chunks.json
# ✅ Loaded 27 chunks from Ondori_chunks.json
# ✅ Loaded 27 chunks from Wings_chunks.json
# ✅ Loaded 27 chunks from white-paper_extracted_chunks.json
# ✅ Loaded 23 chunks from Nebulas_chunks.json
# ✅ Loaded 40 chunks from Wink_chunks.json
# ✅ Loaded 39 chunks from MediBloc_chunks.json
# ✅ Loaded 53 chunks from Rivetz_chunks.json
# ✅ Loaded 37 chunks from Super Game Chain_chunks.json
# ✅ Loaded 2 chunks from steemit.com_cleaned_chunks.json
# ✅ Loaded 56 chunks from PalletOne_chunks.json
# ✅ Loaded 6 chunks from MCPC_chunks.json
# ✅ Loaded 100 chunks from 2014.5_word_to_int_chunks.json
# ✅ Loaded 37 chunks from FOINS_chunks.json
# ✅ Loaded 23 chunks from Decentraland_chunks.json
# ✅ Loaded 14 chunks from SCRIV NETWORK_chunks.json
# ✅ Loaded 5 chunks from Darcrus_chunks.json
# ✅ Loaded 40 chunks from Carry_chunks.json
# ✅ Loaded 30 chunks from Honest_chunks.json
# ✅ Loaded 33 chunks from MX Token_chunks.json
# ✅ Loaded 30 chunks from Safe Haven_chunks.json
# ✅ Loaded 58 chunks from Litex_chunks.json
# ✅ Loaded 28 chunks from EJOY_chunks.json
# ✅ Loaded 21 chunks from Zealium_chunks.json
# ✅ Loaded 33 chunks from Decentralized Vulnerability Platform_chunks.json
# ✅ Loaded 21 chunks from Publica_chunks.json
# ✅ Loaded 8 chunks from Devery_chunks.json
# ✅ Loaded 19 chunks from Liquidity Network_chunks.json
# ✅ Loaded 5 chunks from Ethereum Gold Project_chunks.json
# ✅ Loaded 18 chunks from DigitalDevelopersFund_chunks.json
# ✅ Loaded 44 chunks from Worldcore_chunks.json
# ✅ Loaded 66 chunks from Dusk Network_chunks.json
# ✅ Loaded 23 chunks from Hashgard_chunks.json
# ✅ Loaded 36 chunks from VisionX_chunks.json
# ✅ Loaded 68 chunks from ORS Group_chunks.json
# ✅ Loaded 57 chunks from Ubcoin Market_chunks.json
# ✅ Loaded 45 chunks from Treelion_chunks.json
# ✅ Loaded 16 chunks from Groestlcoin_chunks.json
# ✅ Loaded 32 chunks from SteepCoin_chunks.json
# ✅ Loaded 5 chunks from ENERGI_chunks.json
# ✅ Loaded 137 chunks from Monetha_chunks.json
# ✅ Loaded 11 chunks from Bilaxy_chunks.json
# ✅ Loaded 44 chunks from Sport and Leisure_chunks.json
# ✅ Loaded 21 chunks from Ormeus Coin_chunks.json
# ✅ Loaded 55 chunks from Blockcloud_chunks.json
# ✅ Loaded 20 chunks from Ampleforth_chunks.json
# ✅ Loaded 26 chunks from SnipCoin_chunks.json
# ✅ Loaded 62 chunks from Eximchain_chunks.json
# ✅ Loaded 22 chunks from Qbic_chunks.json
# ✅ Loaded 66 chunks from Auctus_chunks.json
# ✅ Loaded 46 chunks from Connect Coin_chunks.json
# ✅ Loaded 36 chunks from Joint Ventures_chunks.json
# ✅ Loaded 21 chunks from ZEON_chunks.json
# ✅ Loaded 40 chunks from Vites_chunks.json
# ✅ Loaded 31 chunks from cravath_raw_chunks.json
# ✅ Loaded 32 chunks from CARAT_chunks.json
# ✅ Loaded 29 chunks from Ink Protocol_chunks.json
# ✅ Loaded 35 chunks from cashaa_chunks.json
# ✅ Loaded 93 chunks from dascp_raw_chunks.json
# ✅ Loaded 12 chunks from Digiwage_chunks.json
# ✅ Loaded 15 chunks from Databits_chunks.json
# ✅ Loaded 59 chunks from EdenChain_chunks.json
# ✅ Loaded 55 chunks from Zilliqa_chunks.json
# ✅ Loaded 8 chunks from Suretly_chunks.json
# ✅ Loaded 37 chunks from WABnetwork_chunks.json
# ✅ Loaded 9 chunks from Hydro Protocol_chunks.json
# ✅ Loaded 15 chunks from Emercoin_chunks.json
# ✅ Loaded 10 chunks from Bankcoin_chunks.json
# ✅ Loaded 26 chunks from Ethorse_chunks.json
# ✅ Loaded 36 chunks from THEKEY_chunks.json
# ✅ Loaded 44 chunks from ssrn-4414080_processed_chunks.json
# ✅ Loaded 9 chunks from 1X2 Coin_chunks.json
# ✅ Loaded 50 chunks from Tarush_chunks.json
# ✅ Loaded 30 chunks from Achain Whitepaper 2.0_EN_extracted_chunks.json
# ✅ Loaded 6 chunks from Vipstar Coin_chunks.json
# ✅ Loaded 24 chunks from MIR COIN_chunks.json
# ✅ Loaded 9 chunks from BEAM_chunks.json
# ✅ Loaded 46 chunks from QLCchain_chunks.json
# ✅ Loaded 36 chunks from Marginless_chunks.json
# ✅ Loaded 4 chunks from CMITCOIN_chunks.json
# ✅ Loaded 44 chunks from Arbidex_chunks.json
# ✅ Loaded 51 chunks from Phore_chunks.json
# ✅ Loaded 47 chunks from Hyper Speed Network_chunks.json
# ✅ Loaded 60 chunks from savedroid_chunks.json
# ✅ Loaded 41 chunks from B91_chunks.json
# ✅ Loaded 5 chunks from Motocoin_chunks.json
# ✅ Loaded 38 chunks from Crypto.com_chunks.json
# ✅ Loaded 12 chunks from SmartCash_chunks.json
# ✅ Loaded 21 chunks from Gems_chunks.json
# ✅ Loaded 36 chunks from Knoxstertoken_chunks.json
# ✅ Loaded 11 chunks from Blocktix_chunks.json
# ✅ Loaded 13 chunks from ZeusCrowdfunding_chunks.json
# ✅ Loaded 31 chunks from Asch_chunks.json
# ✅ Loaded 47 chunks from Verge_chunks.json
# ✅ Loaded 50 chunks from Tokenbox_chunks.json
# ✅ Loaded 14 chunks from MergeCoin_chunks.json
# ✅ Loaded 66 chunks from SelfSell_chunks.json
# ✅ Loaded 8 chunks from Woodcoin_chunks.json
# ✅ Loaded 44 chunks from Zephyr_chunks.json
# ✅ Loaded 31 chunks from Gaps Chain_chunks.json
# ✅ Loaded 25 chunks from Block Chain_chunks.json
# ✅ Loaded 27 chunks from PAX Gold_chunks.json
# ✅ Loaded 45 chunks from Bitcoin Dark_chunks.json
# ✅ Loaded 23 chunks from Bitcoin Token_chunks.json
# ✅ Loaded 48 chunks from SIRIN LABS_chunks.json
# ✅ Loaded 34 chunks from Yuan Chain Coin_chunks.json
# ✅ Loaded 77 chunks from AVINOC_chunks.json
# ✅ Loaded 46 chunks from Polymath_chunks.json
# ✅ Loaded 45 chunks from Viewly_chunks.json
# ✅ Loaded 38 chunks from AmonD_chunks.json
# ✅ Loaded 43 chunks from MINDOL_chunks.json
# ✅ Loaded 28 chunks from GOmics_chunks.json
# ✅ Loaded 18 chunks from DigiByte_chunks.json
# ✅ Loaded 38 chunks from 10-1108_978-1-80455-320-620221017_processed_chunks.json
# ✅ Loaded 28 chunks from ATN_chunks.json
# ✅ Loaded 2 chunks from Compound Coin_chunks.json
# ✅ Loaded 12 chunks from EscrowCoin_chunks.json
# ✅ Loaded 10 chunks from Sphere_chunks.json
# ✅ Loaded 24 chunks from Stellite_chunks.json
# ✅ Loaded 33 chunks from Vexanium_chunks.json
# ✅ Loaded 12 chunks from EXMR FDN_chunks.json
# ✅ Loaded 95 chunks from TokenPay_chunks.json
# ✅ Loaded 43 chunks from SGPay_chunks.json
# ✅ Loaded 50 chunks from WAX_chunks.json
# ✅ Loaded 31 chunks from DENT ICO_chunks.json
# ✅ Loaded 76 chunks from Opiria PDATA_chunks.json
# ...
# ✅ Loaded 21 chunks from Sharechain_chunks.json
# ✅ Loaded 65 chunks from Cazcoin_chunks.json
# ✅ Loaded 27 chunks from Mainframe_chunks.json
# ✅ Loaded 7 chunks from Neox_chunks.json
# ✅ Loaded 4 chunks from PKG Token_chunks.json
# ✅ Loaded 10 chunks from GINcoin_chunks.json
# ✅ Loaded 11 chunks from MassGrid_chunks.json
# ✅ Loaded 51 chunks from Flexacoin_chunks.json
# ✅ Loaded 30 chunks from bitnautic_chunks.json
# ✅ Loaded 23 chunks from ChainX_chunks.json
# ✅ Loaded 107 chunks from Algorand_chunks.json
# ✅ Loaded 20 chunks from WITChain_chunks.json
# ✅ Loaded 7 chunks from 1irstcoin_chunks.json
# ✅ Loaded 89 chunks from dascp_processed_chunks.json
# ✅ Loaded 44 chunks from FOAM_chunks.json
# ✅ Loaded 12 chunks from TrueFeedBack_chunks.json
# ✅ Loaded 15 chunks from SmartsFox_chunks.json
# ✅ Loaded 67 chunks from CoinMetro_chunks.json
# ✅ Loaded 14 chunks from Nuls_chunks.json
# ✅ Loaded 34 chunks from BOScoin_chunks.json
# ✅ Loaded 37 chunks from BLUE_chunks.json
# ✅ Loaded 70 chunks from Theta_chunks.json
# ✅ Loaded 23 chunks from Natmin_chunks.json
# ✅ Loaded 10 chunks from DACH Coin_chunks.json
# ✅ Loaded 37 chunks from Divi_chunks.json
# ✅ Loaded 15 chunks from Monero_chunks.json
# ✅ Loaded 15 chunks from Gemini Dollar_chunks.json
# ✅ Loaded 32 chunks from Velas_chunks.json
# ✅ Loaded 14 chunks from Viuly_chunks.json
# ✅ Loaded 55 chunks from Uranus_chunks.json
# ✅ Loaded 19 chunks from Energo_chunks.json
# ✅ Loaded 24 chunks from Blocklancer_chunks.json
# ✅ Loaded 0 chunks from CoinMeet_chunks.json
# ✅ Loaded 24 chunks from Aston_chunks.json
# ✅ Loaded 50 chunks from Mobius_chunks.json
# ✅ Loaded 27 chunks from Simmitri_chunks.json
# ✅ Loaded 46 chunks from vSportCoin_chunks.json
# ✅ Loaded 10 chunks from Atlantis Blue Digital Token_chunks.json
# ✅ Loaded 6 chunks from crypto.com_cleaned_chunks.json
# ✅ Loaded 23 chunks from HyperCash_chunks.json
# ✅ Loaded 91 chunks from Obyte_chunks.json
# ✅ Loaded 22 chunks from Shift_chunks.json
# ✅ Loaded 27 chunks from LOCIcoin_chunks.json
# ✅ Loaded 43 chunks from Opus_chunks.json
# ✅ Loaded 34 chunks from Quanta Utility Token_chunks.json
# ✅ Loaded 7 chunks from IQ.cash_chunks.json
# ✅ Loaded 26 chunks from LatiumX_chunks.json
# ✅ Loaded 36 chunks from mcashchain_chunks.json
# ✅ Loaded 20 chunks from us-crypto-regulatory-whitepaper_cleaned_chunks.json
# ✅ Loaded 43 chunks from Zen Protocol_chunks.json
# ✅ Loaded 91 chunks from Ultrain_chunks.json
# ✅ Loaded 7 chunks from Neural Protocol_chunks.json
# ✅ Loaded 8 chunks from Delizia_chunks.json
# ✅ Loaded 93 chunks from Quantstamp_chunks.json
# ✅ Loaded 48 chunks from Aidos Kuneen_chunks.json
# ✅ Loaded 24 chunks from Dash_chunks.json
# ✅ Loaded 128 chunks from Storj_chunks.json
# ✅ Loaded 45 chunks from AirFox_chunks.json
# ✅ Loaded 23 chunks from Apollo_chunks.json
# ✅ Loaded 8 chunks from 999_chunks.json
# ✅ Loaded 30 chunks from SwissBorg_chunks.json
# ✅ Loaded 25 chunks from Terra_chunks.json
# ✅ Loaded 37 chunks from BawNetwork_chunks.json
# ✅ Loaded 49 chunks from Sharder_chunks.json
# ✅ Loaded 34 chunks from AirWire_chunks.json
# ✅ Loaded 36 chunks from Bankera_chunks.json
# ✅ Loaded 16 chunks from HireMatch_chunks.json
# ✅ Loaded 79 chunks from LemoChain_chunks.json
# ✅ Loaded 32 chunks from Enecuum_chunks.json
# ✅ Loaded 50 chunks from Medibit_chunks.json
# ✅ Loaded 25 chunks from Banyan Network_chunks.json
# ✅ Loaded 50 chunks from Tokenstars_chunks.json
# ✅ Loaded 3 chunks from BBSCoin_chunks.json
# ✅ Loaded 28 chunks from SnowGem_chunks.json
# ✅ Loaded 70 chunks from Cosmos_chunks.json
# ✅ Loaded 37 chunks from Horizon State_chunks.json
# ✅ Loaded 20 chunks from TCOIN_chunks.json
# ✅ Loaded 33 chunks from HunterCoin_chunks.json
# ✅ Loaded 12 chunks from KanadeCoin_chunks.json
# ✅ Loaded 12 chunks from Primecoin_chunks.json
# ✅ Loaded 50 chunks from EveriToken_chunks.json
# ✅ Loaded 30 chunks from Gene Source Code Chain_chunks.json
# ✅ Loaded 53 chunks from GazeCoi_chunks.json
# ✅ Loaded 13 chunks from Giant_chunks.json
# ✅ Loaded 62 chunks from WeTrust_chunks.json
# ✅ Loaded 67 chunks from Steem_chunks.json
# ✅ Loaded 73 chunks from Fortuna_chunks.json
# ✅ Loaded 5 chunks from Bitforex_chunks.json
# ✅ Loaded 31 chunks from Halo Platform_chunks.json
# ✅ Loaded 19 chunks from Dero_chunks.json
# ✅ Loaded 53 chunks from FLIP_chunks.json
# ✅ Loaded 20 chunks from CasinoCoin_chunks.json
# ✅ Loaded 32 chunks from Elastos_chunks.json
# ✅ Loaded 43 chunks from ArcBlock_chunks.json
# ✅ Loaded 28 chunks from www.investopedia.com_cleaned_chunks.json
# ✅ Loaded 18 chunks from Bittwatt_chunks.json
# ✅ Loaded 19 chunks from metal Pay_chunks.json
# ✅ Loaded 40 chunks from Nitro_chunks.json
# ✅ Loaded 20 chunks from netkoin_chunks.json
# ✅ Loaded 38 chunks from Complexity - 2022 - Chen - Cryptocurrency Financial Risk Analysis Based on Deep Machine Learning_processed_chunks.json
# ✅ Loaded 18 chunks from Bitcoin Cash_chunks.json
# ✅ Loaded 19 chunks from subx_chunks.json
# ✅ Loaded 40 chunks from On.Live_chunks.json
# ✅ Loaded 37 chunks from Proton_chunks.json
# ✅ Loaded 42 chunks from Puregold_chunks.json
# ✅ Loaded 18 chunks from ALAX_chunks.json
# ✅ Loaded 35 chunks from Sense_chunks.json
# ✅ Loaded 31 chunks from legolas_chunks.json
# ✅ Loaded 67 chunks from Poseidon Network_chunks.json
# ✅ Loaded 8 chunks from GNY_chunks.json
# ✅ Loaded 57 chunks from Everex_chunks.json
# ✅ Loaded 27 chunks from DMarket_chunks.json
# ✅ Loaded 10 chunks from Nasdacoin_chunks.json
# ✅ Loaded 52 chunks from NewsToken_chunks.json
# ✅ Loaded 16 chunks from Signatum_chunks.json
# ✅ Loaded 31 chunks from LikeCoin_chunks.json
# ✅ Loaded 38 chunks from Globalvillage Ecosystem_chunks.json
# ✅ Loaded 10 chunks from Mindexcoin_chunks.json
# ✅ Loaded 57 chunks from INS Ecosystem_chunks.json
# ✅ Loaded 53 chunks from Silverway Token_chunks.json
# ✅ Loaded 34 chunks from Hedgetoken_chunks.json
# ✅ Loaded 30 chunks from TWIST_chunks.json
# ✅ Loaded 47 chunks from Odyssey_chunks.json
# ✅ Loaded 26 chunks from Smartshare_chunks.json
# ✅ Loaded 0 chunks from Internet of People_chunks.json
# ✅ Loaded 39 chunks from MobileGo_chunks.json
# ✅ Loaded 44 chunks from Nexus_chunks.json
# ✅ Loaded 1 chunks from ETERNAL TOKEN_chunks.json
# ✅ Loaded 60 chunks from Asian Dragon_chunks.json
# ✅ Loaded 35 chunks from IXT_chunks.json
# ✅ Loaded 40 chunks from Esports Token_chunks.json
# ✅ Loaded 89 chunks from Origo_chunks.json
# ✅ Loaded 19 chunks from Unikoin Gold_chunks.json
# ✅ Loaded 26 chunks from Project Pai_chunks.json
# ✅ Loaded 22 chunks from DaTa eXchange_chunks.json
# ✅ Loaded 27 chunks from Bridge_chunks.json
# ✅ Loaded 89 chunks from Sharpe Platform Token_chunks.json
# ✅ Loaded 46 chunks from Anchor_chunks.json
# ✅ Loaded 65 chunks from OST_chunks.json
# ✅ Loaded 19 chunks from SunContract_chunks.json
# ✅ Loaded 37 chunks from Blockpass_chunks.json
# ✅ Loaded 57 chunks from SOOM_chunks.json
# ✅ Loaded 47 chunks from ContentBox_chunks.json
# ✅ Loaded 31 chunks from Bigbom_chunks.json
# ✅ Loaded 25 chunks from Melon_chunks.json
# ✅ Loaded 91 chunks from Ivy_chunks.json
# ✅ Loaded 11 chunks from Bitcoin Rhodium_chunks.json
# ✅ Loaded 16 chunks from HorusPay_chunks.json
# ✅ Loaded 10 chunks from regalcoin_chunks.json
# ✅ Loaded 67 chunks from Ontology_chunks.json
# ✅ Loaded 6 chunks from Imbrex_chunks.json
# ✅ Loaded 27 chunks from CloakCoin_chunks.json
# ✅ Loaded 37 chunks from PundiX_chunks.json
# ✅ Loaded 75 chunks from BitRewards_chunks.json
# ✅ Loaded 107 chunks from Cortex_chunks.json
# ✅ Loaded 54 chunks from UnlimitedIP_chunks.json
# ✅ Loaded 33 chunks from Nestree_chunks.json
# ✅ Loaded 15 chunks from Nexty_chunks.json
# ✅ Loaded 18 chunks from UltrAlpha_chunks.json
# ✅ Loaded 27 chunks from Adzcoin_chunks.json
# ✅ Loaded 59 chunks from DeepBrain Chain_chunks.json
# ✅ Loaded 21 chunks from BitCash_chunks.json
# ✅ Loaded 45 chunks from Provoco_chunks.json
# ✅ Loaded 59 chunks from Magic Cube_chunks.json
# ✅ Loaded 35 chunks from Smartup_chunks.json
# ✅ Loaded 46 chunks from Rif Token_chunks.json
# ✅ Loaded 70 chunks from Stellar_chunks.json
# ✅ Loaded 76 chunks from TrustVerse_chunks.json
# ✅ Loaded 24 chunks from OOOBTC Token_chunks.json
# ✅ Loaded 48 chunks from Indorse_chunks.json
# ✅ Loaded 82 chunks from Endor Protocol_chunks.json
# ✅ Loaded 17 chunks from Bibox_chunks.json
# ✅ Loaded 38 chunks from Ryo Currency_chunks.json
# ✅ Loaded 22 chunks from Hydrogen_chunks.json
# ✅ Loaded 16 chunks from Aave_Protocol_Whitepaper_v1_0_extracted_chunks.json
# ✅ Loaded 13 chunks from INO COIN_chunks.json
# ✅ Loaded 39 chunks from Cryptocurrency and Macro-Economic Stability_processed_chunks.json
# ✅ Loaded 29 chunks from DigiPulse_chunks.json
# ✅ Loaded 6 chunks from Noir_chunks.json
# ✅ Loaded 24 chunks from Rankingball Gold_chunks.json
# ✅ Loaded 64 chunks from Hybrid Block_chunks.json
# ✅ Loaded 35 chunks from IOTW_chunks.json
# ✅ Loaded 49 chunks from BORA_chunks.json
# ✅ Loaded 38 chunks from EveryCoin_chunks.json
# ✅ Loaded 19 chunks from Ren_chunks.json
# ✅ Loaded 34 chunks from Japan Content Token_chunks.json
# ✅ Loaded 91 chunks from Neumark_chunks.json
# ✅ Loaded 8 chunks from Shadow Token_chunks.json
# ✅ Loaded 50 chunks from Blockport_chunks.json
# ✅ Loaded 13 chunks from CryptoFlow_chunks.json
# ✅ Loaded 27 chunks from Live Stars_chunks.json
# ✅ Loaded 100 chunks from Bankex_chunks.json
# ✅ Loaded 60 chunks from Constant_chunks.json
# ✅ Loaded 24 chunks from Elixir_chunks.json
# ✅ Loaded 51 chunks from Infinitus_chunks.json
# ✅ Loaded 20 chunks from GoldenFever_chunks.json
# ✅ Loaded 73 chunks from Eligma_chunks.json
# ✅ Loaded 53 chunks from Ultiledger_chunks.json
# ✅ Loaded 11 chunks from Ethbits_chunks.json
# ✅ Loaded 26 chunks from Universa_chunks.json
# ✅ Loaded 44 chunks from Smart Bitcoin_chunks.json
# ✅ Loaded 7 chunks from theholycoins.com_cleaned_chunks.json
# ✅ Loaded 36 chunks from Aeron_chunks.json
# ✅ Loaded 5 chunks from Ragnarok_chunks.json
# ✅ Loaded 18 chunks from Bitcoin Red_chunks.json
# ✅ Loaded 48 chunks from United Traders Token_chunks.json
# ✅ Loaded 42 chunks from Skycoin_chunks.json
# ✅ Loaded 34 chunks from APIS_chunks.json
# ✅ Loaded 8 chunks from Global Jobcoin_chunks.json
# ✅ Loaded 43 chunks from Pillar_chunks.json
# ✅ Loaded 61 chunks from Zebi_chunks.json
# ✅ Loaded 40 chunks from Apex_chunks.json
# ✅ Loaded 50 chunks from SoMee.Social_chunks.json
# ✅ Loaded 17 chunks from vetting_guide_raw_chunks.json
# ✅ Loaded 0 chunks from Zipper_chunks.json
# ✅ Loaded 57 chunks from Emanate_chunks.json
# ✅ Loaded 25 chunks from STPT_chunks.json
# ✅ Loaded 10 chunks from VoteCoin_chunks.json
# ✅ Loaded 31 chunks from Devify_chunks.json
# ✅ Loaded 27 chunks from Alphacon_chunks.json
# ✅ Loaded 14 chunks from Chronobank_chunks.json
# ✅ Loaded 50 chunks from LocalCoinSwap_chunks.json
# ✅ Loaded 11 chunks from NPCoin_chunks.json
# ✅ Loaded 31 chunks from Vetri_chunks.json
# ✅ Loaded 4 chunks from www.scorechain.com_cleaned_chunks.json
# ✅ Loaded 47 chunks from ENTCash_chunks.json
# ✅ Loaded 43 chunks from Banca_chunks.json
# ✅ Loaded 10 chunks from Curriculum Vitae_chunks.json
# ✅ Loaded 39 chunks from SpankChain_chunks.json
# ✅ Loaded 48 chunks from DeepCloudAI_chunks.json
# ✅ Loaded 20 chunks from Bitmax Token_chunks.json
# ✅ Loaded 15 chunks from Denarius_chunks.json
# ✅ Loaded 35 chunks from HEROcoin_chunks.json
# ✅ Loaded 15 chunks from DCTO_chunks.json
# ✅ Loaded 36 chunks from Kcash_chunks.json
# ✅ Loaded 39 chunks from bitCEO_chunks.json
# ✅ Loaded 8 chunks from Contentos_chunks.json
# ✅ Loaded 10 chunks from Staker_chunks.json
# ✅ Loaded 46 chunks from NKN_chunks.json
# ✅ Loaded 75 chunks from Mercury Protocol_chunks.json
# ✅ Loaded 41 chunks from Bayan Token_chunks.json
# ✅ Loaded 46 chunks from IntelliShare_chunks.json
# ✅ Loaded 14 chunks from fscp_chunks.json
# ✅ Loaded 36 chunks from Airbloc_chunks.json
# ✅ Loaded 42 chunks from Gifto_chunks.json
# ✅ Loaded 10 chunks from Observer Technical Note_chunks.json
# ✅ Loaded 39 chunks from Bloom_chunks.json
# ✅ Loaded 76 chunks from fintrux_chunks.json
# ✅ Loaded 14 chunks from Bionic_chunks.json
# ✅ Loaded 31 chunks from Cosmo Chain_chunks.json
# ✅ Loaded 28 chunks from Bytom_chunks.json
# ✅ Loaded 46 chunks from LINA_chunks.json
# ✅ Loaded 29 chunks from Time New Bank_chunks.json
# ✅ Loaded 28 chunks from Maggie_chunks.json
# ✅ Loaded 17 chunks from Bitcoin Gold_chunks.json
# ✅ Loaded 51 chunks from Oyster_chunks.json
# ✅ Loaded 27 chunks from ValueChain_chunks.json
# ✅ Loaded 21 chunks from Nos_chunks.json
# ✅ Loaded 30 chunks from SureRemit_chunks.json
# ✅ Loaded 62 chunks from CryptoFranc_chunks.json
# ✅ Loaded 27 chunks from netbox coin_chunks.json
# ✅ Loaded 60 chunks from Traxia_chunks.json
# ✅ Loaded 27 chunks from Pluton_chunks.json
# ✅ Loaded 23 chunks from Mixin_chunks.json
# ✅ Loaded 1 chunks from Twinkle_chunks.json
# ✅ Loaded 50 chunks from Digitex Futures_chunks.json
# ✅ Loaded 58 chunks from SONM_chunks.json
# ✅ Loaded 34 chunks from StakeNet_chunks.json
# Loaded 53034 documents for vectorization
# Processing batch 1/22 with 2500 documents
# Progress: 2500/53034 documents (4.7%)
# Saved checkpoint at 2500/53034 documents
# Processing batch 2/22 with 2500 documents
# Progress: 5000/53034 documents (9.4%)
# Saved checkpoint at 5000/53034 documents
# Processing batch 3/22 with 2500 documents
# Progress: 7500/53034 documents (14.1%)
# Saved checkpoint at 7500/53034 documents
# Processing batch 4/22 with 2500 documents
# Progress: 10000/53034 documents (18.9%)
# Saved checkpoint at 10000/53034 documents
# Processing batch 5/22 with 2500 documents
# Progress: 12500/53034 documents (23.6%)
# Saved checkpoint at 12500/53034 documents
# Processing batch 6/22 with 2500 documents
# Progress: 15000/53034 documents (28.3%)
# Saved checkpoint at 15000/53034 documents
# Processing batch 7/22 with 2500 documents
# Progress: 17500/53034 documents (33.0%)
# Saved checkpoint at 17500/53034 documents
# Processing batch 8/22 with 2500 documents
# Progress: 20000/53034 documents (37.7%)
# Saved checkpoint at 20000/53034 documents
# Processing batch 9/22 with 2500 documents
# Progress: 22500/53034 documents (42.4%)
# Saved checkpoint at 22500/53034 documents
# Processing batch 10/22 with 2500 documents
# Progress: 25000/53034 documents (47.1%)
# Saved checkpoint at 25000/53034 documents
# Processing batch 11/22 with 2500 documents
# Progress: 27500/53034 documents (51.9%)
# Saved checkpoint at 27500/53034 documents
# Processing batch 12/22 with 2500 documents
# Progress: 30000/53034 documents (56.6%)
# Saved checkpoint at 30000/53034 documents
# Processing batch 13/22 with 2500 documents
# Progress: 32500/53034 documents (61.3%)
# Saved checkpoint at 32500/53034 documents
# Processing batch 14/22 with 2500 documents
# Progress: 35000/53034 documents (66.0%)
# Saved checkpoint at 35000/53034 documents
# Processing batch 15/22 with 2500 documents
# Progress: 37500/53034 documents (70.7%)
# Saved checkpoint at 37500/53034 documents
# Processing batch 16/22 with 2500 documents
# Progress: 40000/53034 documents (75.4%)
# Saved checkpoint at 40000/53034 documents
# Processing batch 17/22 with 2500 documents
# Progress: 42500/53034 documents (80.1%)
# Saved checkpoint at 42500/53034 documents
# Processing batch 18/22 with 2500 documents
# Progress: 45000/53034 documents (84.9%)
# Saved checkpoint at 45000/53034 documents
# Processing batch 19/22 with 2500 documents
# Progress: 47500/53034 documents (89.6%)
# Saved checkpoint at 47500/53034 documents
# Processing batch 20/22 with 2500 documents
# Progress: 50000/53034 documents (94.3%)
# Saved checkpoint at 50000/53034 documents
# Processing batch 21/22 with 2500 documents
# Progress: 52500/53034 documents (99.0%)
# Saved checkpoint at 52500/53034 documents
# Processing batch 22/22 with 534 documents
# Progress: 53034/53034 documents (100.0%)
# Saved checkpoint at 53034/53034 documents
# ✅ Indexed 53034 chunks into vector database
# ✅ Metadata saved to 'faiss_index/index_metadata.json' (JSON)
#
# 🔍 Testing search functionality...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-38ba9077f23a> in <cell line: 0>()
#     110
#     111 # Execute the pipeline
# --> 112 vector_db = run_vector_indexing()
#
# <ipython-input-11-38ba9077f23a> in run_vector_indexing()
#     105     # Test a search query to verify functionality
#     106     print("\n🔍 Testing search functionality...")
# --> 107     test_search(chunker, "What are KYC requirements for crypto exchanges?", k=3)
#     108
#     109     return chunker
#
# NameError: name 'test_search' is not defined

# %%
def load_index(self, path=None):
    """Load existing FAISS index"""
    path = path or self.data_dir

    if not os.path.exists(path):
        raise FileNotFoundError(f"Index directory '{path}' not found.")

    # Initialize embeddings
    self._init_embeddings()

    print(f"📂 Loading FAISS index from {path}...")
    # Add the allow_dangerous_deserialization parameter
    self.vectordb = FAISS.load_local(path, self.embeddings, allow_dangerous_deserialization=True)

    # Load metadata
    metadata_path = os.path.join(path, "index_metadata.json")
    if os.path.exists(metadata_path):
        with open(metadata_path, "r", encoding="utf-8") as f:
            metadata = json.load(f)
            print(f"✅ Loaded metadata for {len(metadata)} documents")
    else:
        print("⚠️ No metadata file found.")

    return self.vectordb is not None

# %%
pip install -U langchain-community
# Out:
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.11/dist-packages (0.3.21)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.51 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.3.51)
# Requirement already satisfied: langchain<1.0.0,>=0.3.23 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.3.23)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (3.11.15)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.8.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.3.28)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: numpy<3,>=1.26.2 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.4.2)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.19.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.23->langchain-community) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.23->langchain-community) (2.11.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.51->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.51->langchain-community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.51->langchain-community) (4.13.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (2025.1.31)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.51->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.23->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.23->langchain-community) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.23->langchain-community) (0.4.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.3.1)

# %% [markdown]
# **Testing the Vector Store**

# %%
from langchain_community.vectorstores import FAISS

# %%
import os
import json
import faiss
import numpy as np
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import HuggingFaceEmbeddings
from typing import List, Dict, Any, Optional

class SmartChunker:
    def __init__(self, data_dir="faiss_index", embedding_model=None):
        """
        Initialize the SmartChunker with the specified data directory and embedding model.
        If embedding_model is None, it will be determined from index inspection.
        """
        self.data_dir = data_dir
        self.embedding_model_name = embedding_model  # Can be None initially
        self.embeddings = None
        self.vectordb = None
        self.dimension = None

    def _inspect_index_dimension(self):
        """Inspect the FAISS index file to determine its dimension"""
        index_path = os.path.join(self.data_dir, "index.faiss")
        if not os.path.exists(index_path):
            raise FileNotFoundError(f"FAISS index file not found at {index_path}")

        # Read the index to get dimension
        index = faiss.read_index(index_path)
        dimension = index.d
        print(f"📏 FAISS index dimension: {dimension}")
        return dimension

    def _select_appropriate_model(self, dimension):
        """Select embedding model based on dimension"""
        dimension_to_model = {
            384: "sentence-transformers/all-MiniLM-L6-v2",
            768: "sentence-transformers/all-mpnet-base-v2",
            1024: "sentence-transformers/paraphrase-MiniLM-L12-v2",
            512: "sentence-transformers/paraphrase-multilingual-mpnet-base-v2"
        }

        if dimension in dimension_to_model:
            model = dimension_to_model[dimension]
            print(f"✅ Auto-selected model '{model}' based on dimension {dimension}")
            return model
        else:
            print(f"⚠️ Unusual dimension {dimension}. Using default model, but this may fail.")
            return "sentence-transformers/all-MiniLM-L6-v2"  # Default fallback

    def _init_embeddings(self):
        """Initialize the embeddings model with hardware acceleration if available."""
        # If we don't have an embedding model specified, determine it from the index dimension
        if self.embedding_model_name is None:
            try:
                dimension = self._inspect_index_dimension()
                self.embedding_model_name = self._select_appropriate_model(dimension)
            except Exception as e:
                print(f"⚠️ Error inspecting index: {e}")
                print("🔄 Using default embedding model: sentence-transformers/all-MiniLM-L6-v2")
                self.embedding_model_name = "sentence-transformers/all-MiniLM-L6-v2"

        print(f"🔍 Initializing embeddings model: {self.embedding_model_name}")

        # Check for CUDA availability
        device = "cuda" if faiss.get_num_gpus() > 0 else "cpu"

        if device == "cuda":
            print("✅ Using CUDA GPU device")
        else:
            print("ℹ️ Using CPU (no GPU acceleration available)")

        # Initialize the embeddings model
        self.embeddings = HuggingFaceEmbeddings(
            model_name=self.embedding_model_name,
            model_kwargs={"device": device}
        )

        # Test the embeddings to get the dimension
        test_embedding = self.embeddings.embed_query("test")
        self.dimension = len(test_embedding)
        print(f"📏 Embedding dimension: {self.dimension}")

        return self.embeddings

    def load_index(self, path=None):
        """Load existing FAISS index"""
        path = path or self.data_dir

        if not os.path.exists(path):
            raise FileNotFoundError(f"Index directory '{path}' not found.")

        # First, inspect the index to get dimension if no model specified
        if self.embedding_model_name is None:
            try:
                dimension = self._inspect_index_dimension()
                self.embedding_model_name = self._select_appropriate_model(dimension)
            except Exception as e:
                print(f"⚠️ Error inspecting index: {e}")

        # Initialize embeddings with the appropriate model
        self._init_embeddings()

        # Get index dimension directly as a double-check
        try:
            index_dimension = self._inspect_index_dimension()
            if index_dimension != self.dimension:
                print(f"⚠️ Dimension mismatch: Embeddings ({self.dimension}) vs Index ({index_dimension})")
                print("🔄 Reinitializing with corrected embedding model...")

                # Re-select model based on actual index dimension
                self.embedding_model_name = self._select_appropriate_model(index_dimension)
                self._init_embeddings()

                # Verify dimensions match now
                if self.dimension != index_dimension:
                    print(f"❌ Still have dimension mismatch after correction attempt. Search may fail.")
        except Exception as e:
            print(f"⚠️ Error during dimension check: {e}")

        print(f"📂 Loading FAISS index from {path}...")

        try:
            # Using allow_dangerous_deserialization parameter
            self.vectordb = FAISS.load_local(path, self.embeddings, allow_dangerous_deserialization=True)
            print("✅ Successfully loaded FAISS index")
        except Exception as e:
            print(f"❌ Error loading index: {e}")
            return False

        # Load metadata
        metadata_path = os.path.join(path, "index_metadata.json")
        if os.path.exists(metadata_path):
            with open(metadata_path, "r", encoding="utf-8") as f:
                metadata = json.load(f)
                print(f"✅ Loaded metadata for {len(metadata)} documents")
        else:
            print("⚠️ No metadata file found.")

        return self.vectordb is not None

    def search(self, query: str, k: int = 3) -> List[Dict[str, Any]]:
        """
        Search the vector database for similar documents.

        Args:
            query: The search query
            k: Number of results to return

        Returns:
            List of document dictionaries with text and metadata
        """
        if self.vectordb is None:
            if not self.load_index():
                raise ValueError("Vector database is not initialized. Please load or create an index first.")

        try:
            # Perform similarity search
            raw_results = self.vectordb.similarity_search_with_score(query, k=k)

            # Format the results
            results = []
            for doc, score in raw_results:
                # Normalize score (FAISS returns distance, lower is better)
                # Convert to similarity score (higher is better)
                similarity = 1.0 / (1.0 + score)

                result = {
                    "text": doc.page_content,
                    "score": similarity,
                    "file_name": doc.metadata.get("source", "Unknown"),
                }

                # Add other metadata if available
                if "entities" in doc.metadata:
                    result["entities"] = doc.metadata["entities"]

                if "risk_score" in doc.metadata:
                    result["risk_score"] = doc.metadata["risk_score"]

                results.append(result)

            return results
        except Exception as e:
            print(f"⚠️ Search error: {e}")
            print("🔄 The embedding model used to search is different from the one used to create the index.")
            print("   You need to use the same embedding model that was used to create the index.")
            print("   Current model dimension:", self.dimension)
            try:
                index_dimension = self._inspect_index_dimension()
                print("   Index dimension:", index_dimension)
            except:
                pass
            return []


def test_search_functionality():
    """
    Load the completed FAISS index and test search functionality,
    automatically selecting the correct embedding model based on index dimensions.
    """
    print("🔍 Loading FAISS index from faiss_index directory...")

    # Initialize chunker with automatic model detection
    chunker = SmartChunker(data_dir="faiss_index", embedding_model=None)

    # Load the existing index
    if chunker.load_index():
        print("✅ Successfully loaded FAISS index")

        # Run the test queries
        test_queries = [
            "What is cryptocurrency?",
            "How do cryptocurrency wallets work?",
            "What are the regulatory requirements for crypto?",
            "Explain blockchain technology",
            "What are the risks of cryptocurrency investment?",
            "Identify potential fraud in crypto transactions",
            "What are KYC requirements for exchanges?"
        ]

        # Run test searches
        for query in test_queries:
            test_search(chunker, query, k=3)

        return chunker
    else:
        print("❌ Failed to load FAISS index - please check the path and embedding model")
        return None

def test_search(chunker: SmartChunker, query: str, k: int = 3) -> None:
    """
    Test search functionality and print results.

    Args:
        chunker: Initialized SmartChunker instance
        query: Search query
        k: Number of results to return
    """
    print(f"\nSearching for: {query}")
    print("=" * 50)

    results = chunker.search(query, k=k)

    if not results:
        print("\n❌ No results found or search error occurred.")
        return

    print(f"\nFound {len(results)} results:")
    for i, result in enumerate(results, 1):
        print(f"\n{i}. File: {result['file_name']}")
        print(f"   Score: {result['score']:.4f}")
        print(f"   Risk Score: {result.get('risk_score', 'N/A')}")

        # Print entities if available
        if result.get('entities'):
            print("   Entities:")
            for etype, elist in result['entities'].items():
                if elist:
                    print(f"     - {etype.capitalize()}: {', '.join(elist[:3])}")

        # Print text preview
        print(f"   Text: {result['text'][:200]}...")
        print("-" * 50)

# Execute the test searches
if __name__ == "__main__":
    chunker = test_search_functionality()

    # Optional: Try some additional custom queries
    if chunker:
        print("\n--- Custom Queries ---\n")

        custom_queries = [
            "How does blockchain prevent fraud?",
            "What are the key risks in DeFi platforms?",
            "Explain money laundering concerns in cryptocurrency",
            "How do stablecoins maintain their value?"
        ]

        for query in custom_queries:
            test_search(chunker, query, k=3)
# Out:
# 🔍 Loading FAISS index from faiss_index directory...
# 📏 FAISS index dimension: 768
# ✅ Auto-selected model 'sentence-transformers/all-mpnet-base-v2' based on dimension 768
# 🔍 Initializing embeddings model: sentence-transformers/all-mpnet-base-v2
# ℹ️ Using CPU (no GPU acceleration available)
# 📏 Embedding dimension: 768
# 📏 FAISS index dimension: 768
# 📂 Loading FAISS index from faiss_index...
# ✅ Successfully loaded FAISS index
# ✅ Loaded metadata for 53034 documents
# ✅ Successfully loaded FAISS index
#
# Searching for: What is cryptocurrency?
# ==================================================
#
# Found 3 results:
#
# 1. File: Experience points.txt
#    Score: 0.5702
#    Risk Score: 10.0
#    Entities:
#      - Location: united states
#    Text: [Section 8] online brief hypercondensed explanation exactly cryptocurrency generated follows cryptocurrency bitcoin developed person persons known satoshi nakamoto cryptocurrency stroke revolutionized...
# --------------------------------------------------
#
# 2. File: Alibabacoin.txt
#    Score: 0.5563
#    Risk Score: 0.0
#    Entities:
#    Text: [Section 2] ico tokens sales t t t t t t t t12 vii project team t t t t t t t t t t t t12 viii roadmap t t t t t t t t t t t t13 ix certificates t t t t t t t t t t t13 b b c x0ci c o n c e p t 1 conc...
# --------------------------------------------------
#
# 3. File: TokenPay.txt
#    Score: 0.5475
#    Risk Score: 0.0
#    Entities:
#    Text: [Section 27] x0cintroduction digital currencies called cryptocurrencies intricate technical details related cryptography start looking human history cowry shells asian region coinage ancient kingdoms ...
# --------------------------------------------------
#
# Searching for: How do cryptocurrency wallets work?
# ==================================================
#
# Found 3 results:
#
# 1. File: Ethos.txt
#    Score: 0.5019
#    Risk Score: 0.0
#    Entities:
#    Text: [Section 7] wallet operates utilizing complete user autonomy control cryptocurrencies afford ethos universal wallet operates like password vault making safe secure key management easier ethos universa...
# --------------------------------------------------
#
# 2. File: Netrum.txt
#    Score: 0.4922
#    Risk Score: 0.0
#    Entities:
#    Text: [Section 39] wallets store certain money true cryptocurrency wallet stores money physical meaning fact single location stores currency digital wallet records transactions stored blockchain instance re...
# --------------------------------------------------
#
# 3. File: REBL.txt
#    Score: 0.4782
#    Risk Score: 0.0
#    Entities:
#    Text: [Section 26] types wallet t t 3 5 3 1 desktop wallet basic desktop wallets provide following features secure storage xe2 x80 x94you access desktop wallet private key json file wallet built ssl encrypt...
# --------------------------------------------------
#
# Searching for: What are the regulatory requirements for crypto?
# ==================================================
#
# Found 3 results:
#
# 1. File: 10-1108_978-1-80455-320-620221017_processed.txt
#    Score: 0.6273
#    Risk Score: 12.0
#    Entities:
#    Text: [Section 11] . investor invest exchange-traded fund private fund trades crypto. retail investor bitcoin traditional brokerage coinbase account. regulators regulators depend company formed business, to...
# --------------------------------------------------
#
# 2. File: Cryptocurrency and Macro-Economic Stability_processed.txt
#    Score: 0.6129
#    Risk Score: 10.0
#    Entities:
#    Text: [Section 27] . good regulations require reporting suspicious transactions competent authorities. b. consumer protection regulations provide adequate protection consumers use cryptocurrency. includes r...
# --------------------------------------------------
#
# 3. File: blogs.cisco.com_cleaned.txt
#    Score: 0.6076
#    Risk Score: 12.0
#    Entities:
#    Text: [Section 20] adoption blockchain severe scrutiny government regulator globe case lawsuit u security exchange commission ripple accuse defendant conduct 13 billion unregistered security offer governmen...
# --------------------------------------------------
#
# Searching for: Explain blockchain technology
# ==================================================
#
# Found 3 results:
#
# 1. File: ENTCash.txt
#    Score: 0.5982
#    Risk Score: 0.0
#    Entities:
#    Text: [Section 4] org 2 https en wikipedia org wiki ethereum 2 41 x0cent white paper vitalik 2016 xe2 x80 x9ccrypto 3 0 xe2 x80 x94 mind xe2 x80 x94 consists approaches limitation ways create systems break ...
# --------------------------------------------------
#
# 2. File: XinFin Network.txt
#    Score: 0.5971
#    Risk Score: 0.0
#    Entities:
#    Text: [Section 3] institutions beginning understand potential applications blockchain conventionally regulated industries understanding blockchain fundamental level blockchain data structure cryptographical...
# --------------------------------------------------
#
# 3. File: SGPay.txt
#    Score: 0.5955
#    Risk Score: 11.0
#    Entities:
#    Text: [Section 39] adviser head regional business development sph digital fastjobs asia successfully exited start ups multi million dollar valuations adviser founder pulse9 studio specialises ai technologie...
# --------------------------------------------------
#
# Searching for: What are the risks of cryptocurrency investment?
# ==================================================
#
# Found 3 results:
#
# 1. File: 24+Noel+B.+Agustin+et+al.,+pp.+269-281_processed.txt
#    Score: 0.6252
#    Risk Score: 67.0
#    Entities:
#    Text: [Section 7] . cryptocurrencies subject inflation risk limited supply. example, bitcoin fixed supply 21 million coins, means value coin decrease demand currencies increases. counts money, volatile. cry...
# --------------------------------------------------
#
# 2. File: Cryptocurrency Returns_processed.txt
#    Score: 0.5971
#    Risk Score: 0.0
#    Entities:
#    Text: [Section 5] . moreover, historically high returns offered cryptocur- rency investments limited lives attracted interest speculating investors, casual observers. potential returns enormous relative con...
# --------------------------------------------------
#
# 3. File: Cryptocurrency Returns_processed.txt
#    Score: 0.5906
#    Risk Score: 0.0
#    Entities:
#    Text: [Section 2] . digital means exchange focus extensive news coverage, especially bitcoin, primary focus tremendous potential return high level accompanying risk. chapter, examine risk-return pattern arr...
# --------------------------------------------------
#
# Searching for: Identify potential fraud in crypto transactions
# ==================================================
#
# Found 3 results:
#
# 1. File: information-14-00171_processed.txt
#    Score: 0.6028
#    Risk Score: 30.0
#    Entities:
#    Text: [Section 2] . use cryptocurrencies common multiple services. food chains, network service providers, tech companies, grocery stores, services accept cryptocurrency mode payment incentives people pay t...
# --------------------------------------------------
#
# 2. File: information-14-00171_processed.txt
#    Score: 0.5984
#    Risk Score: 10.0
#    Entities:
#    Text: [Section 42] . baek et al., 71 , unsupervised learning expectation-maximization algorithm cluster data extract features ethereum transactions real world blockchain ledgers. features engineered unsuper...
# --------------------------------------------------
#
# 3. File: information-14-00171_processed.txt
#    Score: 0.5971
#    Risk Score: 10.0
#    Entities:
#    Text: [Section 8] . compare existing works use different machine learning models different datasets primary reason models aimed identifying scams cryptocurrencies, success rate depends accurate ef cient ach...
# --------------------------------------------------
#
# Searching for: What are KYC requirements for exchanges?
# ==================================================
#
# Found 3 results:
#
# 1. File: OAX.txt
#    Score: 0.5739
#    Risk Score: 0.0
#    Entities:
#    Text: [Section 23] user establishes relationship gateway gateway direct kyc services kyc service provide kyc rating registered openanx dao note physical documents materials stored blockchain merely ethereum...
# --------------------------------------------------
#
# 2. File: selfkey en.txt
#    Score: 0.5521
#    Risk Score: 12.0
#    Entities:
#    Text: [Section 11] precious metals dealers storage facilities fiduciaries corporate services providers lenders banks securities firms lawyers accountants nonprofit foundations professional service providers...
# --------------------------------------------------
#
# 3. File: Micromines.txt
#    Score: 0.5374
#    Risk Score: 11.0
#    Entities:
#    Text: [Section 4] advantages centralised exchanges features ecosystem asian pacific market token information allocations team structure roadmap exchanges useful links 4 x0cmicroex micromines developing gene...
# --------------------------------------------------
#
# --- Custom Queries ---
#
#
# Searching for: How does blockchain prevent fraud?
# ==================================================
#
# Found 3 results:
#
# 1. File: information-14-00171_processed.txt
#    Score: 0.5390
#    Risk Score: 10.0
#    Entities:
#    Text: [Section 6] . enriched glossary makes blockchain. fact blockchain technology decentralized covers identity user address attracts scams felonious activities. machine learning models use different algor...
# --------------------------------------------------
#
# 2. File: Almeela.txt
#    Score: 0.5284
#    Risk Score: 11.0
#    Entities:
#    Text: [Section 32] blockchain technology makes perfectly suited financial services individual check wallet blockchain ensure funds present sent directly individual involved transaction products tried send l...
# --------------------------------------------------
#
# 3. File: Lightpaycoin.txt
#    Score: 0.5281
#    Risk Score: 21.0
#    Entities:
#    Text: [Section 5] easier safer traditional payment solutions susceptible billions dollars fraud year page 4 21 x0cblockchain technology overview new cryptocurrency industry blockchain way storing data digit...
# --------------------------------------------------
#
# Searching for: What are the key risks in DeFi platforms?
# ==================================================
#
# Found 3 results:
#
# 1. File: WEF_Digital_Assets_Regulation_2024_cleaned.txt
#    Score: 0.5536
#    Risk Score: 12.0
#    Entities:
#    Text: [Section 75] control environment developer experiment digital asset decentralize protocol approach facilitates development guideline regulation practical forwardlooking industry player aim innovate sp...
# --------------------------------------------------
#
# 2. File: NeuroChain.txt
#    Score: 0.5418
#    Risk Score: 44.0
#    Entities:
#    Text: [Section 75] risk platform developed meet buyer expectations platform currently development undergo significant redesign prior launch number reasons buyer expectations concerning platform ncc s form f...
# --------------------------------------------------
#
# 3. File: Dai.txt
#    Score: 0.5404
#    Risk Score: 33.0
#    Entities:
#    Text: [Section 180] like dai natural choice prediction market gambling users financial markets hedging derivatives leverage cdps allow permissionless leveraged trading dai useful stable reliable collateral ...
# --------------------------------------------------
#
# Searching for: Explain money laundering concerns in cryptocurrency
# ==================================================
#
# Found 3 results:
#
# 1. File: information-14-00171_processed.txt
#    Score: 0.6796
#    Risk Score: 43.0
#    Entities:
#    Text: [Section 19] . high-yield investment programs hyip high-yield investment programs hyips ponzi schemes promise high returns investments short periods time. programs cheated investors millions dollars. ...
# --------------------------------------------------
#
# 2. File: information-14-00171_processed.txt
#    Score: 0.6631
#    Risk Score: 32.0
#    Entities:
#    Text: [Section 63] . 31. phan, l. li, s. mentzer, k. blockchain technology current discussion fraud. comput. inf. syst. j. 2019, 20, 8 20. 32. teichmann, f.m.j. falker, m.c. cryptocurrencies nancial crime s...
# --------------------------------------------------
#
# 3. File: The Influence of Cryptocurrency on International_processed.txt
#    Score: 0.6533
#    Risk Score: 12.0
#    Entities:
#    Text: [Section 1] --- page 1 --- journal global economy, business finance jgebf issn 2141-5595 journal global economy, business finance jgebf issn 2141-5595 http www.bryanhousepub.org volume 4 issue 1 2022 ...
# --------------------------------------------------
#
# Searching for: How do stablecoins maintain their value?
# ==================================================
#
# Found 3 results:
#
# 1. File: Anchor.txt
#    Score: 0.5322
#    Risk Score: 12.0
#    Entities:
#    Text: [Section 8] value prevent fluctuations dependent market changes offering benefits cryptocurrencies stablecoins generally fall main categories collateralized crypto collateralized algorithmic www thean...
# --------------------------------------------------
#
# 2. File: 1110830.1.0 Introduction to Digital Assets for Institutional Investors_FINAL_0.txt
#    Score: 0.5303
#    Risk Score: 0.0
#    Entities:
#      - Location: china, russia
#    Text: [Section 14] . need stablecoins emerged early days digital assets traditional banking payment providers refused work exchanges. users needed way convert fiat currency bitcoin digital assets, stablecoi...
# --------------------------------------------------
#
# 3. File: Constant.txt
#    Score: 0.5297
#    Risk Score: 0.0
#    Entities:
#    Text: [Section 13] x8bthe price level target specified terms xe2 x80 x8bcrypto asset index xe2 x80 x8b constructed publicly listed prices crypto assets exchanges fed oracles method facilitates transparency ...
# --------------------------------------------------
